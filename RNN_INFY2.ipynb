# %% [markdown]
# <a href="https://colab.research.google.com/github/adityabaidya7/INFY_StockPricePrediction/blob/main/RNN_INFY2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# INFOSYS Stock Price Prediction using Base RNN (SimpleRNN) with yfinance

import numpy as np
import pandas as pd
import datetime
import holidays
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
import tensorflow as tf
import warnings
warnings.filterwarnings('ignore')

# %%
# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Define constants
SYMBOL = "INFY.NS"
START_DATE = "2020-06-01"
END_DATE = "2025-05-31"
SEQUENCE_LENGTH = 60  # 60 days for input sequence

# Get Indian trading holidays
def get_nse_holidays():
    in_holidays = holidays.India(years=range(2020, 2026))
    return set(in_holidays.keys())

TRADING_HOLIDAYS = get_nse_holidays()

# Validate input date
def is_valid_date(date_str):
    try:
        date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
        if not (datetime.date(2020, 6, 1) <= date <= datetime.date(2025, 5, 31)):
            print("Date not in allowed range.")
            return False
        if date.weekday() >= 5:
            print("Weekends are not trading days.")
            return False
        if date in TRADING_HOLIDAYS:
            print("Entered date is a trading holiday.")
            return False
        return True
    except ValueError:
        print("Invalid date format. Use YYYY-MM-DD.")
        return False

# Prompt until valid date is entered
def get_user_date():
    while True:
        date_input = input("Enter a date (YYYY-MM-DD): ")
        if is_valid_date(date_input):
            return datetime.datetime.strptime(date_input, "%Y-%m-%d").date()

# Download historical stock data using yfinance
def get_stock_data():
    print("Fetching data from Yahoo Finance...")
    df = yf.download(SYMBOL, start=START_DATE, end=END_DATE)
    df = df[['Close']]
    df.dropna(inplace=True)
    df.index = pd.to_datetime(df.index)
    return df

# Preprocess: Normalize data and create sequences
def preprocess_data(df):
    scaler = MinMaxScaler()
    scaled_close = scaler.fit_transform(df[['Close']])

    X, y = [], []
    for i in range(SEQUENCE_LENGTH, len(scaled_close)):
        X.append(scaled_close[i - SEQUENCE_LENGTH:i])
        y.append(scaled_close[i])

    X = np.array(X)
    y = np.array(y)
    return X, y, scaler, scaled_close

# Build the SimpleRNN model
def build_model(input_shape):
    model = Sequential()
    model.add(SimpleRNN(units=50, activation='tanh', input_shape=input_shape))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Predict closing price for the given date
def predict_price(model, df, user_date, scaler, scaled_close):
    all_dates = df.index.date
    # Convert user_date to datetime.date for consistent comparison
    user_date_dt = user_date

    # Find the closest trading day if the requested date is not a trading day
    if user_date_dt not in all_dates:
        print(f"No trading data on {user_date_dt}. Predicting for previous valid trading day.")
        try:
            # Find the latest trading day before user_date
            date_used = max([d for d in all_dates if d < user_date_dt])
        except ValueError:
            # No trading data before the user date
            print("No sufficient historical data available before the entered date.")
            return None, None, user_date_dt
    else:
        date_used = user_date_dt # Use the exact user date if it's a trading day

    try:
        # Get the index position for the date used for prediction
        idx = list(df.index.date).index(date_used)
    except ValueError:
        # Should not happen if date_used is from df.index.date, but added for robustness
        print(f"Error finding index for date {date_used}.")
        return None, None, user_date_dt

    if idx < SEQUENCE_LENGTH:
        print("Not enough historical data to make a prediction.")
        return None, None, date_used

    # Prepare input sequence
    input_seq = scaled_close[idx - SEQUENCE_LENGTH:idx]
    input_seq = np.reshape(input_seq, (1, SEQUENCE_LENGTH, 1))

    # Predict scaled price
    predicted_scaled = model.predict(input_seq, verbose=0)
    # Inverse transform to get the actual price
    predicted_price = scaler.inverse_transform(predicted_scaled)[0][0]

    # Get the actual price for the date used for prediction
    # Ensure we handle potential Series output from .loc
    actual_price_series = df.loc[df.index.date == date_used, 'Close']
    actual_price = float(actual_price_series.iloc[0]) if not actual_price_series.empty else None

    return predicted_price, actual_price, date_used

# Plot the result
def plot_results(df, predicted_date, predicted_price):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Historical Close Price',zorder=1)
    #plt.axvline(pd.to_datetime(predicted_date), color='red', linestyle='--', label='Predicted Date')
    plt.scatter(pd.to_datetime(predicted_date), predicted_price, color='orange', label='Predicted Price',zorder=2)
    plt.title("INFOSYS Stock Price with Prediction (yfinance)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#Plotting error with no. of epochs
def plot_training_loss(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title("Training and Validation Loss Over Epochs")
    plt.xlabel("Epoch no.")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Main Function
def main():
    print("=== INFOSYS Stock Price Predictor ===")
    user_date = get_user_date()

    # Step 1: Load and prepare data
    df = get_stock_data()

    # Step 2: Preprocessing
    X, y, scaler, scaled_close = preprocess_data(df)

    # Step 3: Build and train the model
    model = build_model((X.shape[1], 1))
    print("Training RNN model...")
    history = model.fit(X, y, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

    ####
    plot_training_loss(history)

    # Step 4: Predict
    predicted_price, actual_price, date_used = predict_price(model, df, user_date, scaler, scaled_close)
    if predicted_price is not None: # Check if prediction was possible
        print(f"\n📅 Prediction for {date_used}:")
        print(f"🔮 Predicted Closing Price: ₹{predicted_price:.2f}")
        if actual_price is not None: # Check if actual price was found
            print(f"📈 Actual Closing Price   : ₹{actual_price}")
        else:
            print("⚠️ Actual price not available for this date.")

        # Step 5: Plot
        plot_results(df, date_used, predicted_price)
    else:
        print("❌ Unable to predict price due to insufficient data.")

if __name__ == "__main__":
    main()
# Out:
# === INFOSYS Stock Price Predictor ===
# Enter a date (YYYY-MM-DD): 2025-04-21
# [*********************100%***********************]  1 of 1 completed
# Fetching data from Yahoo Finance...
# Training RNN model...
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0579 - val_loss: 0.0024
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.5464e-04 - val_loss: 0.0021
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.1473e-04 - val_loss: 0.0021
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.6225e-04 - val_loss: 0.0020
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.2751e-04 - val_loss: 0.0019
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.9892e-04 - val_loss: 0.0017
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.7424e-04 - val_loss: 0.0015
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.5323e-04 - val_loss: 0.0014
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.3688e-04 - val_loss: 0.0013
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.2367e-04 - val_loss: 0.0012
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1248e-04 - val_loss: 0.0011
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.0287e-04 - val_loss: 0.0011
# Epoch 13/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9445e-04 - val_loss: 0.0011
# Epoch 14/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8693e-04 - val_loss: 0.0010
# Epoch 15/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8011e-04 - val_loss: 9.9052e-04
# Epoch 16/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7384e-04 - val_loss: 9.6577e-04
# Epoch 17/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.6802e-04 - val_loss: 9.4333e-04
# Epoch 18/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.6259e-04 - val_loss: 9.2276e-04
# Epoch 19/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.5751e-04 - val_loss: 9.0386e-04
# Epoch 20/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.5275e-04 - val_loss: 8.8647e-04
# Epoch 21/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.4828e-04 - val_loss: 8.7051e-04
# Epoch 22/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.4407e-04 - val_loss: 8.5582e-04
# Epoch 23/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4010e-04 - val_loss: 8.4225e-04
# Epoch 24/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3635e-04 - val_loss: 8.2962e-04
# Epoch 25/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.3278e-04 - val_loss: 8.1777e-04
# Epoch 26/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.2937e-04 - val_loss: 8.0656e-04
# Epoch 27/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.2610e-04 - val_loss: 7.9586e-04
# Epoch 28/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.2296e-04 - val_loss: 7.8553e-04
# Epoch 29/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.1991e-04 - val_loss: 7.7551e-04
# Epoch 30/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1695e-04 - val_loss: 7.6572e-04
# Epoch 31/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1407e-04 - val_loss: 7.5612e-04
# Epoch 32/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.1124e-04 - val_loss: 7.4672e-04
# Epoch 33/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.0848e-04 - val_loss: 7.3751e-04
# Epoch 34/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.0576e-04 - val_loss: 7.2851e-04
# Epoch 35/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.0310e-04 - val_loss: 7.1975e-04
# Epoch 36/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.0048e-04 - val_loss: 7.1127e-04
# Epoch 37/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9791e-04 - val_loss: 7.0309e-04
# Epoch 38/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.9540e-04 - val_loss: 6.9526e-04
# Epoch 39/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.9294e-04 - val_loss: 6.8777e-04
# Epoch 40/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.9054e-04 - val_loss: 6.8066e-04
# Epoch 41/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.8821e-04 - val_loss: 6.7392e-04
# Epoch 42/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.8594e-04 - val_loss: 6.6756e-04
# Epoch 43/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8374e-04 - val_loss: 6.6155e-04
# Epoch 44/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8161e-04 - val_loss: 6.5592e-04
# Epoch 45/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7955e-04 - val_loss: 6.5061e-04
# Epoch 46/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7756e-04 - val_loss: 6.4564e-04
# Epoch 47/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7565e-04 - val_loss: 6.4096e-04
# Epoch 48/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.7380e-04 - val_loss: 6.3657e-04
# Epoch 49/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.7202e-04 - val_loss: 6.3244e-04
# Epoch 50/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.7031e-04 - val_loss: 6.2855e-04
# Epoch 51/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6867e-04 - val_loss: 6.2487e-04
# Epoch 52/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6708e-04 - val_loss: 6.2140e-04
# Epoch 53/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.6555e-04 - val_loss: 6.1813e-04
# Epoch 54/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.6408e-04 - val_loss: 6.1501e-04
# Epoch 55/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.6267e-04 - val_loss: 6.1205e-04
# Epoch 56/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6130e-04 - val_loss: 6.0924e-04
# Epoch 57/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5998e-04 - val_loss: 6.0655e-04
# Epoch 58/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5871e-04 - val_loss: 6.0399e-04
# Epoch 59/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.5748e-04 - val_loss: 6.0155e-04
# Epoch 60/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5629e-04 - val_loss: 5.9922e-04
# Epoch 61/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5513e-04 - val_loss: 5.9699e-04
# Epoch 62/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.5402e-04 - val_loss: 5.9487e-04
# Epoch 63/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.5294e-04 - val_loss: 5.9284e-04
# Epoch 64/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.5189e-04 - val_loss: 5.9091e-04
# Epoch 65/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.5088e-04 - val_loss: 5.8908e-04
# Epoch 66/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.4990e-04 - val_loss: 5.8733e-04
# Epoch 67/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.4895e-04 - val_loss: 5.8569e-04
# Epoch 68/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.4803e-04 - val_loss: 5.8413e-04
# Epoch 69/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.4715e-04 - val_loss: 5.8264e-04
# Epoch 70/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.4629e-04 - val_loss: 5.8124e-04
# Epoch 71/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4546e-04 - val_loss: 5.7991e-04
# Epoch 72/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4466e-04 - val_loss: 5.7865e-04
# Epoch 73/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.4389e-04 - val_loss: 5.7744e-04
# Epoch 74/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.4315e-04 - val_loss: 5.7628e-04
# Epoch 75/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4243e-04 - val_loss: 5.7515e-04
# Epoch 76/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4173e-04 - val_loss: 5.7407e-04
# Epoch 77/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4106e-04 - val_loss: 5.7300e-04
# Epoch 78/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4041e-04 - val_loss: 5.7196e-04
# Epoch 79/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.3978e-04 - val_loss: 5.7093e-04
# Epoch 80/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3917e-04 - val_loss: 5.6993e-04
# Epoch 81/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3858e-04 - val_loss: 5.6893e-04
# Epoch 82/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.3801e-04 - val_loss: 5.6796e-04
# Epoch 83/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3746e-04 - val_loss: 5.6702e-04
# Epoch 84/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.3692e-04 - val_loss: 5.6610e-04
# Epoch 85/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3641e-04 - val_loss: 5.6520e-04
# Epoch 86/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.3591e-04 - val_loss: 5.6434e-04
# Epoch 87/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3542e-04 - val_loss: 5.6351e-04
# Epoch 88/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.3496e-04 - val_loss: 5.6271e-04
# Epoch 89/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.3451e-04 - val_loss: 5.6195e-04
# Epoch 90/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.3408e-04 - val_loss: 5.6123e-04
# Epoch 91/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.3367e-04 - val_loss: 5.6054e-04
# Epoch 92/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.3327e-04 - val_loss: 5.5989e-04
# Epoch 93/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.3289e-04 - val_loss: 5.5927e-04
# Epoch 94/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3252e-04 - val_loss: 5.5870e-04
# Epoch 95/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3217e-04 - val_loss: 5.5815e-04
# Epoch 96/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.3183e-04 - val_loss: 5.5764e-04
# Epoch 97/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.3151e-04 - val_loss: 5.5716e-04
# Epoch 98/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.3120e-04 - val_loss: 5.5671e-04
# Epoch 99/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3090e-04 - val_loss: 5.5630e-04
# Epoch 100/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.3062e-04 - val_loss: 5.5591e-04
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x793f410abec0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 📅 Prediction for 2025-04-21:
# 🔮 Predicted Closing Price: ₹1399.36
# 📈 Actual Closing Price   : ₹1430.8675537109375

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Define constants
SYMBOL = "INFY.NS"
START_DATE = "2020-06-01"
END_DATE = "2025-05-31"
SEQUENCE_LENGTH = 60  # 60 days for input sequence

# Get Indian trading holidays
def get_nse_holidays():
    in_holidays = holidays.India(years=range(2020, 2026))
    return set(in_holidays.keys())

TRADING_HOLIDAYS = get_nse_holidays()

# Validate input date
def is_valid_date(date_str):
    try:
        date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
        if not (datetime.date(2020, 6, 1) <= date <= datetime.date(2025, 5, 31)):
            print("Date not in allowed range.")
            return False
        if date.weekday() >= 5:
            print("Weekends are not trading days.")
            return False
        if date in TRADING_HOLIDAYS:
            print("Entered date is a trading holiday.")
            return False
        return True
    except ValueError:
        print("Invalid date format. Use YYYY-MM-DD.")
        return False

# Prompt until valid date is entered
def get_user_date():
    while True:
        date_input = input("Enter a date (YYYY-MM-DD): ")
        if is_valid_date(date_input):
            return datetime.datetime.strptime(date_input, "%Y-%m-%d").date()

# Download historical stock data using yfinance
def get_stock_data():
    print("Fetching data from Yahoo Finance...")
    df = yf.download(SYMBOL, start=START_DATE, end=END_DATE)
    df = df[['Close']]
    df.dropna(inplace=True)
    df.index = pd.to_datetime(df.index)
    return df

# Preprocess: Normalize data and create sequences
def preprocess_data(df):
    scaler = MinMaxScaler()
    scaled_close = scaler.fit_transform(df[['Close']])

    X, y = [], []
    for i in range(SEQUENCE_LENGTH, len(scaled_close)):
        X.append(scaled_close[i - SEQUENCE_LENGTH:i])
        y.append(scaled_close[i])

    X = np.array(X)
    y = np.array(y)
    return X, y, scaler, scaled_close

# Build the SimpleRNN model
def build_model(input_shape):
    model = Sequential()
    model.add(SimpleRNN(units=50, activation='tanh', input_shape=input_shape))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Predict closing price for the given date
def predict_price(model, df, user_date, scaler, scaled_close):
    all_dates = df.index.date
    # Convert user_date to datetime.date for consistent comparison
    user_date_dt = user_date

    # Find the closest trading day if the requested date is not a trading day
    if user_date_dt not in all_dates:
        print(f"No trading data on {user_date_dt}. Predicting for previous valid trading day.")
        try:
            # Find the latest trading day before user_date
            date_used = max([d for d in all_dates if d < user_date_dt])
        except ValueError:
            # No trading data before the user date
            print("No sufficient historical data available before the entered date.")
            return None, None, user_date_dt
    else:
        date_used = user_date_dt # Use the exact user date if it's a trading day

    try:
        # Get the index position for the date used for prediction
        idx = list(df.index.date).index(date_used)
    except ValueError:
        # Should not happen if date_used is from df.index.date, but added for robustness
        print(f"Error finding index for date {date_used}.")
        return None, None, user_date_dt

    if idx < SEQUENCE_LENGTH:
        print("Not enough historical data to make a prediction.")
        return None, None, date_used

    # Prepare input sequence
    input_seq = scaled_close[idx - SEQUENCE_LENGTH:idx]
    input_seq = np.reshape(input_seq, (1, SEQUENCE_LENGTH, 1))

    # Predict scaled price
    predicted_scaled = model.predict(input_seq, verbose=0)
    # Inverse transform to get the actual price
    predicted_price = scaler.inverse_transform(predicted_scaled)[0][0]

    # Get the actual price for the date used for prediction
    # Ensure we handle potential Series output from .loc
    actual_price_series = df.loc[df.index.date == date_used, 'Close']
    actual_price = float(actual_price_series.iloc[0]) if not actual_price_series.empty else None

    return predicted_price, actual_price, date_used

# Plot the result
def plot_results(df, predicted_date, predicted_price):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Historical Close Price',zorder=1)
    #plt.axvline(pd.to_datetime(predicted_date), color='red', linestyle='--', label='Predicted Date')
    plt.scatter(pd.to_datetime(predicted_date), predicted_price, color='orange', label='Predicted Price',zorder=2)
    plt.title("INFOSYS Stock Price with Prediction (yfinance)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#Plotting error with no. of epochs
def plot_training_loss(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title("Training and Validation Loss Over Epochs")
    plt.xlabel("Epoch no.")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Main Function
def main():
    print("=== INFOSYS Stock Price Predictor ===")
    user_date = get_user_date()

    # Step 1: Load and prepare data
    df = get_stock_data()

    # Step 2: Preprocessing
    X, y, scaler, scaled_close = preprocess_data(df)

    # Step 3: Build and train the model
    model = build_model((X.shape[1], 1))
    print("Training RNN model...")
    history = model.fit(X, y, epochs=80, batch_size=32, validation_split=0.2, verbose=1)

    ####
    plot_training_loss(history)

    # Predict on training data to evaluate performance
    y_train_pred_scaled = model.predict(X, verbose=0)
    y_train_pred = scaler.inverse_transform(y_train_pred_scaled)
    y_true = scaler.inverse_transform(y.reshape(-1, 1))

    # Calculate metrics
    mae = mean_absolute_error(y_true, y_train_pred)
    mse = mean_squared_error(y_true, y_train_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_train_pred)

    # Print metrics
    print("\n📊 Training Set Performance Metrics:")
    print(f"📉 Mean Absolute Error (MAE) : ₹{mae:.2f}")
    print(f"📉 Mean Squared Error (MSE)  : ₹{mse:.2f}")
    print(f"📉 Root Mean Squared Error   : ₹{rmse:.2f}")
    print(f"📈 R² Score                  : {r2:.4f}")

    # Step 4: Predict
    predicted_price, actual_price, date_used = predict_price(model, df, user_date, scaler, scaled_close)
    if predicted_price is not None: # Check if prediction was possible
        print(f"\n📅 Prediction for {date_used}:")
        print(f"🔮 Predicted Closing Price: ₹{predicted_price:.2f}")
        if actual_price is not None: # Check if actual price was found
            print(f"📈 Actual Closing Price   : ₹{actual_price}")
        else:
            print("⚠️ Actual price not available for this date.")

        # Step 5: Plot
        plot_results(df, date_used, predicted_price)
    else:
        print("❌ Unable to predict price due to insufficient data.")

if __name__ == "__main__":
    main()
# Out:
# === INFOSYS Stock Price Predictor ===
# Enter a date (YYYY-MM-DD): 2025-03-21
# Fetching data from Yahoo Finance...
# [*********************100%***********************]  1 of 1 completed
# Training RNN model...
# Epoch 1/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0255 - val_loss: 0.0128
# Epoch 2/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014 - val_loss: 0.0055
# Epoch 3/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.3967e-04 - val_loss: 0.0037
# Epoch 4/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.2408e-04 - val_loss: 0.0033
# Epoch 5/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.4728e-04 - val_loss: 0.0029
# Epoch 6/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.8888e-04 - val_loss: 0.0027
# Epoch 7/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.4683e-04 - val_loss: 0.0026
# Epoch 8/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.1074e-04 - val_loss: 0.0022
# Epoch 9/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.7302e-04 - val_loss: 0.0017
# Epoch 10/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.4672e-04 - val_loss: 0.0015
# Epoch 11/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.3113e-04 - val_loss: 0.0013
# Epoch 12/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.2328e-04 - val_loss: 0.0012
# Epoch 13/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.1889e-04 - val_loss: 0.0011
# Epoch 14/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.1391e-04 - val_loss: 0.0011
# Epoch 15/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.0657e-04 - val_loss: 0.0010
# Epoch 16/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.9804e-04 - val_loss: 9.4160e-04
# Epoch 17/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.8962e-04 - val_loss: 8.8546e-04
# Epoch 18/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8171e-04 - val_loss: 8.3630e-04
# Epoch 19/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.7423e-04 - val_loss: 7.9407e-04
# Epoch 20/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.6704e-04 - val_loss: 7.5790e-04
# Epoch 21/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.6009e-04 - val_loss: 7.2680e-04
# Epoch 22/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.5330e-04 - val_loss: 6.9995e-04
# Epoch 23/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.4666e-04 - val_loss: 6.7667e-04
# Epoch 24/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.4015e-04 - val_loss: 6.5637e-04
# Epoch 25/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3375e-04 - val_loss: 6.3859e-04
# Epoch 26/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.2747e-04 - val_loss: 6.2295e-04
# Epoch 27/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.2132e-04 - val_loss: 6.0910e-04
# Epoch 28/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1530e-04 - val_loss: 5.9679e-04
# Epoch 29/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0943e-04 - val_loss: 5.8578e-04
# Epoch 30/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.0371e-04 - val_loss: 5.7587e-04
# Epoch 31/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.9816e-04 - val_loss: 5.6691e-04
# Epoch 32/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.9277e-04 - val_loss: 5.5877e-04
# Epoch 33/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.8756e-04 - val_loss: 5.5132e-04
# Epoch 34/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8252e-04 - val_loss: 5.4447e-04
# Epoch 35/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7765e-04 - val_loss: 5.3815e-04
# Epoch 36/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7295e-04 - val_loss: 5.3229e-04
# Epoch 37/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6840e-04 - val_loss: 5.2685e-04
# Epoch 38/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.6400e-04 - val_loss: 5.2177e-04
# Epoch 39/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5974e-04 - val_loss: 5.1702e-04
# Epoch 40/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5560e-04 - val_loss: 5.1258e-04
# Epoch 41/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.5157e-04 - val_loss: 5.0841e-04
# Epoch 42/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4763e-04 - val_loss: 5.0450e-04
# Epoch 43/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4379e-04 - val_loss: 5.0083e-04
# Epoch 44/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4004e-04 - val_loss: 4.9738e-04
# Epoch 45/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.3636e-04 - val_loss: 4.9413e-04
# Epoch 46/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.3277e-04 - val_loss: 4.9108e-04
# Epoch 47/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.2925e-04 - val_loss: 4.8820e-04
# Epoch 48/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2580e-04 - val_loss: 4.8548e-04
# Epoch 49/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.2243e-04 - val_loss: 4.8292e-04
# Epoch 50/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1914e-04 - val_loss: 4.8050e-04
# Epoch 51/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.1593e-04 - val_loss: 4.7822e-04
# Epoch 52/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.1279e-04 - val_loss: 4.7606e-04
# Epoch 53/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.0972e-04 - val_loss: 4.7403e-04
# Epoch 54/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.0674e-04 - val_loss: 4.7211e-04
# Epoch 55/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.0382e-04 - val_loss: 4.7030e-04
# Epoch 56/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0098e-04 - val_loss: 4.6859e-04
# Epoch 57/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.9822e-04 - val_loss: 4.6698e-04
# Epoch 58/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9552e-04 - val_loss: 4.6547e-04
# Epoch 59/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9290e-04 - val_loss: 4.6405e-04
# Epoch 60/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.9034e-04 - val_loss: 4.6272e-04
# Epoch 61/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.8785e-04 - val_loss: 4.6147e-04
# Epoch 62/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8542e-04 - val_loss: 4.6031e-04
# Epoch 63/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.8305e-04 - val_loss: 4.5924e-04
# Epoch 64/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8075e-04 - val_loss: 4.5824e-04
# Epoch 65/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7851e-04 - val_loss: 4.5732e-04
# Epoch 66/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.7633e-04 - val_loss: 4.5648e-04
# Epoch 67/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7421e-04 - val_loss: 4.5570e-04
# Epoch 68/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.7216e-04 - val_loss: 4.5499e-04
# Epoch 69/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.7017e-04 - val_loss: 4.5434e-04
# Epoch 70/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6825e-04 - val_loss: 4.5375e-04
# Epoch 71/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.6640e-04 - val_loss: 4.5321e-04
# Epoch 72/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6461e-04 - val_loss: 4.5271e-04
# Epoch 73/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6290e-04 - val_loss: 4.5225e-04
# Epoch 74/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.6126e-04 - val_loss: 4.5181e-04
# Epoch 75/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5970e-04 - val_loss: 4.5140e-04
# Epoch 76/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.5822e-04 - val_loss: 4.5101e-04
# Epoch 77/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.5681e-04 - val_loss: 4.5062e-04
# Epoch 78/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.5548e-04 - val_loss: 4.5023e-04
# Epoch 79/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.5423e-04 - val_loss: 4.4984e-04
# Epoch 80/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5306e-04 - val_loss: 4.4943e-04
# 📊 Training Set Performance Metrics:
# 📉 Mean Absolute Error (MAE) : ₹17.40
# 📉 Mean Squared Error (MSE)  : ₹565.20
# 📉 Root Mean Squared Error   : ₹23.77
# 📈 R² Score                  : 0.9899
#
# 📅 Prediction for 2025-03-21:
# 🔮 Predicted Closing Price: ₹1594.06
# 📈 Actual Closing Price   : ₹1570.45361328125

# %%
# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Define constants
SYMBOL = "INFY.NS"
START_DATE = "2020-06-01"
END_DATE = "2025-05-31"
SEQUENCE_LENGTH = 60  # 60 days for input sequence

# Get Indian trading holidays
def get_nse_holidays():
    in_holidays = holidays.India(years=range(2020, 2026))
    return set(in_holidays.keys())

TRADING_HOLIDAYS = get_nse_holidays()

# Validate input date
def is_valid_date(date_str):
    try:
        date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
        if not (datetime.date(2020, 6, 1) <= date <= datetime.date(2025, 5, 31)):
            print("Date not in allowed range.")
            return False
        if date.weekday() >= 5:
            print("Weekends are not trading days.")
            return False
        if date in TRADING_HOLIDAYS:
            print("Entered date is a trading holiday.")
            return False
        return True
    except ValueError:
        print("Invalid date format. Use YYYY-MM-DD.")
        return False

# Prompt until valid date is entered
def get_user_date():
    while True:
        date_input = input("Enter a date (YYYY-MM-DD): ")
        if is_valid_date(date_input):
            return datetime.datetime.strptime(date_input, "%Y-%m-%d").date()

# Download historical stock data using yfinance
def get_stock_data():
    print("Fetching data from Yahoo Finance...")
    df = yf.download(SYMBOL, start=START_DATE, end=END_DATE)
    df = df[['Close']]
    df.dropna(inplace=True)
    df.index = pd.to_datetime(df.index)
    return df

# Preprocess: Normalize data and create sequences
def preprocess_data(df):
    scaler = MinMaxScaler()
    scaled_close = scaler.fit_transform(df[['Close']])

    X, y = [], []
    for i in range(SEQUENCE_LENGTH, len(scaled_close)):
        X.append(scaled_close[i - SEQUENCE_LENGTH:i])
        y.append(scaled_close[i])

    X = np.array(X)
    y = np.array(y)
    return X, y, scaler, scaled_close

# Build the SimpleRNN model
def build_model(input_shape):
    model = Sequential()
    model.add(SimpleRNN(units=50, activation='tanh', input_shape=input_shape))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Predict closing price for the given date
def predict_price(model, df, user_date, scaler, scaled_close):
    all_dates = df.index.date
    # Convert user_date to datetime.date for consistent comparison
    user_date_dt = user_date

    # Find the closest trading day if the requested date is not a trading day
    if user_date_dt not in all_dates:
        print(f"No trading data on {user_date_dt}. Predicting for previous valid trading day.")
        try:
            # Find the latest trading day before user_date
            date_used = max([d for d in all_dates if d < user_date_dt])
        except ValueError:
            # No trading data before the user date
            print("No sufficient historical data available before the entered date.")
            return None, None, user_date_dt
    else:
        date_used = user_date_dt # Use the exact user date if it's a trading day

    try:
        # Get the index position for the date used for prediction
        idx = list(df.index.date).index(date_used)
    except ValueError:
        # Should not happen if date_used is from df.index.date, but added for robustness
        print(f"Error finding index for date {date_used}.")
        return None, None, user_date_dt

    if idx < SEQUENCE_LENGTH:
        print("Not enough historical data to make a prediction.")
        return None, None, date_used

    # Prepare input sequence
    input_seq = scaled_close[idx - SEQUENCE_LENGTH:idx]
    input_seq = np.reshape(input_seq, (1, SEQUENCE_LENGTH, 1))

    # Predict scaled price
    predicted_scaled = model.predict(input_seq, verbose=0)
    # Inverse transform to get the actual price
    predicted_price = scaler.inverse_transform(predicted_scaled)[0][0]

    # Get the actual price for the date used for prediction
    # Ensure we handle potential Series output from .loc
    actual_price_series = df.loc[df.index.date == date_used, 'Close']
    actual_price = float(actual_price_series.iloc[0]) if not actual_price_series.empty else None

    return predicted_price, actual_price, date_used

# Plot the result
def plot_results(df, predicted_date, predicted_price):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Historical Close Price',zorder=1)
    #plt.axvline(pd.to_datetime(predicted_date), color='red', linestyle='--', label='Predicted Date')
    plt.scatter(pd.to_datetime(predicted_date), predicted_price, color='orange', label='Predicted Price',zorder=2)
    plt.title("INFOSYS Stock Price with Prediction (yfinance)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#Plotting error with no. of epochs
def plot_training_loss(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title("Training and Validation Loss Over Epochs (SimpleRNN)")
    plt.xlabel("Epoch no.")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Main Function
def main():
    print("=== INFOSYS Stock Price Predictor ===")
    user_date = get_user_date()

    # Step 1: Load and prepare data
    df = get_stock_data()

    # Step 2: Preprocessing
    X, y, scaler, scaled_close = preprocess_data(df)

    # Step 3: Build and train the model
    model = build_model((X.shape[1], 1))
    print("Training RNN model...")
    history = model.fit(X, y, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

    ####
    plot_training_loss(history)

    # Predict on training data to evaluate performance
    y_train_pred_scaled = model.predict(X, verbose=0)
    y_train_pred = scaler.inverse_transform(y_train_pred_scaled)
    y_true = scaler.inverse_transform(y.reshape(-1, 1))

    # Calculate metrics
    mae = mean_absolute_error(y_true, y_train_pred)
    mse = mean_squared_error(y_true, y_train_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_train_pred)

    # Print metrics
    print("\n📊 Training Set Performance Metrics (SimpleRNN):")
    print(f"📉 Mean Absolute Error (MAE) : ₹{mae:.2f}")
    print(f"📉 Mean Squared Error (MSE)  : ₹{mse:.2f}")
    print(f"📉 Root Mean Squared Error   : ₹{rmse:.2f}")
    print(f"📈 R² Score                  : {r2:.4f}")

    # Step 4: Predict
    predicted_price, actual_price, date_used = predict_price(model, df, user_date, scaler, scaled_close)
    if predicted_price is not None: # Check if prediction was possible
        print(f"\n📅 Prediction for {date_used}:")
        print(f"🔮 Predicted Closing Price: ₹{predicted_price:.2f}")
        if actual_price is not None: # Check if actual price was found
            print(f"📈 Actual Closing Price   : ₹{actual_price}")
        else:
            print("⚠️ Actual price not available for this date.")

        # Step 5: Plot
        plot_results(df, date_used, predicted_price)
    else:
        print("❌ Unable to predict price due to insufficient data.")

if __name__ == "__main__":
    main()
# Out:
# === INFOSYS Stock Price Predictor ===
# Enter a date (YYYY-MM-DD): 2025-05-30
# Fetching data from Yahoo Finance...
# [*********************100%***********************]  1 of 1 completed
# Training RNN model...
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.1523 - val_loss: 0.0119
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0020 - val_loss: 0.0069
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0010 - val_loss: 0.0043
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.0041e-04 - val_loss: 0.0034
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.5593e-04 - val_loss: 0.0031
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.1287e-04 - val_loss: 0.0029
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.7930e-04 - val_loss: 0.0026
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.5000e-04 - val_loss: 0.0024
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.2294e-04 - val_loss: 0.0023
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.9826e-04 - val_loss: 0.0021
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.7571e-04 - val_loss: 0.0020
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.5507e-04 - val_loss: 0.0018
# Epoch 13/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.3603e-04 - val_loss: 0.0017
# Epoch 14/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.1823e-04 - val_loss: 0.0016
# Epoch 15/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.0132e-04 - val_loss: 0.0016
# Epoch 16/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.8528e-04 - val_loss: 0.0015
# Epoch 17/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.7049e-04 - val_loss: 0.0015
# Epoch 18/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.5736e-04 - val_loss: 0.0015
# Epoch 19/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.4596e-04 - val_loss: 0.0014
# Epoch 20/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.3604e-04 - val_loss: 0.0014
# Epoch 21/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2727e-04 - val_loss: 0.0013
# Epoch 22/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.1937e-04 - val_loss: 0.0013
# Epoch 23/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1213e-04 - val_loss: 0.0013
# Epoch 24/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.0540e-04 - val_loss: 0.0013
# Epoch 25/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.9903e-04 - val_loss: 0.0012
# Epoch 26/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.9296e-04 - val_loss: 0.0012
# Epoch 27/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.8713e-04 - val_loss: 0.0012
# Epoch 28/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.8149e-04 - val_loss: 0.0012
# Epoch 29/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.7603e-04 - val_loss: 0.0012
# Epoch 30/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.7074e-04 - val_loss: 0.0011
# Epoch 31/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6558e-04 - val_loss: 0.0011
# Epoch 32/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6056e-04 - val_loss: 0.0011
# Epoch 33/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.5567e-04 - val_loss: 0.0011
# Epoch 34/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.5090e-04 - val_loss: 0.0011
# Epoch 35/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.4625e-04 - val_loss: 0.0010
# Epoch 36/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.4172e-04 - val_loss: 0.0010
# Epoch 37/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.3730e-04 - val_loss: 0.0010
# Epoch 38/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.3299e-04 - val_loss: 9.9984e-04
# Epoch 39/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.2879e-04 - val_loss: 9.8458e-04
# Epoch 40/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.2470e-04 - val_loss: 9.6975e-04
# Epoch 41/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.2070e-04 - val_loss: 9.5535e-04
# Epoch 42/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.1680e-04 - val_loss: 9.4141e-04
# Epoch 43/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.1299e-04 - val_loss: 9.2794e-04
# Epoch 44/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.0927e-04 - val_loss: 9.1493e-04
# Epoch 45/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.0564e-04 - val_loss: 9.0238e-04
# Epoch 46/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.0209e-04 - val_loss: 8.9029e-04
# Epoch 47/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9862e-04 - val_loss: 8.7865e-04
# Epoch 48/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9522e-04 - val_loss: 8.6747e-04
# Epoch 49/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.9189e-04 - val_loss: 8.5672e-04
# Epoch 50/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8864e-04 - val_loss: 8.4638e-04
# Epoch 51/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8545e-04 - val_loss: 8.3647e-04
# Epoch 52/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8232e-04 - val_loss: 8.2694e-04
# Epoch 53/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7925e-04 - val_loss: 8.1780e-04
# Epoch 54/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7624e-04 - val_loss: 8.0901e-04
# Epoch 55/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7328e-04 - val_loss: 8.0058e-04
# Epoch 56/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.7037e-04 - val_loss: 7.9248e-04
# Epoch 57/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.6752e-04 - val_loss: 7.8470e-04
# Epoch 58/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6470e-04 - val_loss: 7.7721e-04
# Epoch 59/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.6194e-04 - val_loss: 7.7001e-04
# Epoch 60/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5921e-04 - val_loss: 7.6307e-04
# Epoch 61/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5652e-04 - val_loss: 7.5639e-04
# Epoch 62/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.5387e-04 - val_loss: 7.4994e-04
# Epoch 63/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.5126e-04 - val_loss: 7.4372e-04
# Epoch 64/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.4869e-04 - val_loss: 7.3771e-04
# Epoch 65/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4615e-04 - val_loss: 7.3189e-04
# Epoch 66/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4364e-04 - val_loss: 7.2627e-04
# Epoch 67/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4117e-04 - val_loss: 7.2082e-04
# Epoch 68/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3873e-04 - val_loss: 7.1554e-04
# Epoch 69/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.3632e-04 - val_loss: 7.1043e-04
# Epoch 70/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3395e-04 - val_loss: 7.0546e-04
# Epoch 71/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.3160e-04 - val_loss: 7.0063e-04
# Epoch 72/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.2929e-04 - val_loss: 6.9594e-04
# Epoch 73/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.2701e-04 - val_loss: 6.9139e-04
# Epoch 74/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.2477e-04 - val_loss: 6.8697e-04
# Epoch 75/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2255e-04 - val_loss: 6.8266e-04
# Epoch 76/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.2037e-04 - val_loss: 6.7847e-04
# Epoch 77/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1822e-04 - val_loss: 6.7439e-04
# Epoch 78/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1610e-04 - val_loss: 6.7043e-04
# Epoch 79/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.1402e-04 - val_loss: 6.6658e-04
# Epoch 80/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1196e-04 - val_loss: 6.6283e-04
# Epoch 81/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.0994e-04 - val_loss: 6.5918e-04
# Epoch 82/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.0796e-04 - val_loss: 6.5563e-04
# Epoch 83/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0601e-04 - val_loss: 6.5217e-04
# Epoch 84/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.0409e-04 - val_loss: 6.4881e-04
# Epoch 85/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.0220e-04 - val_loss: 6.4554e-04
# Epoch 86/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.0035e-04 - val_loss: 6.4237e-04
# Epoch 87/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9853e-04 - val_loss: 6.3928e-04
# Epoch 88/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9675e-04 - val_loss: 6.3628e-04
# Epoch 89/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.9500e-04 - val_loss: 6.3335e-04
# Epoch 90/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.9329e-04 - val_loss: 6.3052e-04
# Epoch 91/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.9161e-04 - val_loss: 6.2776e-04
# Epoch 92/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8996e-04 - val_loss: 6.2508e-04
# Epoch 93/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.8835e-04 - val_loss: 6.2248e-04
# Epoch 94/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.8678e-04 - val_loss: 6.1995e-04
# Epoch 95/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.8524e-04 - val_loss: 6.1749e-04
# Epoch 96/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8373e-04 - val_loss: 6.1510e-04
# Epoch 97/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8226e-04 - val_loss: 6.1278e-04
# Epoch 98/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8082e-04 - val_loss: 6.1051e-04
# Epoch 99/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.7941e-04 - val_loss: 6.0831e-04
# Epoch 100/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.7804e-04 - val_loss: 6.0617e-04
# 📊 Training Set Performance Metrics:
# 📉 Mean Absolute Error (MAE) : ₹18.59
# 📉 Mean Squared Error (MSE)  : ₹636.02
# 📉 Root Mean Squared Error   : ₹25.22
# 📈 R² Score                  : 0.9888
#
# 📅 Prediction for 2025-05-30:
# 🔮 Predicted Closing Price: ₹1551.20
# 📈 Actual Closing Price   : ₹1562.699951171875

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Define constants
SYMBOL = "INFY.NS"
START_DATE = "2020-06-01"
END_DATE = "2025-05-31"
SEQUENCE_LENGTH = 60  # 60 days for input sequence

# Get Indian trading holidays
def get_nse_holidays():
    in_holidays = holidays.India(years=range(2020, 2026))
    return set(in_holidays.keys())

TRADING_HOLIDAYS = get_nse_holidays()

# Validate input date
def is_valid_date(date_str):
    try:
        date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
        if not (datetime.date(2020, 6, 1) <= date <= datetime.date(2025, 5, 31)):
            print("Date not in allowed range.")
            return False
        if date.weekday() >= 5:
            print("Weekends are not trading days.")
            return False
        if date in TRADING_HOLIDAYS:
            print("Entered date is a trading holiday.")
            return False
        return True
    except ValueError:
        print("Invalid date format. Use YYYY-MM-DD.")
        return False

# Prompt until valid date is entered
def get_user_date():
    while True:
        date_input = input("Enter a date (YYYY-MM-DD): ")
        if is_valid_date(date_input):
            return datetime.datetime.strptime(date_input, "%Y-%m-%d").date()

# Download historical stock data using yfinance
def get_stock_data():
    print("Fetching data from Yahoo Finance...")
    df = yf.download(SYMBOL, start=START_DATE, end=END_DATE)
    df = df[['Close']]
    df.dropna(inplace=True)
    df.index = pd.to_datetime(df.index)
    return df

# Preprocess: Normalize data and create sequences
def preprocess_data(df):
    scaler = MinMaxScaler()
    scaled_close = scaler.fit_transform(df[['Close']])

    X, y = [], []
    for i in range(SEQUENCE_LENGTH, len(scaled_close)):
        X.append(scaled_close[i - SEQUENCE_LENGTH:i])
        y.append(scaled_close[i])

    X = np.array(X)
    y = np.array(y)

    # Split into training and validation sets
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
    return X_train, X_val, y_train, y_val, scaler, scaled_close

# Build the SimpleRNN model
def build_model(input_shape):
    model = Sequential()
    model.add(SimpleRNN(units=50, activation='tanh', input_shape=input_shape))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Predict closing price for the given date
def predict_price(model, df, user_date, scaler, scaled_close):
    all_dates = df.index.date
    # Convert user_date to datetime.date for consistent comparison
    user_date_dt = user_date

    # Find the closest trading day if the requested date is not a trading day
    if user_date_dt not in all_dates:
        print(f"No trading data on {user_date_dt}. Predicting for previous valid trading day.")
        try:
            # Find the latest trading day before user_date
            date_used = max([d for d in all_dates if d < user_date_dt])
        except ValueError:
            # No trading data before the user date
            print("No sufficient historical data available before the entered date.")
            return None, None, user_date_dt
    else:
        date_used = user_date_dt # Use the exact user date if it's a trading day

    try:
        # Get the index position for the date used for prediction
        idx = list(df.index.date).index(date_used)
    except ValueError:
        # Should not happen if date_used is from df.index.date, but added for robustness
        print(f"Error finding index for date {date_used}.")
        return None, None, user_date_dt

    if idx < SEQUENCE_LENGTH:
        print("Not enough historical data to make a prediction.")
        return None, None, date_used

    # Prepare input sequence
    input_seq = scaled_close[idx - SEQUENCE_LENGTH:idx]
    input_seq = np.reshape(input_seq, (1, SEQUENCE_LENGTH, 1))

    # Predict scaled price
    predicted_scaled = model.predict(input_seq, verbose=0)
    # Inverse transform to get the actual price
    predicted_price = scaler.inverse_transform(predicted_scaled)[0][0]

    # Get the actual price for the date used for prediction
    # Ensure we handle potential Series output from .loc
    actual_price_series = df.loc[df.index.date == date_used, 'Close']
    actual_price = float(actual_price_series.iloc[0]) if not actual_price_series.empty else None

    return predicted_price, actual_price, date_used

# Plot the result
def plot_results(df, predicted_date, predicted_price):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Historical Close Price',zorder=1)
    #plt.axvline(pd.to_datetime(predicted_date), color='red', linestyle='--', label='Predicted Date')
    plt.scatter(pd.to_datetime(predicted_date), predicted_price, color='orange', label='Predicted Price',zorder=2)
    plt.title("INFOSYS Stock Price with Prediction (yfinance)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#Plotting error with no. of epochs
def plot_training_loss(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title("Training and Validation Loss Over Epochs")
    plt.xlabel("Epoch no.")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Main Function
def main():
    print("=== INFOSYS Stock Price Predictor ===")
    user_date = get_user_date()

    # Step 1: Load and prepare data
    df = get_stock_data()

    # Step 2: Preprocessing
    #X, y, scaler, scaled_close = preprocess_data(df)
    X_train, X_val, y_train, y_val, scaler, scaled_close = preprocess_data(df)
    # Step 3: Build and train the model
    model = build_model((X_train.shape[1], 1))
    print("Training RNN model...")
    #history = model.fit(X, y, epochs=80, batch_size=32, validation_split=0.2, verbose=1)
    history = model.fit(X_train, y_train, epochs=80, batch_size=32, validation_data=(X_val, y_val), verbose=1)

    ####
    plot_training_loss(history)

    # Predict on training data to evaluate performance
    y_train_pred_scaled = model.predict(X_train, verbose=0)
    y_train_pred = scaler.inverse_transform(y_train_pred_scaled)
    y_true = scaler.inverse_transform(y_train.reshape(-1, 1))

    # Calculate metrics
    from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

    mae = mean_absolute_error(y_true, y_train_pred)
    mse = mean_squared_error(y_true, y_train_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_train_pred)

    # Print metrics
    print("\n📊 Training Set Performance Metrics:")
    print(f"📉 Mean Absolute Error (MAE) : ₹{mae:.2f}")
    print(f"📉 Mean Squared Error (MSE)  : ₹{mse:.2f}")
    print(f"📉 Root Mean Squared Error   : ₹{rmse:.2f}")
    print(f"📈 R² Score                  : {r2:.4f}")

    # Predict on validation set
    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_pred = scaler.inverse_transform(y_val_pred_scaled)
    y_val_true = scaler.inverse_transform(y_val.reshape(-1, 1))

    # Compute metrics
    from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

    mae_val = mean_absolute_error(y_val_true, y_val_pred)
    mse_val = mean_squared_error(y_val_true, y_val_pred)
    rmse_val = np.sqrt(mse_val)
    r2_val = r2_score(y_val_true, y_val_pred)

    print("\n📊 Validation Set Performance Metrics:")
    print(f"📉 Mean Absolute Error (MAE) : ₹{mae_val:.2f}")
    print(f"📉 Mean Squared Error (MSE)  : ₹{mse_val:.2f}")
    print(f"📉 Root Mean Squared Error   : ₹{rmse_val:.2f}")
    print(f"📈 R² Score                  : {r2_val:.4f}")

    # Step 4: Predict
    predicted_price, actual_price, date_used = predict_price(model, df, user_date, scaler, scaled_close)
    if predicted_price is not None: # Check if prediction was possible
        print(f"\n📅 Prediction for {date_used}:")
        print(f"🔮 Predicted Closing Price: ₹{predicted_price:.2f}")
        if actual_price is not None: # Check if actual price was found
            print(f"📈 Actual Closing Price   : ₹{actual_price}")
        else:
            print("⚠️ Actual price not available for this date.")

        # Step 5: Plot
        plot_results(df, date_used, predicted_price)
    else:
        print("❌ Unable to predict price due to insufficient data.")

if __name__ == "__main__":
    main()
# Out:
# === INFOSYS Stock Price Predictor ===
# Enter a date (YYYY-MM-DD): 2025-03-22
# Weekends are not trading days.
# Enter a date (YYYY-MM-DD): 2025-03-25
# [*********************100%***********************]  1 of 1 completed
# Fetching data from Yahoo Finance...
# Training RNN model...
# Epoch 1/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0244 - val_loss: 0.0094
# Epoch 2/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0021 - val_loss: 0.0054
# Epoch 3/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - val_loss: 0.0043
# Epoch 4/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - val_loss: 0.0041
# Epoch 5/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 6/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012 - val_loss: 0.0031
# Epoch 7/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - val_loss: 0.0027
# Epoch 8/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0010 - val_loss: 0.0024
# Epoch 9/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.3799e-04 - val_loss: 0.0020
# Epoch 10/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.8536e-04 - val_loss: 0.0018
# Epoch 11/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.4080e-04 - val_loss: 0.0016
# Epoch 12/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.0158e-04 - val_loss: 0.0014
# Epoch 13/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.6747e-04 - val_loss: 0.0013
# Epoch 14/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.3746e-04 - val_loss: 0.0012
# Epoch 15/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.1006e-04 - val_loss: 0.0011
# Epoch 16/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.8430e-04 - val_loss: 0.0010
# Epoch 17/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.5963e-04 - val_loss: 9.6826e-04
# Epoch 18/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.3595e-04 - val_loss: 9.2220e-04
# Epoch 19/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.1341e-04 - val_loss: 8.8305e-04
# Epoch 20/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.9217e-04 - val_loss: 8.4916e-04
# Epoch 21/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.7233e-04 - val_loss: 8.1938e-04
# Epoch 22/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.5392e-04 - val_loss: 7.9291e-04
# Epoch 23/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3692e-04 - val_loss: 7.6915e-04
# Epoch 24/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.2125e-04 - val_loss: 7.4765e-04
# Epoch 25/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.0686e-04 - val_loss: 7.2807e-04
# Epoch 26/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.9365e-04 - val_loss: 7.1011e-04
# Epoch 27/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.8156e-04 - val_loss: 6.9356e-04
# Epoch 28/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.7051e-04 - val_loss: 6.7826e-04
# Epoch 29/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.6040e-04 - val_loss: 6.6405e-04
# Epoch 30/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.5115e-04 - val_loss: 6.5084e-04
# Epoch 31/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.4266e-04 - val_loss: 6.3855e-04
# Epoch 32/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.3484e-04 - val_loss: 6.2710e-04
# Epoch 33/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2758e-04 - val_loss: 6.1645e-04
# Epoch 34/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.2081e-04 - val_loss: 6.0654e-04
# Epoch 35/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.1442e-04 - val_loss: 5.9733e-04
# Epoch 36/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.0836e-04 - val_loss: 5.8874e-04
# Epoch 37/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0257e-04 - val_loss: 5.8073e-04
# Epoch 38/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.9701e-04 - val_loss: 5.7325e-04
# Epoch 39/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.9164e-04 - val_loss: 5.6623e-04
# Epoch 40/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8645e-04 - val_loss: 5.5964e-04
# Epoch 41/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8141e-04 - val_loss: 5.5342e-04
# Epoch 42/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7652e-04 - val_loss: 5.4753e-04
# Epoch 43/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.7177e-04 - val_loss: 5.4194e-04
# Epoch 44/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.6715e-04 - val_loss: 5.3661e-04
# Epoch 45/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6267e-04 - val_loss: 5.3153e-04
# Epoch 46/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5831e-04 - val_loss: 5.2667e-04
# Epoch 47/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.5408e-04 - val_loss: 5.2200e-04
# Epoch 48/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4998e-04 - val_loss: 5.1751e-04
# Epoch 49/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.4600e-04 - val_loss: 5.1319e-04
# Epoch 50/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4214e-04 - val_loss: 5.0901e-04
# Epoch 51/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.3841e-04 - val_loss: 5.0498e-04
# Epoch 52/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3479e-04 - val_loss: 5.0107e-04
# Epoch 53/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.3129e-04 - val_loss: 4.9729e-04
# Epoch 54/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.2791e-04 - val_loss: 4.9363e-04
# Epoch 55/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.2464e-04 - val_loss: 4.9008e-04
# Epoch 56/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.2147e-04 - val_loss: 4.8664e-04
# Epoch 57/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1840e-04 - val_loss: 4.8332e-04
# Epoch 58/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1542e-04 - val_loss: 4.8010e-04
# Epoch 59/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1253e-04 - val_loss: 4.7700e-04
# Epoch 60/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.0972e-04 - val_loss: 4.7401e-04
# Epoch 61/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0699e-04 - val_loss: 4.7113e-04
# Epoch 62/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.0433e-04 - val_loss: 4.6836e-04
# Epoch 63/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0173e-04 - val_loss: 4.6570e-04
# Epoch 64/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.9920e-04 - val_loss: 4.6314e-04
# Epoch 65/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.9673e-04 - val_loss: 4.6070e-04
# Epoch 66/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9431e-04 - val_loss: 4.5836e-04
# Epoch 67/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.9196e-04 - val_loss: 4.5613e-04
# Epoch 68/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8966e-04 - val_loss: 4.5400e-04
# Epoch 69/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.8741e-04 - val_loss: 4.5198e-04
# Epoch 70/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.8522e-04 - val_loss: 4.5005e-04
# Epoch 71/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.8308e-04 - val_loss: 4.4823e-04
# Epoch 72/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.8100e-04 - val_loss: 4.4649e-04
# Epoch 73/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.7897e-04 - val_loss: 4.4486e-04
# Epoch 74/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.7699e-04 - val_loss: 4.4331e-04
# Epoch 75/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.7507e-04 - val_loss: 4.4186e-04
# Epoch 76/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.7319e-04 - val_loss: 4.4049e-04
# Epoch 77/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.7137e-04 - val_loss: 4.3920e-04
# Epoch 78/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.6959e-04 - val_loss: 4.3800e-04
# Epoch 79/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.6786e-04 - val_loss: 4.3688e-04
# Epoch 80/80
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6618e-04 - val_loss: 4.3584e-04
# 📊 Training Set Performance Metrics:
# 📉 Mean Absolute Error (MAE) : ₹17.47
# 📉 Mean Squared Error (MSE)  : ₹549.10
# 📉 Root Mean Squared Error   : ₹23.43
# 📈 R² Score                  : 0.9852
#
# 📊 Validation Set Performance Metrics:
# 📉 Mean Absolute Error (MAE) : ₹19.96
# 📉 Mean Squared Error (MSE)  : ₹806.69
# 📉 Root Mean Squared Error   : ₹28.40
# 📈 R² Score                  : 0.9678
#
# 📅 Prediction for 2025-03-25:
# 🔮 Predicted Closing Price: ₹1571.73
# 📈 Actual Closing Price   : ₹1605.8553466796875

# %%
#LSTM for 100 epochs
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LSTM

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Define constants
SYMBOL = "INFY.NS"
START_DATE = "2020-06-01"
END_DATE = "2025-05-31"
SEQUENCE_LENGTH = 60  # 60 days for input sequence

# Get Indian trading holidays
def get_nse_holidays():
    in_holidays = holidays.India(years=range(2020, 2026))
    return set(in_holidays.keys())

TRADING_HOLIDAYS = get_nse_holidays()

# Validate input date
def is_valid_date(date_str):
    try:
        date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
        if not (datetime.date(2020, 6, 1) <= date <= datetime.date(2025, 5, 31)):
            print("Date not in allowed range.")
            return False
        if date.weekday() >= 5:
            print("Weekends are not trading days.")
            return False
        if date in TRADING_HOLIDAYS:
            print("Entered date is a trading holiday.")
            return False
        return True
    except ValueError:
        print("Invalid date format. Use YYYY-MM-DD.")
        return False

# Prompt until valid date is entered
def get_user_date():
    while True:
        date_input = input("Enter a date (YYYY-MM-DD): ")
        if is_valid_date(date_input):
            return datetime.datetime.strptime(date_input, "%Y-%m-%d").date()

# Download historical stock data using yfinance
def get_stock_data():
    print("Fetching data from Yahoo Finance...")
    df = yf.download(SYMBOL, start=START_DATE, end=END_DATE)
    df = df[['Close']]
    df.dropna(inplace=True)
    df.index = pd.to_datetime(df.index)
    return df

# Preprocess: Normalize data and create sequences
def preprocess_data(df):
    scaler = MinMaxScaler()
    scaled_close = scaler.fit_transform(df[['Close']])

    X, y = [], []
    for i in range(SEQUENCE_LENGTH, len(scaled_close)):
        X.append(scaled_close[i - SEQUENCE_LENGTH:i])
        y.append(scaled_close[i])

    X = np.array(X)
    y = np.array(y)

    # Split into training and validation sets
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
    return X_train, X_val, y_train, y_val, scaler, scaled_close

# Build the SimpleRNN model
def build_model(input_shape):
    model = Sequential()
    #model.add(SimpleRNN(units=50, activation='tanh', input_shape=input_shape))
    model.add(LSTM(units=50, activation='tanh', input_shape=input_shape))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Predict closing price for the given date
def predict_price(model, df, user_date, scaler, scaled_close):
    all_dates = df.index.date
    # Convert user_date to datetime.date for consistent comparison
    user_date_dt = user_date

    # Find the closest trading day if the requested date is not a trading day
    if user_date_dt not in all_dates:
        print(f"No trading data on {user_date_dt}. Predicting for previous valid trading day.")
        try:
            # Find the latest trading day before user_date
            date_used = max([d for d in all_dates if d < user_date_dt])
        except ValueError:
            # No trading data before the user date
            print("No sufficient historical data available before the entered date.")
            return None, None, user_date_dt
    else:
        date_used = user_date_dt # Use the exact user date if it's a trading day

    try:
        # Get the index position for the date used for prediction
        idx = list(df.index.date).index(date_used)
    except ValueError:
        # Should not happen if date_used is from df.index.date, but added for robustness
        print(f"Error finding index for date {date_used}.")
        return None, None, user_date_dt

    if idx < SEQUENCE_LENGTH:
        print("Not enough historical data to make a prediction.")
        return None, None, date_used

    # Prepare input sequence
    input_seq = scaled_close[idx - SEQUENCE_LENGTH:idx]
    input_seq = np.reshape(input_seq, (1, SEQUENCE_LENGTH, 1))

    # Predict scaled price
    predicted_scaled = model.predict(input_seq, verbose=0)
    # Inverse transform to get the actual price
    predicted_price = scaler.inverse_transform(predicted_scaled)[0][0]

    # Get the actual price for the date used for prediction
    # Ensure we handle potential Series output from .loc
    actual_price_series = df.loc[df.index.date == date_used, 'Close']
    actual_price = float(actual_price_series.iloc[0]) if not actual_price_series.empty else None

    return predicted_price, actual_price, date_used

# Plot the result
def plot_results(df, predicted_date, predicted_price):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Historical Close Price',zorder=1)
    #plt.axvline(pd.to_datetime(predicted_date), color='red', linestyle='--', label='Predicted Date')
    plt.scatter(pd.to_datetime(predicted_date), predicted_price, color='orange', label='Predicted Price',zorder=2)
    plt.title("INFOSYS Stock Price with Prediction (yfinance)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#Plotting error with no. of epochs
def plot_training_loss(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title("Training and Validation Loss Over Epochs (LSTM)")
    plt.xlabel("Epoch no.")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Main Function
def main():
    print("=== INFOSYS Stock Price Predictor ===")
    user_date = get_user_date()

    # Step 1: Load and prepare data
    df = get_stock_data()

    # Step 2: Preprocessing
    #X, y, scaler, scaled_close = preprocess_data(df)
    X_train, X_val, y_train, y_val, scaler, scaled_close = preprocess_data(df)
    # Step 3: Build and train the model
    model = build_model((X_train.shape[1], 1))
    print("Training LSTM model...")
    #history = model.fit(X, y, epochs=80, batch_size=32, validation_split=0.2, verbose=1)
    history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val), verbose=1)

    ####
    plot_training_loss(history)

    # Predict on training data to evaluate performance
    y_train_pred_scaled = model.predict(X_train, verbose=0)
    y_train_pred = scaler.inverse_transform(y_train_pred_scaled)
    y_true = scaler.inverse_transform(y_train.reshape(-1, 1))

    # Calculate metrics
    from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

    mae = mean_absolute_error(y_true, y_train_pred)
    mse = mean_squared_error(y_true, y_train_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_train_pred)

    # Print metrics
    print("\n Training Set Performance Metrics (LSTM):")
    print(f" Mean Absolute Error (MAE) : ₹{mae:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse:.2f}")
    print(f" Root Mean Squared Error   : ₹{rmse:.2f}")
    print(f" R² Score                  : {r2:.4f}")

    # Predict on validation set
    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_pred = scaler.inverse_transform(y_val_pred_scaled)
    y_val_true = scaler.inverse_transform(y_val.reshape(-1, 1))

    # Compute metrics
    from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

    mae_val = mean_absolute_error(y_val_true, y_val_pred)
    mse_val = mean_squared_error(y_val_true, y_val_pred)
    rmse_val = np.sqrt(mse_val)
    r2_val = r2_score(y_val_true, y_val_pred)

    print("\n Validation Set Performance Metrics (LSTM):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_val:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_val:.2f}")
    print(f" Root Mean Squared Error   : ₹{rmse_val:.2f}")
    print(f" R² Score                  : {r2_val:.4f}")

    # Step 4: Predict
    predicted_price, actual_price, date_used = predict_price(model, df, user_date, scaler, scaled_close)
    if predicted_price is not None: # Check if prediction was possible
        print(f"\n Prediction for {date_used}:")
        print(f" Predicted Closing Price: ₹{predicted_price:.2f}")
        if actual_price is not None: # Check if actual price was found
            print(f" Actual Closing Price   : ₹{actual_price}")
        else:
            print(" Actual price not available for this date.")

        # Step 5: Plot
        plot_results(df, date_used, predicted_price)
    else:
        print("❌ Unable to predict price due to insufficient data.")

if __name__ == "__main__":
    main()
# Out:
# === INFOSYS Stock Price Predictor ===
# Enter a date (YYYY-MM-DD): 2025-05-26
# [*********************100%***********************]  1 of 1 completed
# Fetching data from Yahoo Finance...
# Training LSTM model...
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0952 - val_loss: 0.0145
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 9.9630e-04 - val_loss: 0.0019
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 9.5742e-04 - val_loss: 0.0018
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 9.3197e-04 - val_loss: 0.0017
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.1137e-04 - val_loss: 0.0017
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.9207e-04 - val_loss: 0.0016
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.7270e-04 - val_loss: 0.0016
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.5277e-04 - val_loss: 0.0015
# Epoch 13/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.3194e-04 - val_loss: 0.0015
# Epoch 14/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.0997e-04 - val_loss: 0.0014
# Epoch 15/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 7.8714e-04 - val_loss: 0.0014
# Epoch 16/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 7.6490e-04 - val_loss: 0.0014
# Epoch 17/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 7.4541e-04 - val_loss: 0.0013
# Epoch 18/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 7.2860e-04 - val_loss: 0.0013
# Epoch 19/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 7.1358e-04 - val_loss: 0.0013
# Epoch 20/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 7.0037e-04 - val_loss: 0.0013
# Epoch 21/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.8856e-04 - val_loss: 0.0012
# Epoch 22/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.7778e-04 - val_loss: 0.0012
# Epoch 23/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.6779e-04 - val_loss: 0.0012
# Epoch 24/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.5844e-04 - val_loss: 0.0012
# Epoch 25/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.4963e-04 - val_loss: 0.0012
# Epoch 26/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.4132e-04 - val_loss: 0.0012
# Epoch 27/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.3343e-04 - val_loss: 0.0011
# Epoch 28/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.2593e-04 - val_loss: 0.0011
# Epoch 29/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 6.1876e-04 - val_loss: 0.0011
# Epoch 30/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.1187e-04 - val_loss: 0.0011
# Epoch 31/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6.0522e-04 - val_loss: 0.0011
# Epoch 32/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.9878e-04 - val_loss: 0.0011
# Epoch 33/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.9254e-04 - val_loss: 0.0011
# Epoch 34/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.8648e-04 - val_loss: 0.0011
# Epoch 35/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.8062e-04 - val_loss: 0.0011
# Epoch 36/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.7497e-04 - val_loss: 0.0011
# Epoch 37/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 5.6956e-04 - val_loss: 0.0011
# Epoch 38/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.6440e-04 - val_loss: 0.0011
# Epoch 39/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.5948e-04 - val_loss: 0.0011
# Epoch 40/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 5.5478e-04 - val_loss: 0.0012
# Epoch 41/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 5.5028e-04 - val_loss: 0.0012
# Epoch 42/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.4594e-04 - val_loss: 0.0012
# Epoch 43/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.4172e-04 - val_loss: 0.0012
# Epoch 44/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.3760e-04 - val_loss: 0.0012
# Epoch 45/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.3356e-04 - val_loss: 0.0012
# Epoch 46/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 5.2959e-04 - val_loss: 0.0012
# Epoch 47/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.2568e-04 - val_loss: 0.0012
# Epoch 48/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.2181e-04 - val_loss: 0.0011
# Epoch 49/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.1799e-04 - val_loss: 0.0011
# Epoch 50/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.1421e-04 - val_loss: 0.0011
# Epoch 51/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.1046e-04 - val_loss: 0.0011
# Epoch 52/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 5.0674e-04 - val_loss: 0.0011
# Epoch 53/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.0305e-04 - val_loss: 0.0011
# Epoch 54/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.9939e-04 - val_loss: 0.0011
# Epoch 55/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.9575e-04 - val_loss: 0.0011
# Epoch 56/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.9214e-04 - val_loss: 0.0011
# Epoch 57/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.8854e-04 - val_loss: 0.0011
# Epoch 58/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.8496e-04 - val_loss: 0.0011
# Epoch 59/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.8140e-04 - val_loss: 0.0011
# Epoch 60/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.7785e-04 - val_loss: 0.0011
# Epoch 61/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.7431e-04 - val_loss: 0.0011
# Epoch 62/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.7078e-04 - val_loss: 0.0011
# Epoch 63/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.6726e-04 - val_loss: 0.0010
# Epoch 64/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 4.6375e-04 - val_loss: 0.0010
# Epoch 65/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.6024e-04 - val_loss: 0.0010
# Epoch 66/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.5674e-04 - val_loss: 0.0010
# Epoch 67/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.5324e-04 - val_loss: 0.0010
# Epoch 68/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.4975e-04 - val_loss: 0.0010
# Epoch 69/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.4627e-04 - val_loss: 9.9898e-04
# Epoch 70/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.4280e-04 - val_loss: 9.9014e-04
# Epoch 71/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.3934e-04 - val_loss: 9.8123e-04
# Epoch 72/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.3589e-04 - val_loss: 9.7227e-04
# Epoch 73/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.3245e-04 - val_loss: 9.6327e-04
# Epoch 74/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.2902e-04 - val_loss: 9.5426e-04
# Epoch 75/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.2560e-04 - val_loss: 9.4525e-04
# Epoch 76/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.2220e-04 - val_loss: 9.3625e-04
# Epoch 77/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.1882e-04 - val_loss: 9.2727e-04
# Epoch 78/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.1545e-04 - val_loss: 9.1833e-04
# Epoch 79/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.1210e-04 - val_loss: 9.0943e-04
# Epoch 80/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.0876e-04 - val_loss: 9.0058e-04
# Epoch 81/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.0544e-04 - val_loss: 8.9179e-04
# Epoch 82/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.0214e-04 - val_loss: 8.8305e-04
# Epoch 83/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.9885e-04 - val_loss: 8.7438e-04
# Epoch 84/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.9558e-04 - val_loss: 8.6578e-04
# Epoch 85/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.9234e-04 - val_loss: 8.5725e-04
# Epoch 86/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.8911e-04 - val_loss: 8.4879e-04
# Epoch 87/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 3.8590e-04 - val_loss: 8.4041e-04
# Epoch 88/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 3.8272e-04 - val_loss: 8.3210e-04
# Epoch 89/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.7955e-04 - val_loss: 8.2388e-04
# Epoch 90/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.7641e-04 - val_loss: 8.1573e-04
# Epoch 91/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.7329e-04 - val_loss: 8.0766e-04
# Epoch 92/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.7020e-04 - val_loss: 7.9967e-04
# Epoch 93/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.6713e-04 - val_loss: 7.9177e-04
# Epoch 94/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.6409e-04 - val_loss: 7.8395e-04
# Epoch 95/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.6107e-04 - val_loss: 7.7622e-04
# Epoch 96/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.5809e-04 - val_loss: 7.6857e-04
# Epoch 97/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.5514e-04 - val_loss: 7.6101e-04
# Epoch 98/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.5222e-04 - val_loss: 7.5354e-04
# Epoch 99/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 3.4933e-04 - val_loss: 7.4616e-04
# Epoch 100/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.4648e-04 - val_loss: 7.3887e-04
#  Training Set Performance Metrics (LSTM):
#  Mean Absolute Error (MAE) : ₹18.99
#  Mean Squared Error (MSE)  : ₹659.01
#  Root Mean Squared Error   : ₹25.67
#  R² Score                  : 0.9823
#
#  Validation Set Performance Metrics (LSTM):
#  Mean Absolute Error (MAE) : ₹30.08
#  Mean Squared Error (MSE)  : ₹1367.59
#  Root Mean Squared Error   : ₹36.98
#  R² Score                  : 0.9454
#
#  Prediction for 2025-05-26:
#  Predicted Closing Price: ₹1527.73
#  Actual Closing Price   : ₹1558.5706787109375

# %%
#SimpleRNN for 100 epochs
# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Define constants
SYMBOL = "INFY.NS"
START_DATE = "2020-06-01"
END_DATE = "2025-05-31"
SEQUENCE_LENGTH = 60  # 60 days for input sequence

# Get Indian trading holidays
def get_nse_holidays():
    in_holidays = holidays.India(years=range(2020, 2026))
    return set(in_holidays.keys())

TRADING_HOLIDAYS = get_nse_holidays()

# Validate input date
def is_valid_date(date_str):
    try:
        date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
        if not (datetime.date(2020, 6, 1) <= date <= datetime.date(2025, 5, 31)):
            print("Date not in allowed range.")
            return False
        if date.weekday() >= 5:
            print("Weekends are not trading days.")
            return False
        if date in TRADING_HOLIDAYS:
            print("Entered date is a trading holiday.")
            return False
        return True
    except ValueError:
        print("Invalid date format. Use YYYY-MM-DD.")
        return False

# Prompt until valid date is entered
def get_user_date():
    while True:
        date_input = input("Enter a date (YYYY-MM-DD): ")
        if is_valid_date(date_input):
            return datetime.datetime.strptime(date_input, "%Y-%m-%d").date()

# Download historical stock data using yfinance
def get_stock_data():
    print("Fetching data from Yahoo Finance...")
    df = yf.download(SYMBOL, start=START_DATE, end=END_DATE)
    df = df[['Close']]
    df.dropna(inplace=True)
    df.index = pd.to_datetime(df.index)
    return df

# Preprocess: Normalize data and create sequences
def preprocess_data(df):
    scaler = MinMaxScaler()
    scaled_close = scaler.fit_transform(df[['Close']])

    X, y = [], []
    for i in range(SEQUENCE_LENGTH, len(scaled_close)):
        X.append(scaled_close[i - SEQUENCE_LENGTH:i])
        y.append(scaled_close[i])

    X = np.array(X)
    y = np.array(y)

    # Split into training and validation sets
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, shuffle=False)
    return X_train, X_val, y_train, y_val, scaler, scaled_close

# Build the SimpleRNN model
def build_model(input_shape):
    model = Sequential()
    model.add(SimpleRNN(units=50, activation='tanh', input_shape=input_shape))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Predict closing price for the given date
def predict_price(model, df, user_date, scaler, scaled_close):
    all_dates = df.index.date
    # Convert user_date to datetime.date for consistent comparison
    user_date_dt = user_date

    # Find the closest trading day if the requested date is not a trading day
    if user_date_dt not in all_dates:
        print(f"No trading data on {user_date_dt}. Predicting for previous valid trading day.")
        try:
            # Find the latest trading day before user_date
            date_used = max([d for d in all_dates if d < user_date_dt])
        except ValueError:
            # No trading data before the user date
            print("No sufficient historical data available before the entered date.")
            return None, None, user_date_dt
    else:
        date_used = user_date_dt # Use the exact user date if it's a trading day

    try:
        # Get the index position for the date used for prediction
        idx = list(df.index.date).index(date_used)
    except ValueError:
        # Should not happen if date_used is from df.index.date, but added for robustness
        print(f"Error finding index for date {date_used}.")
        return None, None, user_date_dt

    if idx < SEQUENCE_LENGTH:
        print("Not enough historical data to make a prediction.")
        return None, None, date_used

    # Prepare input sequence
    input_seq = scaled_close[idx - SEQUENCE_LENGTH:idx]
    input_seq = np.reshape(input_seq, (1, SEQUENCE_LENGTH, 1))

    # Predict scaled price
    predicted_scaled = model.predict(input_seq, verbose=0)
    # Inverse transform to get the actual price
    predicted_price = scaler.inverse_transform(predicted_scaled)[0][0]

    # Get the actual price for the date used for prediction
    # Ensure we handle potential Series output from .loc
    actual_price_series = df.loc[df.index.date == date_used, 'Close']
    actual_price = float(actual_price_series.iloc[0]) if not actual_price_series.empty else None

    return predicted_price, actual_price, date_used

# Plot the result
def plot_results(df, predicted_date, predicted_price):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Historical Close Price',zorder=1)
    #plt.axvline(pd.to_datetime(predicted_date), color='red', linestyle='--', label='Predicted Date')
    plt.scatter(pd.to_datetime(predicted_date), predicted_price, color='orange', label='Predicted Price',zorder=2)
    plt.title("INFOSYS Stock Price with Prediction (yfinance)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#Plotting error with no. of epochs
def plot_training_loss(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title("Training and Validation Loss Over Epochs (SimpleRNN)")
    plt.xlabel("Epoch no.")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Main Function
def main():
    print("=== INFOSYS Stock Price Predictor ===")
    user_date = get_user_date()

    # Step 1: Load and prepare data
    df = get_stock_data()

    # Step 2: Preprocessing
    #X, y, scaler, scaled_close = preprocess_data(df)
    X_train, X_val, y_train, y_val, scaler, scaled_close = preprocess_data(df)

    # Step 3: Build and train the model
    model = build_model((X_train.shape[1], 1))
    print("Training RNN model...")
    #history = model.fit(X, y, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
    history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val), verbose=1)

    ####
    plot_training_loss(history)

    # Predict on training data to evaluate performance
    y_train_pred_scaled = model.predict(X_train, verbose=0)
    y_train_pred = scaler.inverse_transform(y_train_pred_scaled)
    y_true = scaler.inverse_transform(y_train.reshape(-1, 1))

    from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

    # Calculate metrics
    mae = mean_absolute_error(y_true, y_train_pred)
    mse = mean_squared_error(y_true, y_train_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_train_pred)

    # Print metrics
    print("\n Training Set Performance Metrics (SimpleRNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse:.2f}")
    print(f" Root Mean Squared Error   : ₹{rmse:.2f}")
    print(f" R² Score                  : {r2:.4f}")

    # Predict on validation set
    y_val_pred_scaled = model.predict(X_val, verbose=0)
    y_val_pred = scaler.inverse_transform(y_val_pred_scaled)
    y_val_true = scaler.inverse_transform(y_val.reshape(-1, 1))

    # Compute metrics
    from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

    mae_val = mean_absolute_error(y_val_true, y_val_pred)
    mse_val = mean_squared_error(y_val_true, y_val_pred)
    rmse_val = np.sqrt(mse_val)
    r2_val = r2_score(y_val_true, y_val_pred)

    print("\n Validation Set Performance Metrics (SimpleRNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_val:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_val:.2f}")
    print(f" Root Mean Squared Error   : ₹{rmse_val:.2f}")
    print(f" R² Score                  : {r2_val:.4f}")

    # Step 4: Predict
    predicted_price, actual_price, date_used = predict_price(model, df, user_date, scaler, scaled_close)
    if predicted_price is not None: # Check if prediction was possible
        print(f"\n Prediction for {date_used}:")
        print(f" Predicted Closing Price: ₹{predicted_price:.2f}")
        if actual_price is not None: # Check if actual price was found
            print(f" Actual Closing Price   : ₹{actual_price}")
        else:
            print("Actual price not available for this date.")

        # Step 5: Plot
        plot_results(df, date_used, predicted_price)
    else:
        print("❌ Unable to predict price due to insufficient data.")

if __name__ == "__main__":
    main()
# Out:
# === INFOSYS Stock Price Predictor ===
# Enter a date (YYYY-MM-DD): 2025-05-26
# [*********************100%***********************]  1 of 1 completed
# Fetching data from Yahoo Finance...
# Training RNN model...
# Epoch 1/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.3524 - val_loss: 0.0173
# Epoch 2/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0069 - val_loss: 0.0052
# Epoch 3/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0030 - val_loss: 0.0039
# Epoch 4/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 5/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 6/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 7/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 8/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 9/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 10/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 11/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 12/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 13/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 14/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 15/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 16/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 17/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 18/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 19/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 20/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 21/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 22/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 23/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.9642e-04 - val_loss: 0.0012
# Epoch 24/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.6358e-04 - val_loss: 0.0012
# Epoch 25/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.3268e-04 - val_loss: 0.0012
# Epoch 26/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.0397e-04 - val_loss: 0.0011
# Epoch 27/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.7760e-04 - val_loss: 0.0011
# Epoch 28/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.5357e-04 - val_loss: 0.0011
# Epoch 29/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.3170e-04 - val_loss: 0.0011
# Epoch 30/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.1176e-04 - val_loss: 0.0010
# Epoch 31/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.9349e-04 - val_loss: 0.0010
# Epoch 32/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.7663e-04 - val_loss: 0.0010
# Epoch 33/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.6099e-04 - val_loss: 9.8677e-04
# Epoch 34/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.4637e-04 - val_loss: 9.6892e-04
# Epoch 35/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.3264e-04 - val_loss: 9.5169e-04
# Epoch 36/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.1965e-04 - val_loss: 9.3504e-04
# Epoch 37/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.0729e-04 - val_loss: 9.1891e-04
# Epoch 38/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.9546e-04 - val_loss: 9.0330e-04
# Epoch 39/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.8409e-04 - val_loss: 8.8821e-04
# Epoch 40/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.7309e-04 - val_loss: 8.7366e-04
# Epoch 41/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.6242e-04 - val_loss: 8.5970e-04
# Epoch 42/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.5205e-04 - val_loss: 8.4635e-04
# Epoch 43/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.4195e-04 - val_loss: 8.3365e-04
# Epoch 44/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.3211e-04 - val_loss: 8.2165e-04
# Epoch 45/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.2255e-04 - val_loss: 8.1036e-04
# Epoch 46/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.1326e-04 - val_loss: 7.9978e-04
# Epoch 47/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.0427e-04 - val_loss: 7.8994e-04
# Epoch 48/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.9560e-04 - val_loss: 7.8080e-04
# Epoch 49/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.8725e-04 - val_loss: 7.7235e-04
# Epoch 50/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.7924e-04 - val_loss: 7.6455e-04
# Epoch 51/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.7157e-04 - val_loss: 7.5735e-04
# Epoch 52/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.6424e-04 - val_loss: 7.5071e-04
# Epoch 53/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.5723e-04 - val_loss: 7.4455e-04
# Epoch 54/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.5053e-04 - val_loss: 7.3883e-04
# Epoch 55/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.4412e-04 - val_loss: 7.3349e-04
# Epoch 56/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.3798e-04 - val_loss: 7.2847e-04
# Epoch 57/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.3208e-04 - val_loss: 7.2372e-04
# Epoch 58/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.2640e-04 - val_loss: 7.1921e-04
# Epoch 59/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2092e-04 - val_loss: 7.1489e-04
# Epoch 60/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1561e-04 - val_loss: 7.1074e-04
# Epoch 61/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1045e-04 - val_loss: 7.0673e-04
# Epoch 62/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.0544e-04 - val_loss: 7.0285e-04
# Epoch 63/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.0056e-04 - val_loss: 6.9908e-04
# Epoch 64/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.9580e-04 - val_loss: 6.9542e-04
# Epoch 65/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.9114e-04 - val_loss: 6.9184e-04
# Epoch 66/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.8658e-04 - val_loss: 6.8835e-04
# Epoch 67/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.8211e-04 - val_loss: 6.8494e-04
# Epoch 68/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.7773e-04 - val_loss: 6.8160e-04
# Epoch 69/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.7343e-04 - val_loss: 6.7832e-04
# Epoch 70/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.6921e-04 - val_loss: 6.7509e-04
# Epoch 71/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6506e-04 - val_loss: 6.7190e-04
# Epoch 72/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6097e-04 - val_loss: 6.6875e-04
# Epoch 73/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.5695e-04 - val_loss: 6.6562e-04
# Epoch 74/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5297e-04 - val_loss: 6.6250e-04
# Epoch 75/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.4905e-04 - val_loss: 6.5936e-04
# Epoch 76/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.4517e-04 - val_loss: 6.5621e-04
# Epoch 77/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.4132e-04 - val_loss: 6.5304e-04
# Epoch 78/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.3751e-04 - val_loss: 6.4983e-04
# Epoch 79/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.3373e-04 - val_loss: 6.4657e-04
# Epoch 80/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.2998e-04 - val_loss: 6.4325e-04
# Epoch 81/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2625e-04 - val_loss: 6.3988e-04
# Epoch 82/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2254e-04 - val_loss: 6.3644e-04
# Epoch 83/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.1885e-04 - val_loss: 6.3292e-04
# Epoch 84/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.1519e-04 - val_loss: 6.2931e-04
# Epoch 85/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.1154e-04 - val_loss: 6.2561e-04
# Epoch 86/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0792e-04 - val_loss: 6.2181e-04
# Epoch 87/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.0431e-04 - val_loss: 6.1789e-04
# Epoch 88/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.0073e-04 - val_loss: 6.1385e-04
# Epoch 89/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9716e-04 - val_loss: 6.0967e-04
# Epoch 90/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9362e-04 - val_loss: 6.0534e-04
# Epoch 91/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.9009e-04 - val_loss: 6.0084e-04
# Epoch 92/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8659e-04 - val_loss: 5.9616e-04
# Epoch 93/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.8310e-04 - val_loss: 5.9128e-04
# Epoch 94/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.7964e-04 - val_loss: 5.8619e-04
# Epoch 95/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7620e-04 - val_loss: 5.8087e-04
# Epoch 96/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.7277e-04 - val_loss: 5.7533e-04
# Epoch 97/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.6937e-04 - val_loss: 5.6956e-04
# Epoch 98/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.6600e-04 - val_loss: 5.6357e-04
# Epoch 99/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.6266e-04 - val_loss: 5.5739e-04
# Epoch 100/100
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5935e-04 - val_loss: 5.5104e-04
#  Training Set Performance Metrics (SimpleRNN):
#  Mean Absolute Error (MAE) : ₹17.86
#  Mean Squared Error (MSE)  : ₹598.39
#  Root Mean Squared Error   : ₹24.46
#  R² Score                  : 0.9884
#
#  Validation Set Performance Metrics (SimpleRNN):
#  Mean Absolute Error (MAE) : ₹22.79
#  Mean Squared Error (MSE)  : ₹1019.93
#  Root Mean Squared Error   : ₹31.94
#  R² Score                  : 0.9692
#
#  Prediction for 2025-05-26:
#  Predicted Closing Price: ₹1546.90
#  Actual Closing Price   : ₹1558.5706787109375
