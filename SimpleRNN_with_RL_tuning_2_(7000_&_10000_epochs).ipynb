# %% [markdown]
# <a href="https://colab.research.google.com/github/adityabaidya7/INFY_StockPricePrediction/blob/main/SimpleRNN_with_RL_tuning_2_(7000_%26_10000_epochs).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **7000 epochs**

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import SimpleRNN
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from matplotlib.dates import DateFormatter
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import numpy as np
import pandas as pd
import datetime
import holidays
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import warnings

warnings.filterwarnings('ignore')

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

SYMBOL = "INFY.NS"
SEQUENCE_LENGTH = 60

TRAIN_START_DATE = "2020-06-01"
TRAIN_END_DATE = "2025-05-31"

TEST_START_DATE = "2025-06-01"
TEST_END_DATE = "2025-07-01"

# Get Indian trading holidays
def get_nse_holidays():
    in_holidays = holidays.India(years=range(2020, 2026))
    return set(in_holidays.keys())

TRADING_HOLIDAYS = get_nse_holidays()

def is_valid_date(date_str):
    try:
        date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
        if not (datetime.date(2025, 6, 1) <= date <= datetime.date(2025, 7, 1)):
            print("Date must be between 2025-06-01 and 2025-07-01.")
            return False
        if date.weekday() >= 5:
            print("Weekends are not trading days.")
            return False
        if date in TRADING_HOLIDAYS:
            print("Entered date is a trading holiday.")
            return False
        return True
    except ValueError:
        print("Invalid date format. Use YYYY-MM-DD.")
        return False

def get_stock_data():
    print("Fetching data from Yahoo Finance...")
    full_df = yf.download(SYMBOL, start=TRAIN_START_DATE, end=TEST_END_DATE)
    full_df = full_df[['Close']]
    full_df.dropna(inplace=True)
    full_df.index = pd.to_datetime(full_df.index)

    train_df = full_df.loc[TRAIN_START_DATE:TRAIN_END_DATE]
    test_df = full_df.loc[TEST_START_DATE:TEST_END_DATE]
    return train_df, test_df, full_df

# Prompt until valid date is entered
def get_user_date():
    while True:
        date_input = input("Enter a date (YYYY-MM-DD): ")
        if is_valid_date(date_input):
            return datetime.datetime.strptime(date_input, "%Y-%m-%d").date()

# Build the SimpleRNN model
def build_model(input_shape, learning_rate=0.001): # Added learning_rate parameter
    model = Sequential()
    model.add(SimpleRNN(units=50, activation='tanh', input_shape=input_shape))
    model.add(Dense(1))
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate) # Use custom learning rate
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# Reinforcement Learning Fine-Tuning
class RLAgent:
    """
    A simple RL Agent to fine-tune the RNN model.
    The "environment" is the time series data, and the "action" is the prediction.
    The reward is based on prediction accuracy.
    """
    def __init__(self, model, learning_rate=0.001):
        self.model = model
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate) # Pass learning_rate to RLAgent

    @tf.function
    def train_step(self, state, target):
        """
        Performs a single training step to fine-tune the model weights.
        """
        with tf.GradientTape() as tape:
            prediction = self.model(state, training=True)
            # Use Mean Squared Error directly as the loss to minimize
            loss = tf.reduce_mean(tf.square(tf.cast(target, tf.float32) - prediction))

        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss # Return the mean loss for the batch


def fine_tune_with_rl(model, X_train, y_train, epochs=5, learning_rate=0.001, batch_size=32):
    """
    Fine- tunes the pre-trained RNN model using a simple reinforcement learning loop with batched data.
    """
    print("\n--- Starting Reinforcement Learning Fine-Tuning (Batched) ---")
    agent = RLAgent(model, learning_rate=learning_rate)

    # Create a TensorFlow Dataset and batch it
    dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    dataset = dataset.batch(batch_size)

    num_batches = tf.data.experimental.cardinality(dataset).numpy()

    for epoch in range(epochs):
        total_loss = 0
        batch_count = 0
        for batch_x, batch_y in dataset:
            # Ensure batch_x has the correct shape (batch_size, sequence_length, 1)
            batch_x_reshaped = tf.reshape(batch_x, (tf.shape(batch_x)[0], tf.shape(batch_x)[1], 1))
            loss = agent.train_step(batch_x_reshaped, batch_y)
            total_loss += loss.numpy() # Sum up the mean loss for each batch
            batch_count += 1

        # Calculate average loss per epoch
        average_epoch_loss = total_loss / num_batches if num_batches > 0 else 0
        print(f"RL Epoch {epoch + 1}/{epochs}, Average Loss per Batch: {average_epoch_loss:.6f}") # Print average loss

    print("--- RL Fine-Tuning Complete ---")
    return model


def create_test_sequences(train_df, test_df, scaler):
    combined = pd.concat([train_df, test_df])
    scaled = scaler.transform(combined[['Close']])
    X_test = []
    test_dates = test_df.index.date

    for i in range(len(train_df), len(combined)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled[i - SEQUENCE_LENGTH:i]
        X_test.append(seq)

    X_test = np.array(X_test)
    return X_test, test_dates

def predict_price_on_test(model, full_df, scaler, user_date):
    all_dates = full_df.index.date
    try:
        idx = list(all_dates).index(user_date)
    except ValueError:
        print("User date not found in data.")
        return None, None, user_date

    if idx < SEQUENCE_LENGTH:
        print("Not enough data to predict for this date.")
        return None, None, user_date

    input_seq = scaler.transform(full_df[['Close']].values)[idx - SEQUENCE_LENGTH:idx]
    input_seq = np.reshape(input_seq, (1, SEQUENCE_LENGTH, 1))

    predicted_scaled = model.predict(input_seq, verbose=0)
    predicted_price = scaler.inverse_transform(predicted_scaled)[0][0]

    actual_price = float(full_df.iloc[idx]['Close']) if idx < len(full_df) else None
    return predicted_price, actual_price, full_df.index[idx].date()

# Plot the result
def plot_results(df, predicted_date, predicted_price, actual_price):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Historical Close Price',zorder=1)
    #plt.axvline(pd.to_datetime(predicted_date), color='red', linestyle='--', label='Predicted Date')
    plt.scatter(pd.to_datetime(predicted_date), predicted_price, color='orange', label='Predicted Price',zorder=2)
    if actual_price is not None:
        plt.scatter(pd.to_datetime(predicted_date), actual_price, color='green', label='Actual Price',zorder=3, s=100)
    plt.title("INFOSYS Stock Price with Prediction (yfinance)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#Plotting error with no. of epochs
def plot_training_loss(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title("Training and Validation Loss Over Epochs (RNN)")
    plt.xlabel("Epoch no.")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def main():
    print("=== INFOSYS LSTM Stock Price Predictor (Test Phase June–July 2025) ===")
    user_date = get_user_date()

    # Step 1: Get stock data
    train_df, test_df, full_df = get_stock_data()

    # Step 2: Preprocess
    scaler = MinMaxScaler()
    scaled_train = scaler.fit_transform(train_df[['Close']])
    X, y = [], []
    for i in range(SEQUENCE_LENGTH, len(scaled_train)):
        X.append(scaled_train[i - SEQUENCE_LENGTH:i])
        y.append(scaled_train[i])
    X = np.array(X)
    y = np.array(y)

    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
    #early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    # Step 3: Build and train model
    model = build_model((X_train.shape[1], 1), learning_rate=0.0005) # Reduced Adam learning rate
    print("Training RNN model...")
    history = model.fit(X_train, y_train, epochs=7000, batch_size=64, validation_data=(X_val, y_val), verbose = 1) #callbacks = [early_stop], verbose=1)

    #print(f"\nBest weights restored from epoch: {early_stop.best_epoch + 1}")

    # Step 4: Plot training loss
    plot_training_loss(history)

    # Step 5: Fine-tune with Reinforcement Learning
    rl_tuned_model = fine_tune_with_rl(model, X_train, y_train, epochs=150, learning_rate=0.0001, batch_size=32)

    # Predict on training data to evaluate performance
    y_train_pred_scaled = rl_tuned_model.predict(X_train, verbose=0)
    y_train_pred = scaler.inverse_transform(y_train_pred_scaled)
    y_true_train = scaler.inverse_transform(y_train.reshape(-1, 1))

    # Calculate and print training metrics
    mae_train = mean_absolute_error(y_true_train, y_train_pred)
    mse_train = mean_squared_error(y_true_train, y_train_pred)
    rmse_train = np.sqrt(mse_train)
    r2_train = r2_score(y_true_train, y_train_pred)
    mape_train = mean_absolute_percentage_error(y_true_train, y_train_pred) * 100
    accuracy_train = 100 - mape_train
    mse_percent_train = (mse_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    mae_percent_train = (mae_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    print("\n Training Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_train:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_train:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_train:.2f}")
    print(f" R² Score                  : {r2_train:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_train:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_train:.2f}%")
    print(f" MSE Percentage of Average Price : {mse_percent_train:.2f}%")
    print(f" MAE Percentage of Average Price : {mae_percent_train:.2f}%")

    # Predict on validation set
    y_val_pred_scaled = rl_tuned_model.predict(X_val, verbose=0)
    y_val_pred = scaler.inverse_transform(y_val_pred_scaled)
    y_val_true = scaler.inverse_transform(y_val.reshape(-1, 1))

    # Calculate and print validation metrics
    mae_val = mean_absolute_error(y_val_true, y_val_pred)
    mse_val = mean_squared_error(y_val_true, y_val_pred)
    rmse_val = np.sqrt(mse_val)
    r2_val = r2_score(y_val_true, y_val_pred)
    mape_val = mean_absolute_percentage_error(y_val_true, y_val_pred) * 100
    accuracy_val = 100 - mape_val
    mse_percent_val = (mse_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    mae_percent_val = (mae_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    print("\n Validation Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_val:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_val:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_val:.2f}")
    print(f" R² Score                  : {r2_val:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_val:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_val:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_val:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_val:.2f}%")


    # Step 6: Predict for user-input test date
    predicted_price, actual_price, predicted_date = predict_price_on_test(rl_tuned_model, full_df, scaler, user_date)
    if predicted_price is not None:
        print(f"\n Prediction for {predicted_date}:")
        print(f" Predicted Closing Price: ₹{predicted_price:.2f}")
        if actual_price is not None:
            print(f" Actual Closing Price   : ₹{actual_price}")
        else:
            print("Actual price not available.")

        plot_results(full_df, predicted_date, predicted_price, actual_price)
    else:
        print("❌ Unable to make prediction.")

    # === Step 7: Predict all test dates and compare ===

    # Reuse combined full_df
    combined_df = pd.concat([train_df, test_df])
    scaled_combined = scaler.transform(combined_df[['Close']])

    X_test_all = []
    test_date_indexes = []

    for i in range(len(train_df), len(combined_df)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled_combined[i - SEQUENCE_LENGTH:i]
        X_test_all.append(seq)
        test_date_indexes.append(combined_df.index[i])

    X_test_all = np.array(X_test_all)

    # Predict on test sequences
    y_test_pred_scaled = rl_tuned_model.predict(X_test_all, verbose=0)
    y_test_pred = scaler.inverse_transform(y_test_pred_scaled)

    # Actual prices
    y_test_true = test_df.loc[test_date_indexes, 'Close'].values

    # Calculate and print test metrics
    mae_test = mean_absolute_error(y_test_true, y_test_pred)
    mse_test = mean_squared_error(y_test_true, y_test_pred)
    rmse_test = np.sqrt(mse_test)
    r2_test = r2_score(y_test_true, y_test_pred)
    mape_test = mean_absolute_percentage_error(y_test_true, y_test_pred) * 100
    accuracy_test = 100 - mape_test
    mse_percent_test = (mse_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    mae_percent_test = (mae_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    print("\n Test Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_test:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_test:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_test:.2f}")
    print(f" R² Score                  : {r2_test:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_test:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_test:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_test:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_test:.2f}%")

    # Plot actual vs predicted
    plt.figure(figsize=(12, 6))
    plt.plot(test_date_indexes, y_test_true, label='Actual Price')
    plt.plot(test_date_indexes, y_test_pred, label='Predicted Price')
    plt.title("Actual vs Predicted INFY Closing Prices (01-Jun to 01-Jul 2025)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.xticks(rotation=45)
    plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# === INFOSYS LSTM Stock Price Predictor (Test Phase June–July 2025) ===
# Fetching data from Yahoo Finance...
# [*********************100%***********************]  1 of 1 completed
# Streaming output truncated to the last 5000 lines.
# Epoch 4501/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1542e-04 - val_loss: 0.0027
# Epoch 4502/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.0831e-04 - val_loss: 0.0018
# Epoch 4503/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.8271e-05 - val_loss: 0.0019
# Epoch 4504/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.0338e-04 - val_loss: 0.0021
# Epoch 4505/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.0016e-04 - val_loss: 0.0021
# Epoch 4506/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.0606e-04 - val_loss: 0.0020
# Epoch 4507/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.1072e-04 - val_loss: 0.0021
# Epoch 4508/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.0730e-04 - val_loss: 0.0018
# Epoch 4509/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.1031e-04 - val_loss: 0.0019
# Epoch 4510/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.0871e-04 - val_loss: 0.0022
# Epoch 4511/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.3551e-05 - val_loss: 0.0016
# Epoch 4512/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 9.4693e-05 - val_loss: 0.0019
# Epoch 4513/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 9.4696e-05 - val_loss: 0.0023
# Epoch 4514/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.0264e-04 - val_loss: 0.0019
# Epoch 4515/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.4469e-05 - val_loss: 0.0021
# Epoch 4516/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.5889e-05 - val_loss: 0.0018
# Epoch 4517/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.4738e-05 - val_loss: 0.0019
# Epoch 4518/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.5257e-05 - val_loss: 0.0018
# Epoch 4519/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.6684e-05 - val_loss: 0.0020
# Epoch 4520/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.9989e-05 - val_loss: 0.0018
# Epoch 4521/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 8.4622e-05 - val_loss: 0.0018
# Epoch 4522/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 8.2317e-05 - val_loss: 0.0020
# Epoch 4523/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.3111e-05 - val_loss: 0.0018
# Epoch 4524/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 8.3274e-05 - val_loss: 0.0022
# Epoch 4525/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8.7411e-05 - val_loss: 0.0018
# Epoch 4526/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.5810e-05 - val_loss: 0.0018
# Epoch 4527/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.6623e-05 - val_loss: 0.0016
# Epoch 4528/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 9.1666e-05 - val_loss: 0.0018
# Epoch 4529/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.0127e-04 - val_loss: 0.0017
# Epoch 4530/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.1696e-05 - val_loss: 0.0019
# Epoch 4531/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 8.5639e-05 - val_loss: 0.0019
# Epoch 4532/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 7.2896e-05 - val_loss: 0.0017
# Epoch 4533/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 7.6636e-05 - val_loss: 0.0020
# Epoch 4534/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 7.2468e-05 - val_loss: 0.0018
# Epoch 4535/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 7.1097e-05 - val_loss: 0.0016
# Epoch 4536/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 7.7455e-05 - val_loss: 0.0018
# Epoch 4537/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.9692e-05 - val_loss: 0.0019
# Epoch 4538/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 7.6683e-05 - val_loss: 0.0017
# Epoch 4539/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.4063e-05 - val_loss: 0.0018
# Epoch 4540/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.3813e-05 - val_loss: 0.0020
# Epoch 4541/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 7.5965e-05 - val_loss: 0.0019
# Epoch 4542/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 7.8077e-05 - val_loss: 0.0018
# Epoch 4543/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.6109e-05 - val_loss: 0.0020
# Epoch 4544/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.1559e-05 - val_loss: 0.0021
# Epoch 4545/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.4924e-05 - val_loss: 0.0020
# Epoch 4546/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.5743e-05 - val_loss: 0.0016
# Epoch 4547/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 7.4897e-05 - val_loss: 0.0017
# Epoch 4548/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.1453e-05 - val_loss: 0.0016
# Epoch 4549/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 7.3093e-05 - val_loss: 0.0016
# Epoch 4550/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.0332e-05 - val_loss: 0.0018
# Epoch 4551/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 7.4314e-05 - val_loss: 0.0018
# Epoch 4552/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.0048e-05 - val_loss: 0.0019
# Epoch 4553/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 7.8781e-05 - val_loss: 0.0016
# Epoch 4554/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.8815e-05 - val_loss: 0.0017
# Epoch 4555/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 8.9689e-05 - val_loss: 0.0019
# Epoch 4556/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.4616e-05 - val_loss: 0.0017
# Epoch 4557/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 9.3548e-05 - val_loss: 0.0021
# Epoch 4558/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.9098e-05 - val_loss: 0.0021
# Epoch 4559/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 8.0293e-05 - val_loss: 0.0021
# Epoch 4560/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 6.8762e-05 - val_loss: 0.0020
# Epoch 4561/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.3218e-05 - val_loss: 0.0018
# Epoch 4562/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.9496e-05 - val_loss: 0.0017
# Epoch 4563/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.7367e-05 - val_loss: 0.0018
# Epoch 4564/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.5900e-05 - val_loss: 0.0017
# Epoch 4565/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.5943e-05 - val_loss: 0.0018
# Epoch 4566/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.6911e-05 - val_loss: 0.0019
# Epoch 4567/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.7405e-05 - val_loss: 0.0019
# Epoch 4568/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.7324e-05 - val_loss: 0.0020
# Epoch 4569/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.7266e-05 - val_loss: 0.0020
# Epoch 4570/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.8422e-05 - val_loss: 0.0020
# Epoch 4571/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.9094e-05 - val_loss: 0.0020
# Epoch 4572/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.9506e-05 - val_loss: 0.0020
# Epoch 4573/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.9302e-05 - val_loss: 0.0020
# Epoch 4574/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.8425e-05 - val_loss: 0.0020
# Epoch 4575/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.7968e-05 - val_loss: 0.0021
# Epoch 4576/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.7868e-05 - val_loss: 0.0021
# Epoch 4577/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.7902e-05 - val_loss: 0.0021
# Epoch 4578/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.7798e-05 - val_loss: 0.0021
# Epoch 4579/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 5.7857e-05 - val_loss: 0.0021
# Epoch 4580/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.8847e-05 - val_loss: 0.0020
# Epoch 4581/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 6.1185e-05 - val_loss: 0.0020
# Epoch 4582/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.3698e-05 - val_loss: 0.0019
# Epoch 4583/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.6772e-05 - val_loss: 0.0017
# Epoch 4584/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 7.3508e-05 - val_loss: 0.0016
# Epoch 4585/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.2931e-05 - val_loss: 0.0016
# Epoch 4586/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.8045e-05 - val_loss: 0.0016
# Epoch 4587/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 7.0016e-05 - val_loss: 0.0018
# Epoch 4588/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.4576e-05 - val_loss: 0.0019
# Epoch 4589/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.4626e-05 - val_loss: 0.0018
# Epoch 4590/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.9099e-05 - val_loss: 0.0019
# Epoch 4591/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.4395e-05 - val_loss: 0.0020
# Epoch 4592/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.6291e-05 - val_loss: 0.0019
# Epoch 4593/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.0275e-05 - val_loss: 0.0018
# Epoch 4594/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.2010e-05 - val_loss: 0.0021
# Epoch 4595/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.8748e-05 - val_loss: 0.0021
# Epoch 4596/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.8213e-05 - val_loss: 0.0020
# Epoch 4597/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.7756e-05 - val_loss: 0.0020
# Epoch 4598/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.7814e-05 - val_loss: 0.0019
# Epoch 4599/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.8141e-05 - val_loss: 0.0019
# Epoch 4600/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 6.2193e-05 - val_loss: 0.0018
# Epoch 4601/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.8269e-05 - val_loss: 0.0017
# Epoch 4602/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 7.4028e-05 - val_loss: 0.0015
# Epoch 4603/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 7.7239e-05 - val_loss: 0.0015
# Epoch 4604/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.4978e-05 - val_loss: 0.0015
# Epoch 4605/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 6.5832e-05 - val_loss: 0.0016
# Epoch 4606/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.8999e-05 - val_loss: 0.0017
# Epoch 4607/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.8835e-05 - val_loss: 0.0017
# Epoch 4608/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.2664e-05 - val_loss: 0.0018
# Epoch 4609/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.3538e-05 - val_loss: 0.0019
# Epoch 4610/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 6.1160e-05 - val_loss: 0.0019
# Epoch 4611/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.8778e-05 - val_loss: 0.0019
# Epoch 4612/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.8162e-05 - val_loss: 0.0019
# Epoch 4613/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.8313e-05 - val_loss: 0.0020
# Epoch 4614/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.0102e-05 - val_loss: 0.0020
# Epoch 4615/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.1503e-05 - val_loss: 0.0019
# Epoch 4616/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6.0181e-05 - val_loss: 0.0019
# Epoch 4617/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.8067e-05 - val_loss: 0.0019
# Epoch 4618/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.4495e-05 - val_loss: 0.0019
# Epoch 4619/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.3051e-05 - val_loss: 0.0020
# Epoch 4620/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.4452e-05 - val_loss: 0.0021
# Epoch 4621/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.6624e-05 - val_loss: 0.0020
# Epoch 4622/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.9243e-05 - val_loss: 0.0019
# Epoch 4623/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.2379e-05 - val_loss: 0.0019
# Epoch 4624/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 6.2789e-05 - val_loss: 0.0019
# Epoch 4625/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.1201e-05 - val_loss: 0.0019
# Epoch 4626/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 6.1018e-05 - val_loss: 0.0019
# Epoch 4627/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.9351e-05 - val_loss: 0.0019
# Epoch 4628/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.2008e-05 - val_loss: 0.0018
# Epoch 4629/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6.5310e-05 - val_loss: 0.0017
# Epoch 4630/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.7881e-05 - val_loss: 0.0016
# Epoch 4631/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 7.1283e-05 - val_loss: 0.0015
# Epoch 4632/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 7.4146e-05 - val_loss: 0.0014
# Epoch 4633/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.4092e-05 - val_loss: 0.0014
# Epoch 4634/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 7.1320e-05 - val_loss: 0.0015
# Epoch 4635/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.5185e-05 - val_loss: 0.0017
# Epoch 4636/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.2243e-05 - val_loss: 0.0020
# Epoch 4637/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.3992e-05 - val_loss: 0.0023
# Epoch 4638/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.7408e-05 - val_loss: 0.0025
# Epoch 4639/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.7326e-05 - val_loss: 0.0026
# Epoch 4640/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.8817e-05 - val_loss: 0.0024
# Epoch 4641/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.4164e-05 - val_loss: 0.0022
# Epoch 4642/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.2263e-05 - val_loss: 0.0020
# Epoch 4643/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.8622e-05 - val_loss: 0.0020
# Epoch 4644/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.8121e-05 - val_loss: 0.0019
# Epoch 4645/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.8223e-05 - val_loss: 0.0018
# Epoch 4646/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.7945e-05 - val_loss: 0.0018
# Epoch 4647/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.6977e-05 - val_loss: 0.0018
# Epoch 4648/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.8032e-05 - val_loss: 0.0019
# Epoch 4649/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.8885e-05 - val_loss: 0.0019
# Epoch 4650/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.7907e-05 - val_loss: 0.0019
# Epoch 4651/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.5840e-05 - val_loss: 0.0019
# Epoch 4652/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.3997e-05 - val_loss: 0.0019
# Epoch 4653/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.2748e-05 - val_loss: 0.0019
# Epoch 4654/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.2029e-05 - val_loss: 0.0019
# Epoch 4655/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.2159e-05 - val_loss: 0.0019
# Epoch 4656/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.2724e-05 - val_loss: 0.0019
# Epoch 4657/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.2834e-05 - val_loss: 0.0019
# Epoch 4658/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.2314e-05 - val_loss: 0.0019
# Epoch 4659/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.1448e-05 - val_loss: 0.0019
# Epoch 4660/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.0767e-05 - val_loss: 0.0019
# Epoch 4661/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.0783e-05 - val_loss: 0.0019
# Epoch 4662/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.1813e-05 - val_loss: 0.0019
# Epoch 4663/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.4514e-05 - val_loss: 0.0019
# Epoch 4664/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.9739e-05 - val_loss: 0.0021
# Epoch 4665/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.7199e-05 - val_loss: 0.0021
# Epoch 4666/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.3797e-05 - val_loss: 0.0020
# Epoch 4667/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.8195e-05 - val_loss: 0.0019
# Epoch 4668/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 6.9987e-05 - val_loss: 0.0018
# Epoch 4669/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 6.0471e-05 - val_loss: 0.0018
# Epoch 4670/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.4532e-05 - val_loss: 0.0019
# Epoch 4671/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 5.0512e-05 - val_loss: 0.0019
# Epoch 4672/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.8980e-05 - val_loss: 0.0017
# Epoch 4673/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.7598e-05 - val_loss: 0.0018
# Epoch 4674/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.4573e-05 - val_loss: 0.0019
# Epoch 4675/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.2394e-05 - val_loss: 0.0020
# Epoch 4676/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.0673e-05 - val_loss: 0.0021
# Epoch 4677/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.8021e-05 - val_loss: 0.0021
# Epoch 4678/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.4879e-05 - val_loss: 0.0021
# Epoch 4679/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.2941e-05 - val_loss: 0.0021
# Epoch 4680/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.2875e-05 - val_loss: 0.0021
# Epoch 4681/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.4271e-05 - val_loss: 0.0020
# Epoch 4682/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.4682e-05 - val_loss: 0.0021
# Epoch 4683/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.3965e-05 - val_loss: 0.0021
# Epoch 4684/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.2668e-05 - val_loss: 0.0021
# Epoch 4685/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.1693e-05 - val_loss: 0.0021
# Epoch 4686/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.1628e-05 - val_loss: 0.0022
# Epoch 4687/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.2157e-05 - val_loss: 0.0022
# Epoch 4688/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.2476e-05 - val_loss: 0.0022
# Epoch 4689/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.2646e-05 - val_loss: 0.0023
# Epoch 4690/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.2740e-05 - val_loss: 0.0023
# Epoch 4691/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.3147e-05 - val_loss: 0.0023
# Epoch 4692/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 3.3863e-05 - val_loss: 0.0023
# Epoch 4693/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.4597e-05 - val_loss: 0.0023
# Epoch 4694/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.4896e-05 - val_loss: 0.0023
# Epoch 4695/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.5117e-05 - val_loss: 0.0023
# Epoch 4696/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.5535e-05 - val_loss: 0.0023
# Epoch 4697/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.6358e-05 - val_loss: 0.0022
# Epoch 4698/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.7011e-05 - val_loss: 0.0022
# Epoch 4699/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.7343e-05 - val_loss: 0.0022
# Epoch 4700/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.7239e-05 - val_loss: 0.0022
# Epoch 4701/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.7271e-05 - val_loss: 0.0023
# Epoch 4702/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.7717e-05 - val_loss: 0.0023
# Epoch 4703/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.8534e-05 - val_loss: 0.0023
# Epoch 4704/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.9331e-05 - val_loss: 0.0023
# Epoch 4705/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.0080e-05 - val_loss: 0.0023
# Epoch 4706/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.1011e-05 - val_loss: 0.0023
# Epoch 4707/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.1593e-05 - val_loss: 0.0023
# Epoch 4708/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.1091e-05 - val_loss: 0.0023
# Epoch 4709/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.0139e-05 - val_loss: 0.0023
# Epoch 4710/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.9771e-05 - val_loss: 0.0022
# Epoch 4711/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.9573e-05 - val_loss: 0.0022
# Epoch 4712/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.9586e-05 - val_loss: 0.0022
# Epoch 4713/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.0679e-05 - val_loss: 0.0022
# Epoch 4714/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.2781e-05 - val_loss: 0.0023
# Epoch 4715/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.4713e-05 - val_loss: 0.0025
# Epoch 4716/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.5769e-05 - val_loss: 0.0026
# Epoch 4717/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.5667e-05 - val_loss: 0.0026
# Epoch 4718/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.4478e-05 - val_loss: 0.0026
# Epoch 4719/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.2416e-05 - val_loss: 0.0025
# Epoch 4720/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.0522e-05 - val_loss: 0.0025
# Epoch 4721/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.0280e-05 - val_loss: 0.0025
# Epoch 4722/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.0157e-05 - val_loss: 0.0026
# Epoch 4723/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.0453e-05 - val_loss: 0.0027
# Epoch 4724/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.3391e-05 - val_loss: 0.0028
# Epoch 4725/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.9606e-05 - val_loss: 0.0029
# Epoch 4726/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.0672e-05 - val_loss: 0.0029
# Epoch 4727/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 7.0139e-05 - val_loss: 0.0025
# Epoch 4728/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.6698e-05 - val_loss: 0.0022
# Epoch 4729/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.4434e-05 - val_loss: 0.0023
# Epoch 4730/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.7208e-05 - val_loss: 0.0022
# Epoch 4731/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.4987e-05 - val_loss: 0.0025
# Epoch 4732/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.3817e-05 - val_loss: 0.0026
# Epoch 4733/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.3523e-05 - val_loss: 0.0027
# Epoch 4734/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.3764e-05 - val_loss: 0.0028
# Epoch 4735/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.4658e-05 - val_loss: 0.0028
# Epoch 4736/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.7473e-05 - val_loss: 0.0025
# Epoch 4737/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.8510e-05 - val_loss: 0.0024
# Epoch 4738/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.8564e-05 - val_loss: 0.0025
# Epoch 4739/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.0579e-05 - val_loss: 0.0024
# Epoch 4740/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.5963e-05 - val_loss: 0.0025
# Epoch 4741/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.0715e-05 - val_loss: 0.0027
# Epoch 4742/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.6627e-05 - val_loss: 0.0026
# Epoch 4743/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.2360e-05 - val_loss: 0.0024
# Epoch 4744/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.0031e-05 - val_loss: 0.0025
# Epoch 4745/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.2039e-05 - val_loss: 0.0028
# Epoch 4746/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.7396e-05 - val_loss: 0.0030
# Epoch 4747/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.7214e-05 - val_loss: 0.0031
# Epoch 4748/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.6479e-05 - val_loss: 0.0032
# Epoch 4749/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.7937e-05 - val_loss: 0.0032
# Epoch 4750/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.9824e-05 - val_loss: 0.0032
# Epoch 4751/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.1139e-05 - val_loss: 0.0030
# Epoch 4752/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.2946e-05 - val_loss: 0.0030
# Epoch 4753/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.5782e-05 - val_loss: 0.0028
# Epoch 4754/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.8654e-05 - val_loss: 0.0026
# Epoch 4755/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.1028e-05 - val_loss: 0.0024
# Epoch 4756/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 5.2766e-05 - val_loss: 0.0024
# Epoch 4757/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 5.1389e-05 - val_loss: 0.0025
# Epoch 4758/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.5291e-05 - val_loss: 0.0026
# Epoch 4759/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 3.8260e-05 - val_loss: 0.0026
# Epoch 4760/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.4005e-05 - val_loss: 0.0025
# Epoch 4761/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.1504e-05 - val_loss: 0.0025
# Epoch 4762/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.9382e-05 - val_loss: 0.0025
# Epoch 4763/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.8316e-05 - val_loss: 0.0025
# Epoch 4764/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.8701e-05 - val_loss: 0.0024
# Epoch 4765/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.9772e-05 - val_loss: 0.0023
# Epoch 4766/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.1028e-05 - val_loss: 0.0023
# Epoch 4767/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.3011e-05 - val_loss: 0.0022
# Epoch 4768/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.5278e-05 - val_loss: 0.0022
# Epoch 4769/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.8891e-05 - val_loss: 0.0022
# Epoch 4770/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.5067e-05 - val_loss: 0.0022
# Epoch 4771/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.5702e-05 - val_loss: 0.0022
# Epoch 4772/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.4478e-05 - val_loss: 0.0021
# Epoch 4773/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.2824e-05 - val_loss: 0.0022
# Epoch 4774/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 7.6679e-05 - val_loss: 0.0024
# Epoch 4775/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.9057e-05 - val_loss: 0.0022
# Epoch 4776/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.2783e-05 - val_loss: 0.0023
# Epoch 4777/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 3.9458e-05 - val_loss: 0.0025
# Epoch 4778/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.3383e-05 - val_loss: 0.0024
# Epoch 4779/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.0130e-05 - val_loss: 0.0024
# Epoch 4780/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.6811e-05 - val_loss: 0.0025
# Epoch 4781/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.3372e-05 - val_loss: 0.0024
# Epoch 4782/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.9825e-05 - val_loss: 0.0025
# Epoch 4783/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.1744e-05 - val_loss: 0.0024
# Epoch 4784/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.5273e-05 - val_loss: 0.0024
# Epoch 4785/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.4311e-05 - val_loss: 0.0024
# Epoch 4786/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.7139e-05 - val_loss: 0.0022
# Epoch 4787/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.8348e-05 - val_loss: 0.0025
# Epoch 4788/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.8919e-05 - val_loss: 0.0023
# Epoch 4789/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.1313e-05 - val_loss: 0.0025
# Epoch 4790/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.2959e-05 - val_loss: 0.0025
# Epoch 4791/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.6447e-05 - val_loss: 0.0026
# Epoch 4792/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.9682e-05 - val_loss: 0.0027
# Epoch 4793/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.5473e-05 - val_loss: 0.0025
# Epoch 4794/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.9649e-05 - val_loss: 0.0023
# Epoch 4795/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.0478e-05 - val_loss: 0.0025
# Epoch 4796/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.5815e-05 - val_loss: 0.0023
# Epoch 4797/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.9060e-05 - val_loss: 0.0022
# Epoch 4798/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.6172e-05 - val_loss: 0.0023
# Epoch 4799/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.5779e-05 - val_loss: 0.0025
# Epoch 4800/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.2669e-05 - val_loss: 0.0025
# Epoch 4801/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.2367e-05 - val_loss: 0.0025
# Epoch 4802/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.1787e-05 - val_loss: 0.0022
# Epoch 4803/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.6589e-05 - val_loss: 0.0025
# Epoch 4804/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 5.1387e-05 - val_loss: 0.0027
# Epoch 4805/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.1303e-05 - val_loss: 0.0027
# Epoch 4806/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 5.3397e-05 - val_loss: 0.0027
# Epoch 4807/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.6878e-05 - val_loss: 0.0027
# Epoch 4808/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.0422e-05 - val_loss: 0.0027
# Epoch 4809/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.1567e-05 - val_loss: 0.0027
# Epoch 4810/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.5489e-05 - val_loss: 0.0027
# Epoch 4811/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.5780e-05 - val_loss: 0.0028
# Epoch 4812/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.5732e-05 - val_loss: 0.0030
# Epoch 4813/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.6983e-05 - val_loss: 0.0029
# Epoch 4814/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.2360e-05 - val_loss: 0.0026
# Epoch 4815/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.8687e-05 - val_loss: 0.0026
# Epoch 4816/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.9200e-05 - val_loss: 0.0030
# Epoch 4817/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.9001e-05 - val_loss: 0.0031
# Epoch 4818/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.4160e-05 - val_loss: 0.0032
# Epoch 4819/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.3593e-05 - val_loss: 0.0034
# Epoch 4820/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.3436e-05 - val_loss: 0.0032
# Epoch 4821/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.6206e-05 - val_loss: 0.0028
# Epoch 4822/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.9134e-05 - val_loss: 0.0028
# Epoch 4823/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.2885e-05 - val_loss: 0.0025
# Epoch 4824/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.4035e-05 - val_loss: 0.0026
# Epoch 4825/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.1479e-05 - val_loss: 0.0026
# Epoch 4826/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.9527e-05 - val_loss: 0.0023
# Epoch 4827/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.2062e-05 - val_loss: 0.0028
# Epoch 4828/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.7674e-05 - val_loss: 0.0027
# Epoch 4829/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.7237e-05 - val_loss: 0.0031
# Epoch 4830/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.9628e-05 - val_loss: 0.0027
# Epoch 4831/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.4229e-05 - val_loss: 0.0028
# Epoch 4832/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.0006e-05 - val_loss: 0.0028
# Epoch 4833/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.2875e-05 - val_loss: 0.0030
# Epoch 4834/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.2392e-05 - val_loss: 0.0029
# Epoch 4835/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.3735e-05 - val_loss: 0.0030
# Epoch 4836/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.2822e-05 - val_loss: 0.0029
# Epoch 4837/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.4334e-05 - val_loss: 0.0030
# Epoch 4838/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.1702e-05 - val_loss: 0.0032
# Epoch 4839/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.1462e-05 - val_loss: 0.0035
# Epoch 4840/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.3886e-05 - val_loss: 0.0040
# Epoch 4841/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 7.6893e-05 - val_loss: 0.0041
# Epoch 4842/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.0458e-05 - val_loss: 0.0035
# Epoch 4843/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.9193e-05 - val_loss: 0.0025
# Epoch 4844/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.4580e-05 - val_loss: 0.0032
# Epoch 4845/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.5710e-05 - val_loss: 0.0031
# Epoch 4846/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.0394e-05 - val_loss: 0.0032
# Epoch 4847/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.9822e-05 - val_loss: 0.0038
# Epoch 4848/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.8501e-05 - val_loss: 0.0035
# Epoch 4849/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.3967e-05 - val_loss: 0.0034
# Epoch 4850/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.4035e-05 - val_loss: 0.0035
# Epoch 4851/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.3118e-05 - val_loss: 0.0034
# Epoch 4852/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.1970e-05 - val_loss: 0.0037
# Epoch 4853/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.0656e-05 - val_loss: 0.0037
# Epoch 4854/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.7518e-05 - val_loss: 0.0036
# Epoch 4855/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.4792e-05 - val_loss: 0.0036
# Epoch 4856/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.5354e-05 - val_loss: 0.0034
# Epoch 4857/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.7503e-05 - val_loss: 0.0035
# Epoch 4858/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.7888e-05 - val_loss: 0.0032
# Epoch 4859/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.0421e-05 - val_loss: 0.0037
# Epoch 4860/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.3034e-05 - val_loss: 0.0036
# Epoch 4861/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.5993e-05 - val_loss: 0.0038
# Epoch 4862/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.7470e-05 - val_loss: 0.0033
# Epoch 4863/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.4138e-05 - val_loss: 0.0035
# Epoch 4864/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.3978e-05 - val_loss: 0.0036
# Epoch 4865/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.7202e-05 - val_loss: 0.0036
# Epoch 4866/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.4559e-05 - val_loss: 0.0032
# Epoch 4867/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.8405e-05 - val_loss: 0.0030
# Epoch 4868/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.5210e-05 - val_loss: 0.0031
# Epoch 4869/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.8651e-05 - val_loss: 0.0035
# Epoch 4870/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.2417e-05 - val_loss: 0.0040
# Epoch 4871/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.4990e-05 - val_loss: 0.0038
# Epoch 4872/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 5.9424e-05 - val_loss: 0.0033
# Epoch 4873/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.4635e-05 - val_loss: 0.0028
# Epoch 4874/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 6.9998e-05 - val_loss: 0.0025
# Epoch 4875/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.7896e-05 - val_loss: 0.0027
# Epoch 4876/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.5777e-05 - val_loss: 0.0030
# Epoch 4877/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 8.0534e-05 - val_loss: 0.0024
# Epoch 4878/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.3416e-05 - val_loss: 0.0024
# Epoch 4879/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.3817e-05 - val_loss: 0.0024
# Epoch 4880/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.6023e-05 - val_loss: 0.0030
# Epoch 4881/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.8908e-05 - val_loss: 0.0027
# Epoch 4882/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.7892e-05 - val_loss: 0.0033
# Epoch 4883/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.0422e-05 - val_loss: 0.0036
# Epoch 4884/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.2822e-05 - val_loss: 0.0032
# Epoch 4885/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.5639e-05 - val_loss: 0.0033
# Epoch 4886/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.8645e-05 - val_loss: 0.0032
# Epoch 4887/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.7265e-05 - val_loss: 0.0032
# Epoch 4888/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.9374e-05 - val_loss: 0.0032
# Epoch 4889/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.5374e-05 - val_loss: 0.0032
# Epoch 4890/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.0889e-05 - val_loss: 0.0033
# Epoch 4891/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 6.2469e-05 - val_loss: 0.0037
# Epoch 4892/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.1032e-05 - val_loss: 0.0036
# Epoch 4893/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.7610e-05 - val_loss: 0.0032
# Epoch 4894/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.2842e-05 - val_loss: 0.0026
# Epoch 4895/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.8520e-05 - val_loss: 0.0027
# Epoch 4896/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6.5338e-05 - val_loss: 0.0029
# Epoch 4897/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 5.5890e-05 - val_loss: 0.0029
# Epoch 4898/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.4424e-05 - val_loss: 0.0030
# Epoch 4899/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.0522e-05 - val_loss: 0.0028
# Epoch 4900/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.7591e-05 - val_loss: 0.0030
# Epoch 4901/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.5695e-05 - val_loss: 0.0028
# Epoch 4902/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.3578e-05 - val_loss: 0.0028
# Epoch 4903/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.3948e-05 - val_loss: 0.0027
# Epoch 4904/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.5710e-05 - val_loss: 0.0028
# Epoch 4905/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.8999e-05 - val_loss: 0.0029
# Epoch 4906/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.2811e-05 - val_loss: 0.0030
# Epoch 4907/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.5040e-05 - val_loss: 0.0030
# Epoch 4908/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.5249e-05 - val_loss: 0.0030
# Epoch 4909/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.3839e-05 - val_loss: 0.0030
# Epoch 4910/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.1084e-05 - val_loss: 0.0029
# Epoch 4911/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.7917e-05 - val_loss: 0.0029
# Epoch 4912/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.7346e-05 - val_loss: 0.0029
# Epoch 4913/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.1381e-05 - val_loss: 0.0029
# Epoch 4914/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.8523e-05 - val_loss: 0.0029
# Epoch 4915/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.4124e-05 - val_loss: 0.0027
# Epoch 4916/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.3526e-05 - val_loss: 0.0025
# Epoch 4917/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.2058e-05 - val_loss: 0.0023
# Epoch 4918/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.2169e-05 - val_loss: 0.0021
# Epoch 4919/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.2254e-05 - val_loss: 0.0021
# Epoch 4920/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 5.3729e-05 - val_loss: 0.0022
# Epoch 4921/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 5.7758e-05 - val_loss: 0.0023
# Epoch 4922/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 6.0237e-05 - val_loss: 0.0024
# Epoch 4923/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.9960e-05 - val_loss: 0.0023
# Epoch 4924/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6.3323e-05 - val_loss: 0.0024
# Epoch 4925/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.0171e-05 - val_loss: 0.0025
# Epoch 4926/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.3486e-05 - val_loss: 0.0028
# Epoch 4927/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.5158e-05 - val_loss: 0.0029
# Epoch 4928/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.2719e-05 - val_loss: 0.0029
# Epoch 4929/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.7015e-05 - val_loss: 0.0027
# Epoch 4930/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.2664e-05 - val_loss: 0.0028
# Epoch 4931/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.3743e-05 - val_loss: 0.0028
# Epoch 4932/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.0431e-05 - val_loss: 0.0028
# Epoch 4933/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.8069e-05 - val_loss: 0.0030
# Epoch 4934/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.0159e-05 - val_loss: 0.0033
# Epoch 4935/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.3178e-05 - val_loss: 0.0035
# Epoch 4936/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.9697e-05 - val_loss: 0.0035
# Epoch 4937/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.4438e-05 - val_loss: 0.0037
# Epoch 4938/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.3208e-05 - val_loss: 0.0037
# Epoch 4939/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.2350e-05 - val_loss: 0.0037
# Epoch 4940/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.5090e-05 - val_loss: 0.0036
# Epoch 4941/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.7856e-05 - val_loss: 0.0035
# Epoch 4942/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.5959e-05 - val_loss: 0.0037
# Epoch 4943/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.3851e-05 - val_loss: 0.0035
# Epoch 4944/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 3.2928e-05 - val_loss: 0.0032
# Epoch 4945/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.4017e-05 - val_loss: 0.0030
# Epoch 4946/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.4832e-05 - val_loss: 0.0028
# Epoch 4947/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.5907e-05 - val_loss: 0.0026
# Epoch 4948/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.8323e-05 - val_loss: 0.0026
# Epoch 4949/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.0734e-05 - val_loss: 0.0027
# Epoch 4950/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.1539e-05 - val_loss: 0.0028
# Epoch 4951/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.1489e-05 - val_loss: 0.0028
# Epoch 4952/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.3144e-05 - val_loss: 0.0027
# Epoch 4953/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.5427e-05 - val_loss: 0.0027
# Epoch 4954/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.9844e-05 - val_loss: 0.0028
# Epoch 4955/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.9458e-05 - val_loss: 0.0028
# Epoch 4956/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 7.5317e-05 - val_loss: 0.0028
# Epoch 4957/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.1752e-05 - val_loss: 0.0031
# Epoch 4958/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.8492e-05 - val_loss: 0.0024
# Epoch 4959/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 7.4215e-05 - val_loss: 0.0027
# Epoch 4960/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.1008e-05 - val_loss: 0.0029
# Epoch 4961/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.8175e-05 - val_loss: 0.0028
# Epoch 4962/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.8626e-05 - val_loss: 0.0031
# Epoch 4963/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.1908e-05 - val_loss: 0.0029
# Epoch 4964/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.8541e-05 - val_loss: 0.0029
# Epoch 4965/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.9995e-05 - val_loss: 0.0028
# Epoch 4966/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.6539e-05 - val_loss: 0.0028
# Epoch 4967/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4942e-05 - val_loss: 0.0027
# Epoch 4968/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 3.5573e-05 - val_loss: 0.0028
# Epoch 4969/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.1967e-05 - val_loss: 0.0027
# Epoch 4970/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.1601e-05 - val_loss: 0.0027
# Epoch 4971/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.1610e-05 - val_loss: 0.0027
# Epoch 4972/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.3010e-05 - val_loss: 0.0026
# Epoch 4973/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.5100e-05 - val_loss: 0.0026
# Epoch 4974/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.6104e-05 - val_loss: 0.0026
# Epoch 4975/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.9254e-05 - val_loss: 0.0026
# Epoch 4976/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.4354e-05 - val_loss: 0.0027
# Epoch 4977/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.8298e-05 - val_loss: 0.0027
# Epoch 4978/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.2083e-05 - val_loss: 0.0031
# Epoch 4979/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.5953e-05 - val_loss: 0.0031
# Epoch 4980/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.2906e-05 - val_loss: 0.0030
# Epoch 4981/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.7118e-05 - val_loss: 0.0032
# Epoch 4982/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.2447e-05 - val_loss: 0.0033
# Epoch 4983/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.4677e-05 - val_loss: 0.0031
# Epoch 4984/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.8357e-05 - val_loss: 0.0029
# Epoch 4985/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.1451e-05 - val_loss: 0.0026
# Epoch 4986/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.1034e-05 - val_loss: 0.0023
# Epoch 4987/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.5055e-05 - val_loss: 0.0022
# Epoch 4988/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.5869e-05 - val_loss: 0.0022
# Epoch 4989/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 5.7455e-05 - val_loss: 0.0021
# Epoch 4990/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 5.6089e-05 - val_loss: 0.0021
# Epoch 4991/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 5.8332e-05 - val_loss: 0.0021
# Epoch 4992/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 6.0913e-05 - val_loss: 0.0023
# Epoch 4993/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.8225e-05 - val_loss: 0.0025
# Epoch 4994/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.4379e-05 - val_loss: 0.0026
# Epoch 4995/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.1575e-05 - val_loss: 0.0027
# Epoch 4996/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.6302e-05 - val_loss: 0.0027
# Epoch 4997/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.0344e-05 - val_loss: 0.0028
# Epoch 4998/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.8088e-05 - val_loss: 0.0031
# Epoch 4999/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.7532e-05 - val_loss: 0.0035
# Epoch 5000/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.9472e-05 - val_loss: 0.0037
# Epoch 5001/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.4532e-05 - val_loss: 0.0037
# Epoch 5002/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.0688e-05 - val_loss: 0.0034
# Epoch 5003/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.5328e-05 - val_loss: 0.0028
# Epoch 5004/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.2453e-05 - val_loss: 0.0026
# Epoch 5005/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.5138e-05 - val_loss: 0.0025
# Epoch 5006/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.7518e-05 - val_loss: 0.0027
# Epoch 5007/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.7157e-05 - val_loss: 0.0028
# Epoch 5008/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.5333e-05 - val_loss: 0.0030
# Epoch 5009/7000
# ...
# Epoch 6925/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.9118e-05 - val_loss: 0.0034
# Epoch 6926/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.9525e-05 - val_loss: 0.0033
# Epoch 6927/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.8049e-05 - val_loss: 0.0032
# Epoch 6928/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.6350e-05 - val_loss: 0.0031
# Epoch 6929/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.6839e-05 - val_loss: 0.0031
# Epoch 6930/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.8827e-05 - val_loss: 0.0030
# Epoch 6931/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.0550e-05 - val_loss: 0.0028
# Epoch 6932/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 2.1732e-05 - val_loss: 0.0028
# Epoch 6933/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 2.2557e-05 - val_loss: 0.0028
# Epoch 6934/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.3106e-05 - val_loss: 0.0029
# Epoch 6935/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.1878e-05 - val_loss: 0.0030
# Epoch 6936/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.9495e-05 - val_loss: 0.0029
# Epoch 6937/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.0556e-05 - val_loss: 0.0029
# Epoch 6938/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 2.3909e-05 - val_loss: 0.0028
# Epoch 6939/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 2.6600e-05 - val_loss: 0.0029
# Epoch 6940/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.6109e-05 - val_loss: 0.0030
# Epoch 6941/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.3231e-05 - val_loss: 0.0031
# Epoch 6942/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.1983e-05 - val_loss: 0.0033
# Epoch 6943/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.2561e-05 - val_loss: 0.0034
# Epoch 6944/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.2805e-05 - val_loss: 0.0032
# Epoch 6945/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.1612e-05 - val_loss: 0.0028
# Epoch 6946/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 2.0520e-05 - val_loss: 0.0026
# Epoch 6947/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 2.0248e-05 - val_loss: 0.0026
# Epoch 6948/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.9968e-05 - val_loss: 0.0027
# Epoch 6949/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 2.0173e-05 - val_loss: 0.0027
# Epoch 6950/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 2.1260e-05 - val_loss: 0.0027
# Epoch 6951/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.4870e-05 - val_loss: 0.0026
# Epoch 6952/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.0874e-05 - val_loss: 0.0029
# Epoch 6953/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.7675e-05 - val_loss: 0.0036
# Epoch 6954/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.5047e-05 - val_loss: 0.0038
# Epoch 6955/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 5.0178e-05 - val_loss: 0.0040
# Epoch 6956/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.5483e-05 - val_loss: 0.0046
# Epoch 6957/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.5462e-05 - val_loss: 0.0036
# Epoch 6958/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.1308e-05 - val_loss: 0.0039
# Epoch 6959/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.1499e-05 - val_loss: 0.0033
# Epoch 6960/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.8610e-05 - val_loss: 0.0037
# Epoch 6961/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.5865e-05 - val_loss: 0.0043
# Epoch 6962/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.8005e-05 - val_loss: 0.0040
# Epoch 6963/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.6621e-05 - val_loss: 0.0038
# Epoch 6964/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.3594e-05 - val_loss: 0.0034
# Epoch 6965/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.6951e-05 - val_loss: 0.0035
# Epoch 6966/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.5713e-05 - val_loss: 0.0038
# Epoch 6967/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.4005e-05 - val_loss: 0.0031
# Epoch 6968/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.4136e-05 - val_loss: 0.0038
# Epoch 6969/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.4540e-05 - val_loss: 0.0030
# Epoch 6970/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.8758e-05 - val_loss: 0.0030
# Epoch 6971/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 3.6882e-05 - val_loss: 0.0032
# Epoch 6972/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 3.7726e-05 - val_loss: 0.0036
# Epoch 6973/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 3.4013e-05 - val_loss: 0.0032
# Epoch 6974/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 2.6384e-05 - val_loss: 0.0030
# Epoch 6975/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 2.3451e-05 - val_loss: 0.0028
# Epoch 6976/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.5875e-05 - val_loss: 0.0031
# Epoch 6977/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.1409e-05 - val_loss: 0.0036
# Epoch 6978/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.5645e-05 - val_loss: 0.0035
# Epoch 6979/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.4235e-05 - val_loss: 0.0034
# Epoch 6980/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.2104e-05 - val_loss: 0.0034
# Epoch 6981/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1022e-05 - val_loss: 0.0034
# Epoch 6982/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.2396e-05 - val_loss: 0.0034
# Epoch 6983/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.4208e-05 - val_loss: 0.0033
# Epoch 6984/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.6005e-05 - val_loss: 0.0030
# Epoch 6985/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.6049e-05 - val_loss: 0.0029
# Epoch 6986/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.5280e-05 - val_loss: 0.0029
# Epoch 6987/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.4901e-05 - val_loss: 0.0030
# Epoch 6988/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.4683e-05 - val_loss: 0.0032
# Epoch 6989/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.3157e-05 - val_loss: 0.0032
# Epoch 6990/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.2799e-05 - val_loss: 0.0031
# Epoch 6991/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.2359e-05 - val_loss: 0.0030
# Epoch 6992/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.0764e-05 - val_loss: 0.0030
# Epoch 6993/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 9.9800e-06 - val_loss: 0.0031
# Epoch 6994/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.1564e-05 - val_loss: 0.0032
# Epoch 6995/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.4404e-05 - val_loss: 0.0032
# Epoch 6996/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.6393e-05 - val_loss: 0.0032
# Epoch 6997/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.7130e-05 - val_loss: 0.0033
# Epoch 6998/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.7189e-05 - val_loss: 0.0033
# Epoch 6999/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.7036e-05 - val_loss: 0.0033
# Epoch 7000/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.6128e-05 - val_loss: 0.0032
# --- Starting Reinforcement Learning Fine-Tuning (Batched) ---
# RL Epoch 1/150, Average Loss per Batch: 0.000018
# RL Epoch 2/150, Average Loss per Batch: 0.000020
# RL Epoch 3/150, Average Loss per Batch: 0.000010
# RL Epoch 4/150, Average Loss per Batch: 0.000008
# RL Epoch 5/150, Average Loss per Batch: 0.000008
# RL Epoch 6/150, Average Loss per Batch: 0.000009
# RL Epoch 7/150, Average Loss per Batch: 0.000010
# RL Epoch 8/150, Average Loss per Batch: 0.000022
# RL Epoch 9/150, Average Loss per Batch: 0.000024
# RL Epoch 10/150, Average Loss per Batch: 0.000044
# RL Epoch 11/150, Average Loss per Batch: 0.000044
# RL Epoch 12/150, Average Loss per Batch: 0.000022
# RL Epoch 13/150, Average Loss per Batch: 0.000014
# RL Epoch 14/150, Average Loss per Batch: 0.000011
# RL Epoch 15/150, Average Loss per Batch: 0.000014
# RL Epoch 16/150, Average Loss per Batch: 0.000012
# RL Epoch 17/150, Average Loss per Batch: 0.000011
# RL Epoch 18/150, Average Loss per Batch: 0.000011
# RL Epoch 19/150, Average Loss per Batch: 0.000008
# RL Epoch 20/150, Average Loss per Batch: 0.000011
# RL Epoch 21/150, Average Loss per Batch: 0.000009
# RL Epoch 22/150, Average Loss per Batch: 0.000007
# RL Epoch 23/150, Average Loss per Batch: 0.000012
# RL Epoch 24/150, Average Loss per Batch: 0.000008
# RL Epoch 25/150, Average Loss per Batch: 0.000007
# RL Epoch 26/150, Average Loss per Batch: 0.000009
# RL Epoch 27/150, Average Loss per Batch: 0.000006
# RL Epoch 28/150, Average Loss per Batch: 0.000006
# RL Epoch 29/150, Average Loss per Batch: 0.000005
# RL Epoch 30/150, Average Loss per Batch: 0.000005
# RL Epoch 31/150, Average Loss per Batch: 0.000004
# RL Epoch 32/150, Average Loss per Batch: 0.000004
# RL Epoch 33/150, Average Loss per Batch: 0.000004
# RL Epoch 34/150, Average Loss per Batch: 0.000004
# RL Epoch 35/150, Average Loss per Batch: 0.000004
# RL Epoch 36/150, Average Loss per Batch: 0.000004
# RL Epoch 37/150, Average Loss per Batch: 0.000004
# RL Epoch 38/150, Average Loss per Batch: 0.000004
# RL Epoch 39/150, Average Loss per Batch: 0.000005
# RL Epoch 40/150, Average Loss per Batch: 0.000006
# RL Epoch 41/150, Average Loss per Batch: 0.000013
# RL Epoch 42/150, Average Loss per Batch: 0.000024
# RL Epoch 43/150, Average Loss per Batch: 0.000063
# RL Epoch 44/150, Average Loss per Batch: 0.000068
# RL Epoch 45/150, Average Loss per Batch: 0.000061
# RL Epoch 46/150, Average Loss per Batch: 0.000067
# RL Epoch 47/150, Average Loss per Batch: 0.000028
# RL Epoch 48/150, Average Loss per Batch: 0.000013
# RL Epoch 49/150, Average Loss per Batch: 0.000015
# RL Epoch 50/150, Average Loss per Batch: 0.000013
# RL Epoch 51/150, Average Loss per Batch: 0.000010
# RL Epoch 52/150, Average Loss per Batch: 0.000017
# RL Epoch 53/150, Average Loss per Batch: 0.000010
# RL Epoch 54/150, Average Loss per Batch: 0.000010
# RL Epoch 55/150, Average Loss per Batch: 0.000020
# RL Epoch 56/150, Average Loss per Batch: 0.000010
# RL Epoch 57/150, Average Loss per Batch: 0.000013
# RL Epoch 58/150, Average Loss per Batch: 0.000020
# RL Epoch 59/150, Average Loss per Batch: 0.000011
# RL Epoch 60/150, Average Loss per Batch: 0.000011
# RL Epoch 61/150, Average Loss per Batch: 0.000012
# RL Epoch 62/150, Average Loss per Batch: 0.000011
# RL Epoch 63/150, Average Loss per Batch: 0.000008
# RL Epoch 64/150, Average Loss per Batch: 0.000007
# RL Epoch 65/150, Average Loss per Batch: 0.000013
# RL Epoch 66/150, Average Loss per Batch: 0.000007
# RL Epoch 67/150, Average Loss per Batch: 0.000009
# RL Epoch 68/150, Average Loss per Batch: 0.000014
# RL Epoch 69/150, Average Loss per Batch: 0.000009
# RL Epoch 70/150, Average Loss per Batch: 0.000010
# RL Epoch 71/150, Average Loss per Batch: 0.000010
# RL Epoch 72/150, Average Loss per Batch: 0.000010
# RL Epoch 73/150, Average Loss per Batch: 0.000007
# RL Epoch 74/150, Average Loss per Batch: 0.000006
# RL Epoch 75/150, Average Loss per Batch: 0.000011
# RL Epoch 76/150, Average Loss per Batch: 0.000007
# RL Epoch 77/150, Average Loss per Batch: 0.000007
# RL Epoch 78/150, Average Loss per Batch: 0.000009
# RL Epoch 79/150, Average Loss per Batch: 0.000008
# RL Epoch 80/150, Average Loss per Batch: 0.000006
# RL Epoch 81/150, Average Loss per Batch: 0.000005
# RL Epoch 82/150, Average Loss per Batch: 0.000007
# RL Epoch 83/150, Average Loss per Batch: 0.000005
# RL Epoch 84/150, Average Loss per Batch: 0.000004
# RL Epoch 85/150, Average Loss per Batch: 0.000005
# RL Epoch 86/150, Average Loss per Batch: 0.000005
# RL Epoch 87/150, Average Loss per Batch: 0.000004
# RL Epoch 88/150, Average Loss per Batch: 0.000004
# RL Epoch 89/150, Average Loss per Batch: 0.000004
# RL Epoch 90/150, Average Loss per Batch: 0.000004
# RL Epoch 91/150, Average Loss per Batch: 0.000003
# RL Epoch 92/150, Average Loss per Batch: 0.000003
# RL Epoch 93/150, Average Loss per Batch: 0.000003
# RL Epoch 94/150, Average Loss per Batch: 0.000004
# RL Epoch 95/150, Average Loss per Batch: 0.000003
# RL Epoch 96/150, Average Loss per Batch: 0.000003
# RL Epoch 97/150, Average Loss per Batch: 0.000003
# RL Epoch 98/150, Average Loss per Batch: 0.000003
# RL Epoch 99/150, Average Loss per Batch: 0.000003
# RL Epoch 100/150, Average Loss per Batch: 0.000003
# RL Epoch 101/150, Average Loss per Batch: 0.000003
# RL Epoch 102/150, Average Loss per Batch: 0.000003
# RL Epoch 103/150, Average Loss per Batch: 0.000003
# RL Epoch 104/150, Average Loss per Batch: 0.000004
# RL Epoch 105/150, Average Loss per Batch: 0.000004
# RL Epoch 106/150, Average Loss per Batch: 0.000007
# RL Epoch 107/150, Average Loss per Batch: 0.000012
# RL Epoch 108/150, Average Loss per Batch: 0.000022
# RL Epoch 109/150, Average Loss per Batch: 0.000049
# RL Epoch 110/150, Average Loss per Batch: 0.000063
# RL Epoch 111/150, Average Loss per Batch: 0.000100
# RL Epoch 112/150, Average Loss per Batch: 0.000076
# RL Epoch 113/150, Average Loss per Batch: 0.000038
# RL Epoch 114/150, Average Loss per Batch: 0.000020
# RL Epoch 115/150, Average Loss per Batch: 0.000010
# RL Epoch 116/150, Average Loss per Batch: 0.000010
# RL Epoch 117/150, Average Loss per Batch: 0.000013
# RL Epoch 118/150, Average Loss per Batch: 0.000009
# RL Epoch 119/150, Average Loss per Batch: 0.000007
# RL Epoch 120/150, Average Loss per Batch: 0.000008
# RL Epoch 121/150, Average Loss per Batch: 0.000010
# RL Epoch 122/150, Average Loss per Batch: 0.000006
# RL Epoch 123/150, Average Loss per Batch: 0.000006
# RL Epoch 124/150, Average Loss per Batch: 0.000011
# RL Epoch 125/150, Average Loss per Batch: 0.000007
# RL Epoch 126/150, Average Loss per Batch: 0.000007
# RL Epoch 127/150, Average Loss per Batch: 0.000009
# RL Epoch 128/150, Average Loss per Batch: 0.000009
# RL Epoch 129/150, Average Loss per Batch: 0.000006
# RL Epoch 130/150, Average Loss per Batch: 0.000006
# RL Epoch 131/150, Average Loss per Batch: 0.000009
# RL Epoch 132/150, Average Loss per Batch: 0.000005
# RL Epoch 133/150, Average Loss per Batch: 0.000005
# RL Epoch 134/150, Average Loss per Batch: 0.000007
# RL Epoch 135/150, Average Loss per Batch: 0.000007
# RL Epoch 136/150, Average Loss per Batch: 0.000005
# RL Epoch 137/150, Average Loss per Batch: 0.000005
# RL Epoch 138/150, Average Loss per Batch: 0.000006
# RL Epoch 139/150, Average Loss per Batch: 0.000005
# RL Epoch 140/150, Average Loss per Batch: 0.000004
# RL Epoch 141/150, Average Loss per Batch: 0.000004
# RL Epoch 142/150, Average Loss per Batch: 0.000005
# RL Epoch 143/150, Average Loss per Batch: 0.000004
# RL Epoch 144/150, Average Loss per Batch: 0.000004
# RL Epoch 145/150, Average Loss per Batch: 0.000004
# RL Epoch 146/150, Average Loss per Batch: 0.000004
# RL Epoch 147/150, Average Loss per Batch: 0.000004
# RL Epoch 148/150, Average Loss per Batch: 0.000004
# RL Epoch 149/150, Average Loss per Batch: 0.000004
# RL Epoch 150/150, Average Loss per Batch: 0.000004
# --- RL Fine-Tuning Complete ---
#
#  Training Set Performance Metrics (RNN):
#  Mean Absolute Error (MAE) : ₹2.29
#  Mean Squared Error (MSE)  : ₹8.37
#  Root Squared Error (RMSE) : ₹2.89
#  R² Score                  : 0.9998
#  Mean Absolute Percentage Error (MAPE) : 0.17%
#  Accuracy (100 - MAPE) : 99.83%
#  MSE Percentage of Average Price : 0.61%
#  MAE Percentage of Average Price : 0.17%
#
#  Validation Set Performance Metrics (RNN):
#  Mean Absolute Error (MAE) : ₹63.62
#  Mean Squared Error (MSE)  : ₹5928.72
#  Root Squared Error (RMSE) : ₹77.00
#  R² Score                  : 0.7631
#  Mean Absolute Percentage Error (MAPE) : 3.54%
#  Accuracy (100 - MAPE) : 96.46%
#  MSE Percentage of Average Price: 340.50%
#  MAE Percentage of Average Price: 3.65%
#
#  Prediction for 2025-06-18:
#  Predicted Closing Price: ₹1647.13
#  Actual Closing Price   : ₹1632.9000244140625
#  Test Set Performance Metrics (RNN):
#  Mean Absolute Error (MAE) : ₹18.33
#  Mean Squared Error (MSE)  : ₹544.09
#  Root Squared Error (RMSE) : ₹23.33
#  R² Score                  : 0.3619
#  Mean Absolute Percentage Error (MAPE) : 1.15%
#  Accuracy (100 - MAPE) : 98.85%
#  MSE Percentage of Average Price: 34.09%
#  MAE Percentage of Average Price: 1.15%

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import SimpleRNN
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from matplotlib.dates import DateFormatter
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import numpy as np
import pandas as pd
import datetime
import holidays
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import warnings

warnings.filterwarnings('ignore')

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

SYMBOL = "INFY.NS"
SEQUENCE_LENGTH = 60

TRAIN_START_DATE = "2020-06-01"
TRAIN_END_DATE = "2025-05-31"

TEST_START_DATE = "2025-06-01"
TEST_END_DATE = "2025-07-01"

# Get Indian trading holidays
def get_nse_holidays():
    in_holidays = holidays.India(years=range(2020, 2026))
    return set(in_holidays.keys())

TRADING_HOLIDAYS = get_nse_holidays()

def is_valid_date(date_str):
    try:
        date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
        if not (datetime.date(2025, 6, 1) <= date <= datetime.date(2025, 7, 1)):
            print("Date must be between 2025-06-01 and 2025-07-01.")
            return False
        if date.weekday() >= 5:
            print("Weekends are not trading days.")
            return False
        if date in TRADING_HOLIDAYS:
            print("Entered date is a trading holiday.")
            return False
        return True
    except ValueError:
        print("Invalid date format. Use YYYY-MM-DD.")
        return False

def get_stock_data():
    print("Fetching data from Yahoo Finance...")
    full_df = yf.download(SYMBOL, start=TRAIN_START_DATE, end=TEST_END_DATE)
    full_df = full_df[['Close']]
    full_df.dropna(inplace=True)
    full_df.index = pd.to_datetime(full_df.index)

    train_df = full_df.loc[TRAIN_START_DATE:TRAIN_END_DATE]
    test_df = full_df.loc[TEST_START_DATE:TEST_END_DATE]
    return train_df, test_df, full_df

# Prompt until valid date is entered
def get_user_date():
    while True:
        date_input = input("Enter a date (YYYY-MM-DD): ")
        if is_valid_date(date_input):
            return datetime.datetime.strptime(date_input, "%Y-%m-%d").date()

# Build the SimpleRNN model
def build_model(input_shape, learning_rate=0.001): # Added learning_rate parameter
    model = Sequential()
    model.add(SimpleRNN(units=50, activation='tanh', input_shape=input_shape))
    model.add(Dense(1))
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate) # Use custom learning rate
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# Reinforcement Learning Fine-Tuning
class RLAgent:
    """
    A simple RL Agent to fine-tune the RNN model.
    The "environment" is the time series data, and the "action" is the prediction.
    The reward is based on prediction accuracy.
    """
    def __init__(self, model, learning_rate=0.001):
        self.model = model
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate) # Pass learning_rate to RLAgent

    @tf.function
    def train_step(self, state, target):
        """
        Performs a single training step to fine-tune the model weights.
        """
        with tf.GradientTape() as tape:
            prediction = self.model(state, training=True)
            # Use Mean Squared Error directly as the loss to minimize
            loss = tf.reduce_mean(tf.square(tf.cast(target, tf.float32) - prediction))

        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss # Return the mean loss for the batch


def fine_tune_with_rl(model, X_train, y_train, epochs=5, learning_rate=0.001, batch_size=32):
    """
    Fine- tunes the pre-trained RNN model using a simple reinforcement learning loop with batched data.
    """
    print("\n--- Starting Reinforcement Learning Fine-Tuning (Batched) ---")
    agent = RLAgent(model, learning_rate=learning_rate)

    # Create a TensorFlow Dataset and batch it
    dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    dataset = dataset.batch(batch_size)

    num_batches = tf.data.experimental.cardinality(dataset).numpy()

    for epoch in range(epochs):
        total_loss = 0
        batch_count = 0
        for batch_x, batch_y in dataset:
            # Ensure batch_x has the correct shape (batch_size, sequence_length, 1)
            batch_x_reshaped = tf.reshape(batch_x, (tf.shape(batch_x)[0], tf.shape(batch_x)[1], 1))
            loss = agent.train_step(batch_x_reshaped, batch_y)
            total_loss += loss.numpy() # Sum up the mean loss for each batch
            batch_count += 1

        # Calculate average loss per epoch
        average_epoch_loss = total_loss / num_batches if num_batches > 0 else 0
        print(f"RL Epoch {epoch + 1}/{epochs}, Average Loss per Batch: {average_epoch_loss:.6f}") # Print average loss

    print("--- RL Fine-Tuning Complete ---")
    return model


def create_test_sequences(train_df, test_df, scaler):
    combined = pd.concat([train_df, test_df])
    scaled = scaler.transform(combined[['Close']])
    X_test = []
    test_dates = test_df.index.date

    for i in range(len(train_df), len(combined)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled[i - SEQUENCE_LENGTH:i]
        X_test.append(seq)

    X_test = np.array(X_test)
    return X_test, test_dates

def predict_price_on_test(model, full_df, scaler, user_date):
    all_dates = full_df.index.date
    try:
        idx = list(all_dates).index(user_date)
    except ValueError:
        print("User date not found in data.")
        return None, None, user_date

    if idx < SEQUENCE_LENGTH:
        print("Not enough data to predict for this date.")
        return None, None, user_date

    input_seq = scaler.transform(full_df[['Close']].values)[idx - SEQUENCE_LENGTH:idx]
    input_seq = np.reshape(input_seq, (1, SEQUENCE_LENGTH, 1))

    predicted_scaled = model.predict(input_seq, verbose=0)
    predicted_price = scaler.inverse_transform(predicted_scaled)[0][0]

    actual_price = float(full_df.iloc[idx]['Close']) if idx < len(full_df) else None
    return predicted_price, actual_price, full_df.index[idx].date()

# Plot the result
def plot_results(df, predicted_date, predicted_price, actual_price):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Historical Close Price',zorder=1)
    #plt.axvline(pd.to_datetime(predicted_date), color='red', linestyle='--', label='Predicted Date')
    plt.scatter(pd.to_datetime(predicted_date), predicted_price, color='orange', label='Predicted Price',zorder=2)
    if actual_price is not None:
        plt.scatter(pd.to_datetime(predicted_date), actual_price, color='green', label='Actual Price',zorder=3, s=100)
    plt.title("INFOSYS Stock Price with Prediction (yfinance)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#Plotting error with no. of epochs
def plot_training_loss(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title("Training and Validation Loss Over Epochs (RNN)")
    plt.xlabel("Epoch no.")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def main():
    print("=== INFOSYS LSTM Stock Price Predictor (Test Phase June–July 2025) ===")
    user_date = get_user_date()

    # Step 1: Get stock data
    train_df, test_df, full_df = get_stock_data()

    # Step 2: Preprocess
    scaler = MinMaxScaler()
    scaled_train = scaler.fit_transform(train_df[['Close']])
    X, y = [], []
    for i in range(SEQUENCE_LENGTH, len(scaled_train)):
        X.append(scaled_train[i - SEQUENCE_LENGTH:i])
        y.append(scaled_train[i])
    X = np.array(X)
    y = np.array(y)

    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
    #early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    # Step 3: Build and train model
    model = build_model((X_train.shape[1], 1), learning_rate=0.0005) # Reduced Adam learning rate
    print("Training RNN model...")
    history = model.fit(X_train, y_train, epochs=7000, batch_size=64, validation_data=(X_val, y_val), verbose = 1) #callbacks = [early_stop], verbose=1)

    #print(f"\nBest weights restored from epoch: {early_stop.best_epoch + 1}")

    # Step 4: Plot training loss
    plot_training_loss(history)

    # Step 5: Fine-tune with Reinforcement Learning
    rl_tuned_model = fine_tune_with_rl(model, X_train, y_train, epochs=200, learning_rate=0.0001, batch_size=32)

    # Predict on training data to evaluate performance
    y_train_pred_scaled = rl_tuned_model.predict(X_train, verbose=0)
    y_train_pred = scaler.inverse_transform(y_train_pred_scaled)
    y_true_train = scaler.inverse_transform(y_train.reshape(-1, 1))

    # Calculate and print training metrics
    mae_train = mean_absolute_error(y_true_train, y_train_pred)
    mse_train = mean_squared_error(y_true_train, y_train_pred)
    rmse_train = np.sqrt(mse_train)
    r2_train = r2_score(y_true_train, y_train_pred)
    mape_train = mean_absolute_percentage_error(y_true_train, y_train_pred) * 100
    accuracy_train = 100 - mape_train
    mse_percent_train = (mse_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    mae_percent_train = (mae_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    print("\n Training Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_train:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_train:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_train:.2f}")
    print(f" R² Score                  : {r2_train:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_train:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_train:.2f}%")
    print(f" MSE Percentage of Average Price : {mse_percent_train:.2f}%")
    print(f" MAE Percentage of Average Price : {mae_percent_train:.2f}%")

    # Predict on validation set
    y_val_pred_scaled = rl_tuned_model.predict(X_val, verbose=0)
    y_val_pred = scaler.inverse_transform(y_val_pred_scaled)
    y_val_true = scaler.inverse_transform(y_val.reshape(-1, 1))

    # Calculate and print validation metrics
    mae_val = mean_absolute_error(y_val_true, y_val_pred)
    mse_val = mean_squared_error(y_val_true, y_val_pred)
    rmse_val = np.sqrt(mse_val)
    r2_val = r2_score(y_val_true, y_val_pred)
    mape_val = mean_absolute_percentage_error(y_val_true, y_val_pred) * 100
    accuracy_val = 100 - mape_val
    mse_percent_val = (mse_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    mae_percent_val = (mae_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    print("\n Validation Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_val:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_val:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_val:.2f}")
    print(f" R² Score                  : {r2_val:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_val:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_val:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_val:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_val:.2f}%")


    # Step 6: Predict for user-input test date
    predicted_price, actual_price, predicted_date = predict_price_on_test(rl_tuned_model, full_df, scaler, user_date)
    if predicted_price is not None:
        print(f"\n Prediction for {predicted_date}:")
        print(f" Predicted Closing Price: ₹{predicted_price:.2f}")
        if actual_price is not None:
            print(f" Actual Closing Price   : ₹{actual_price}")
        else:
            print("Actual price not available.")

        plot_results(full_df, predicted_date, predicted_price, actual_price)
    else:
        print("❌ Unable to make prediction.")

    # === Step 7: Predict all test dates and compare ===

    # Reuse combined full_df
    combined_df = pd.concat([train_df, test_df])
    scaled_combined = scaler.transform(combined_df[['Close']])

    X_test_all = []
    test_date_indexes = []

    for i in range(len(train_df), len(combined_df)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled_combined[i - SEQUENCE_LENGTH:i]
        X_test_all.append(seq)
        test_date_indexes.append(combined_df.index[i])

    X_test_all = np.array(X_test_all)

    # Predict on test sequences
    y_test_pred_scaled = rl_tuned_model.predict(X_test_all, verbose=0)
    y_test_pred = scaler.inverse_transform(y_test_pred_scaled)

    # Actual prices
    y_test_true = test_df.loc[test_date_indexes, 'Close'].values

    # Calculate and print test metrics
    mae_test = mean_absolute_error(y_test_true, y_test_pred)
    mse_test = mean_squared_error(y_test_true, y_test_pred)
    rmse_test = np.sqrt(mse_test)
    r2_test = r2_score(y_test_true, y_test_pred)
    mape_test = mean_absolute_percentage_error(y_test_true, y_test_pred) * 100
    accuracy_test = 100 - mape_test
    mse_percent_test = (mse_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    mae_percent_test = (mae_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    print("\n Test Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_test:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_test:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_test:.2f}")
    print(f" R² Score                  : {r2_test:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_test:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_test:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_test:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_test:.2f}%")

    # Plot actual vs predicted
    plt.figure(figsize=(12, 6))
    plt.plot(test_date_indexes, y_test_true, label='Actual Price')
    plt.plot(test_date_indexes, y_test_pred, label='Predicted Price')
    plt.title("Actual vs Predicted INFY Closing Prices (01-Jun to 01-Jul 2025)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.xticks(rotation=45)
    plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# === INFOSYS LSTM Stock Price Predictor (Test Phase June–July 2025) ===
# [*********************100%***********************]  1 of 1 completed
# Fetching data from Yahoo Finance...
# Training RNN model...
# Streaming output truncated to the last 5000 lines.
# Epoch 4501/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.1599e-04 - val_loss: 0.0015
# Epoch 4502/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.2145e-04 - val_loss: 0.0012
# Epoch 4503/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.1309e-04 - val_loss: 0.0016
# Epoch 4504/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.2437e-04 - val_loss: 0.0012
# Epoch 4505/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.0733e-04 - val_loss: 0.0013
# Epoch 4506/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.1095e-04 - val_loss: 0.0013
# Epoch 4507/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.0860e-04 - val_loss: 0.0012
# Epoch 4508/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.0388e-04 - val_loss: 0.0014
# Epoch 4509/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.4380e-05 - val_loss: 0.0012
# Epoch 4510/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.7389e-05 - val_loss: 0.0014
# Epoch 4511/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.8944e-05 - val_loss: 0.0012
# Epoch 4512/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.6922e-05 - val_loss: 0.0014
# Epoch 4513/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.0153e-04 - val_loss: 0.0012
# Epoch 4514/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.0283e-04 - val_loss: 0.0014
# Epoch 4515/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.0879e-04 - val_loss: 0.0012
# Epoch 4516/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.0355e-04 - val_loss: 0.0014
# Epoch 4517/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.1345e-04 - val_loss: 0.0012
# Epoch 4518/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.8653e-05 - val_loss: 0.0013
# Epoch 4519/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 9.8967e-05 - val_loss: 0.0013
# Epoch 4520/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 9.4457e-05 - val_loss: 0.0013
# Epoch 4521/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 9.4890e-05 - val_loss: 0.0013
# Epoch 4522/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 8.4717e-05 - val_loss: 0.0012
# Epoch 4523/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 8.5923e-05 - val_loss: 0.0014
# Epoch 4524/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.5843e-05 - val_loss: 0.0013
# Epoch 4525/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.7841e-05 - val_loss: 0.0014
# Epoch 4526/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 9.0075e-05 - val_loss: 0.0012
# Epoch 4527/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.9384e-05 - val_loss: 0.0014
# Epoch 4528/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.4369e-05 - val_loss: 0.0013
# Epoch 4529/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.3507e-05 - val_loss: 0.0014
# Epoch 4530/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.0235e-04 - val_loss: 0.0013
# Epoch 4531/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.9040e-05 - val_loss: 0.0014
# Epoch 4532/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.0771e-04 - val_loss: 0.0012
# Epoch 4533/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.5625e-05 - val_loss: 0.0013
# Epoch 4534/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.6585e-05 - val_loss: 0.0013
# Epoch 4535/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.5311e-05 - val_loss: 0.0012
# Epoch 4536/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 9.2818e-05 - val_loss: 0.0014
# Epoch 4537/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8.9560e-05 - val_loss: 0.0011
# Epoch 4538/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.9656e-05 - val_loss: 0.0013
# Epoch 4539/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.9360e-05 - val_loss: 0.0012
# Epoch 4540/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.2434e-05 - val_loss: 0.0013
# Epoch 4541/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.7284e-05 - val_loss: 0.0012
# Epoch 4542/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 8.2385e-05 - val_loss: 0.0012
# Epoch 4543/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 8.0399e-05 - val_loss: 0.0013
# Epoch 4544/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 8.3752e-05 - val_loss: 0.0012
# Epoch 4545/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.6225e-05 - val_loss: 0.0013
# Epoch 4546/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.0741e-05 - val_loss: 0.0012
# Epoch 4547/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.9386e-05 - val_loss: 0.0012
# Epoch 4548/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.9992e-05 - val_loss: 0.0012
# Epoch 4549/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.9022e-05 - val_loss: 0.0013
# Epoch 4550/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.5127e-05 - val_loss: 0.0011
# Epoch 4551/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.0353e-05 - val_loss: 0.0013
# Epoch 4552/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.5001e-05 - val_loss: 0.0011
# Epoch 4553/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 8.9481e-05 - val_loss: 0.0013
# Epoch 4554/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.0966e-05 - val_loss: 0.0011
# Epoch 4555/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 7.7163e-05 - val_loss: 0.0012
# Epoch 4556/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.8289e-05 - val_loss: 0.0012
# Epoch 4557/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.7632e-05 - val_loss: 0.0012
# Epoch 4558/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.9182e-05 - val_loss: 0.0013
# Epoch 4559/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.8864e-05 - val_loss: 0.0012
# Epoch 4560/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.1670e-05 - val_loss: 0.0012
# Epoch 4561/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.1529e-05 - val_loss: 0.0012
# Epoch 4562/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 7.4913e-05 - val_loss: 0.0012
# Epoch 4563/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 7.4741e-05 - val_loss: 0.0013
# Epoch 4564/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 7.8825e-05 - val_loss: 0.0012
# Epoch 4565/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.7089e-05 - val_loss: 0.0012
# Epoch 4566/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.6099e-05 - val_loss: 0.0012
# Epoch 4567/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.3273e-05 - val_loss: 0.0011
# Epoch 4568/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 7.3069e-05 - val_loss: 0.0012
# Epoch 4569/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.2294e-05 - val_loss: 0.0011
# Epoch 4570/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 7.5749e-05 - val_loss: 0.0012
# Epoch 4571/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.9276e-05 - val_loss: 0.0011
# Epoch 4572/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.5226e-05 - val_loss: 0.0011
# Epoch 4573/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 7.0208e-05 - val_loss: 0.0012
# Epoch 4574/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 7.3522e-05 - val_loss: 0.0012
# Epoch 4575/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 6.9253e-05 - val_loss: 0.0012
# Epoch 4576/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.2266e-05 - val_loss: 0.0012
# Epoch 4577/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.7829e-05 - val_loss: 0.0012
# Epoch 4578/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 7.0446e-05 - val_loss: 0.0012
# Epoch 4579/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.4437e-05 - val_loss: 0.0012
# Epoch 4580/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.6204e-05 - val_loss: 0.0012
# Epoch 4581/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.1622e-05 - val_loss: 0.0012
# Epoch 4582/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 6.1809e-05 - val_loss: 0.0012
# Epoch 4583/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.8393e-05 - val_loss: 0.0012
# Epoch 4584/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.1336e-05 - val_loss: 0.0013
# Epoch 4585/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 5.7946e-05 - val_loss: 0.0012
# Epoch 4586/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 6.1553e-05 - val_loss: 0.0013
# Epoch 4587/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.8969e-05 - val_loss: 0.0013
# Epoch 4588/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 6.2133e-05 - val_loss: 0.0013
# Epoch 4589/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.0402e-05 - val_loss: 0.0013
# Epoch 4590/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.1858e-05 - val_loss: 0.0012
# Epoch 4591/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 6.2601e-05 - val_loss: 0.0013
# Epoch 4592/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.2503e-05 - val_loss: 0.0012
# Epoch 4593/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.3576e-05 - val_loss: 0.0012
# Epoch 4594/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.4216e-05 - val_loss: 0.0012
# Epoch 4595/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.4495e-05 - val_loss: 0.0012
# Epoch 4596/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.4503e-05 - val_loss: 0.0011
# Epoch 4597/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.6891e-05 - val_loss: 0.0011
# Epoch 4598/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.2286e-05 - val_loss: 0.0011
# Epoch 4599/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.4089e-05 - val_loss: 0.0011
# Epoch 4600/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.7639e-05 - val_loss: 0.0011
# Epoch 4601/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.5481e-05 - val_loss: 0.0011
# Epoch 4602/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.2961e-05 - val_loss: 0.0011
# Epoch 4603/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.9147e-05 - val_loss: 0.0011
# Epoch 4604/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.8393e-05 - val_loss: 0.0011
# Epoch 4605/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.6526e-05 - val_loss: 0.0011
# Epoch 4606/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.6420e-05 - val_loss: 0.0011
# Epoch 4607/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.8135e-05 - val_loss: 0.0011
# Epoch 4608/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.9633e-05 - val_loss: 0.0011
# Epoch 4609/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.4264e-05 - val_loss: 0.0012
# Epoch 4610/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.9196e-05 - val_loss: 0.0012
# Epoch 4611/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.2338e-05 - val_loss: 0.0012
# Epoch 4612/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 6.1420e-05 - val_loss: 0.0013
# Epoch 4613/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.7450e-05 - val_loss: 0.0013
# Epoch 4614/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.5817e-05 - val_loss: 0.0013
# Epoch 4615/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.0852e-05 - val_loss: 0.0013
# Epoch 4616/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.2134e-05 - val_loss: 0.0012
# Epoch 4617/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.7341e-05 - val_loss: 0.0012
# Epoch 4618/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.3577e-05 - val_loss: 0.0013
# Epoch 4619/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.5152e-05 - val_loss: 0.0013
# Epoch 4620/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.4155e-05 - val_loss: 0.0013
# Epoch 4621/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.3972e-05 - val_loss: 0.0013
# Epoch 4622/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.9552e-05 - val_loss: 0.0012
# Epoch 4623/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.1866e-05 - val_loss: 0.0012
# Epoch 4624/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.0678e-05 - val_loss: 0.0013
# Epoch 4625/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.7482e-05 - val_loss: 0.0013
# Epoch 4626/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.5161e-05 - val_loss: 0.0013
# Epoch 4627/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4903e-05 - val_loss: 0.0013
# Epoch 4628/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.5224e-05 - val_loss: 0.0013
# Epoch 4629/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.4589e-05 - val_loss: 0.0013
# Epoch 4630/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2461e-05 - val_loss: 0.0013
# Epoch 4631/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.9214e-05 - val_loss: 0.0013
# Epoch 4632/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.6339e-05 - val_loss: 0.0013
# Epoch 4633/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.5064e-05 - val_loss: 0.0013
# Epoch 4634/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.4544e-05 - val_loss: 0.0013
# Epoch 4635/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.4083e-05 - val_loss: 0.0013
# Epoch 4636/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.3674e-05 - val_loss: 0.0013
# Epoch 4637/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.3395e-05 - val_loss: 0.0013
# Epoch 4638/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.3288e-05 - val_loss: 0.0013
# Epoch 4639/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.3220e-05 - val_loss: 0.0013
# Epoch 4640/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.3007e-05 - val_loss: 0.0013
# Epoch 4641/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.2692e-05 - val_loss: 0.0013
# Epoch 4642/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.2421e-05 - val_loss: 0.0013
# Epoch 4643/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.2279e-05 - val_loss: 0.0013
# Epoch 4644/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.2228e-05 - val_loss: 0.0013
# Epoch 4645/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.2250e-05 - val_loss: 0.0013
# Epoch 4646/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.2364e-05 - val_loss: 0.0013
# Epoch 4647/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.2592e-05 - val_loss: 0.0013
# Epoch 4648/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.2902e-05 - val_loss: 0.0013
# Epoch 4649/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.3262e-05 - val_loss: 0.0013
# Epoch 4650/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 3.3662e-05 - val_loss: 0.0013
# Epoch 4651/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.4140e-05 - val_loss: 0.0013
# Epoch 4652/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 3.4759e-05 - val_loss: 0.0014
# Epoch 4653/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.5589e-05 - val_loss: 0.0014
# Epoch 4654/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 3.6710e-05 - val_loss: 0.0014
# Epoch 4655/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.8212e-05 - val_loss: 0.0014
# Epoch 4656/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.0208e-05 - val_loss: 0.0014
# Epoch 4657/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.2833e-05 - val_loss: 0.0014
# Epoch 4658/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.6288e-05 - val_loss: 0.0014
# Epoch 4659/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.0923e-05 - val_loss: 0.0014
# Epoch 4660/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.7317e-05 - val_loss: 0.0014
# Epoch 4661/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6.6378e-05 - val_loss: 0.0013
# Epoch 4662/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.2828e-05 - val_loss: 0.0012
# Epoch 4663/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.1733e-05 - val_loss: 0.0012
# Epoch 4664/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.4735e-05 - val_loss: 0.0011
# Epoch 4665/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.4125e-05 - val_loss: 0.0012
# Epoch 4666/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.1344e-05 - val_loss: 0.0013
# Epoch 4667/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.5036e-05 - val_loss: 0.0013
# Epoch 4668/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.1592e-05 - val_loss: 0.0013
# Epoch 4669/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.6629e-05 - val_loss: 0.0013
# Epoch 4670/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.7229e-05 - val_loss: 0.0012
# Epoch 4671/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.8351e-05 - val_loss: 0.0012
# Epoch 4672/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.8620e-05 - val_loss: 0.0012
# Epoch 4673/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.8465e-05 - val_loss: 0.0012
# Epoch 4674/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.8685e-05 - val_loss: 0.0012
# Epoch 4675/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 3.7222e-05 - val_loss: 0.0012
# Epoch 4676/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.5860e-05 - val_loss: 0.0012
# Epoch 4677/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 3.5260e-05 - val_loss: 0.0012
# Epoch 4678/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.5392e-05 - val_loss: 0.0012
# Epoch 4679/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.5462e-05 - val_loss: 0.0012
# Epoch 4680/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.6032e-05 - val_loss: 0.0012
# Epoch 4681/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.7175e-05 - val_loss: 0.0013
# Epoch 4682/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.7573e-05 - val_loss: 0.0013
# Epoch 4683/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.7271e-05 - val_loss: 0.0013
# Epoch 4684/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.6717e-05 - val_loss: 0.0013
# Epoch 4685/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.6347e-05 - val_loss: 0.0013
# Epoch 4686/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.6372e-05 - val_loss: 0.0013
# Epoch 4687/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.6931e-05 - val_loss: 0.0013
# Epoch 4688/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.8154e-05 - val_loss: 0.0013
# Epoch 4689/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.0810e-05 - val_loss: 0.0013
# Epoch 4690/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.5735e-05 - val_loss: 0.0013
# Epoch 4691/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.2133e-05 - val_loss: 0.0013
# Epoch 4692/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.8114e-05 - val_loss: 0.0013
# Epoch 4693/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.6211e-05 - val_loss: 0.0013
# Epoch 4694/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.0186e-05 - val_loss: 0.0014
# Epoch 4695/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.6269e-05 - val_loss: 0.0014
# Epoch 4696/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.4787e-05 - val_loss: 0.0014
# Epoch 4697/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.5969e-05 - val_loss: 0.0014
# Epoch 4698/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.9331e-05 - val_loss: 0.0015
# Epoch 4699/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 5.2802e-05 - val_loss: 0.0015
# Epoch 4700/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.3356e-05 - val_loss: 0.0014
# Epoch 4701/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 5.0804e-05 - val_loss: 0.0013
# Epoch 4702/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.1325e-05 - val_loss: 0.0013
# Epoch 4703/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.3832e-05 - val_loss: 0.0013
# Epoch 4704/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.3277e-05 - val_loss: 0.0014
# Epoch 4705/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.9071e-05 - val_loss: 0.0014
# Epoch 4706/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.8247e-05 - val_loss: 0.0015
# Epoch 4707/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.2783e-05 - val_loss: 0.0016
# Epoch 4708/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.9060e-05 - val_loss: 0.0016
# Epoch 4709/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.5295e-05 - val_loss: 0.0017
# Epoch 4710/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.9786e-05 - val_loss: 0.0017
# Epoch 4711/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 6.2884e-05 - val_loss: 0.0016
# Epoch 4712/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.8598e-05 - val_loss: 0.0015
# Epoch 4713/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.1679e-05 - val_loss: 0.0015
# Epoch 4714/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 7.2636e-05 - val_loss: 0.0015
# Epoch 4715/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 7.3213e-05 - val_loss: 0.0015
# Epoch 4716/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.0746e-05 - val_loss: 0.0014
# Epoch 4717/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.0527e-05 - val_loss: 0.0013
# Epoch 4718/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.9313e-05 - val_loss: 0.0011
# Epoch 4719/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 8.5935e-05 - val_loss: 0.0010
# Epoch 4720/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 7.2926e-05 - val_loss: 0.0011
# Epoch 4721/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 6.1271e-05 - val_loss: 0.0012
# Epoch 4722/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 5.2218e-05 - val_loss: 0.0012
# Epoch 4723/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 4.8660e-05 - val_loss: 0.0011
# Epoch 4724/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.9297e-05 - val_loss: 0.0011
# Epoch 4725/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.0674e-05 - val_loss: 0.0011
# Epoch 4726/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.9491e-05 - val_loss: 0.0011
# Epoch 4727/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.1410e-05 - val_loss: 0.0012
# Epoch 4728/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.2203e-05 - val_loss: 0.0012
# Epoch 4729/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.9464e-05 - val_loss: 0.0012
# Epoch 4730/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.5849e-05 - val_loss: 0.0012
# Epoch 4731/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.0339e-05 - val_loss: 0.0012
# Epoch 4732/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.6867e-05 - val_loss: 0.0012
# Epoch 4733/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.3805e-05 - val_loss: 0.0012
# Epoch 4734/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.1423e-05 - val_loss: 0.0012
# Epoch 4735/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 2.9410e-05 - val_loss: 0.0013
# Epoch 4736/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.8358e-05 - val_loss: 0.0013
# Epoch 4737/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.7988e-05 - val_loss: 0.0013
# Epoch 4738/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 2.8713e-05 - val_loss: 0.0014
# Epoch 4739/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.9995e-05 - val_loss: 0.0014
# Epoch 4740/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.1195e-05 - val_loss: 0.0014
# Epoch 4741/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.2461e-05 - val_loss: 0.0014
# Epoch 4742/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.3707e-05 - val_loss: 0.0014
# Epoch 4743/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.4731e-05 - val_loss: 0.0014
# Epoch 4744/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 3.5021e-05 - val_loss: 0.0014
# Epoch 4745/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 3.5317e-05 - val_loss: 0.0014
# Epoch 4746/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.6208e-05 - val_loss: 0.0014
# Epoch 4747/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.7837e-05 - val_loss: 0.0014
# Epoch 4748/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 4.0566e-05 - val_loss: 0.0013
# Epoch 4749/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.3344e-05 - val_loss: 0.0013
# Epoch 4750/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.3613e-05 - val_loss: 0.0014
# Epoch 4751/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.2159e-05 - val_loss: 0.0014
# Epoch 4752/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.0398e-05 - val_loss: 0.0015
# Epoch 4753/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.8924e-05 - val_loss: 0.0015
# Epoch 4754/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.0194e-05 - val_loss: 0.0016
# Epoch 4755/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.3490e-05 - val_loss: 0.0015
# Epoch 4756/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.4357e-05 - val_loss: 0.0015
# Epoch 4757/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.4188e-05 - val_loss: 0.0016
# Epoch 4758/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.7576e-05 - val_loss: 0.0018
# Epoch 4759/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.3272e-05 - val_loss: 0.0018
# Epoch 4760/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.8030e-05 - val_loss: 0.0016
# Epoch 4761/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.8460e-05 - val_loss: 0.0015
# Epoch 4762/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.1892e-05 - val_loss: 0.0015
# Epoch 4763/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.8530e-05 - val_loss: 0.0015
# Epoch 4764/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.7544e-05 - val_loss: 0.0016
# Epoch 4765/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.9274e-05 - val_loss: 0.0016
# Epoch 4766/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 5.5743e-05 - val_loss: 0.0017
# Epoch 4767/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 5.8864e-05 - val_loss: 0.0016
# Epoch 4768/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 6.6663e-05 - val_loss: 0.0016
# Epoch 4769/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.4797e-05 - val_loss: 0.0015
# Epoch 4770/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.6918e-05 - val_loss: 0.0015
# Epoch 4771/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.0493e-05 - val_loss: 0.0015
# Epoch 4772/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.6546e-05 - val_loss: 0.0014
# Epoch 4773/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.4165e-05 - val_loss: 0.0012
# Epoch 4774/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 5.8316e-05 - val_loss: 0.0013
# Epoch 4775/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.4076e-05 - val_loss: 0.0011
# Epoch 4776/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.4174e-05 - val_loss: 0.0011
# Epoch 4777/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.0575e-05 - val_loss: 0.0012
# Epoch 4778/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.0836e-05 - val_loss: 0.0012
# Epoch 4779/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.6931e-05 - val_loss: 0.0013
# Epoch 4780/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.2884e-05 - val_loss: 0.0013
# Epoch 4781/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 7.0531e-05 - val_loss: 0.0013
# Epoch 4782/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.1552e-05 - val_loss: 0.0012
# Epoch 4783/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.2860e-05 - val_loss: 0.0013
# Epoch 4784/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.1431e-05 - val_loss: 0.0014
# Epoch 4785/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.6662e-05 - val_loss: 0.0013
# Epoch 4786/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.5396e-05 - val_loss: 0.0012
# Epoch 4787/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.4172e-05 - val_loss: 0.0013
# Epoch 4788/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.4079e-05 - val_loss: 0.0013
# Epoch 4789/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.4522e-05 - val_loss: 0.0013
# Epoch 4790/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.5292e-05 - val_loss: 0.0013
# Epoch 4791/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.3695e-05 - val_loss: 0.0013
# Epoch 4792/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.1964e-05 - val_loss: 0.0013
# Epoch 4793/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.1083e-05 - val_loss: 0.0013
# Epoch 4794/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.1867e-05 - val_loss: 0.0013
# Epoch 4795/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.2712e-05 - val_loss: 0.0013
# Epoch 4796/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.3247e-05 - val_loss: 0.0014
# Epoch 4797/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.7192e-05 - val_loss: 0.0014
# Epoch 4798/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.4410e-05 - val_loss: 0.0014
# Epoch 4799/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.7764e-05 - val_loss: 0.0014
# Epoch 4800/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.1137e-05 - val_loss: 0.0013
# Epoch 4801/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.4323e-05 - val_loss: 0.0014
# Epoch 4802/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.5102e-05 - val_loss: 0.0014
# Epoch 4803/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.8753e-05 - val_loss: 0.0014
# Epoch 4804/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.5438e-05 - val_loss: 0.0014
# Epoch 4805/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.3131e-05 - val_loss: 0.0014
# Epoch 4806/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.4538e-05 - val_loss: 0.0014
# Epoch 4807/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.2538e-05 - val_loss: 0.0015
# Epoch 4808/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.6448e-05 - val_loss: 0.0015
# Epoch 4809/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.2950e-05 - val_loss: 0.0015
# Epoch 4810/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.1626e-05 - val_loss: 0.0015
# Epoch 4811/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 3.2479e-05 - val_loss: 0.0015
# Epoch 4812/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.3766e-05 - val_loss: 0.0015
# Epoch 4813/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.5325e-05 - val_loss: 0.0015
# Epoch 4814/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.6703e-05 - val_loss: 0.0015
# Epoch 4815/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.8320e-05 - val_loss: 0.0015
# Epoch 4816/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.0443e-05 - val_loss: 0.0015
# Epoch 4817/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.2190e-05 - val_loss: 0.0015
# Epoch 4818/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.6112e-05 - val_loss: 0.0015
# Epoch 4819/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.9929e-05 - val_loss: 0.0015
# Epoch 4820/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.8869e-05 - val_loss: 0.0016
# Epoch 4821/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.8373e-05 - val_loss: 0.0016
# Epoch 4822/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.0161e-05 - val_loss: 0.0016
# Epoch 4823/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.2035e-05 - val_loss: 0.0016
# Epoch 4824/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.5655e-05 - val_loss: 0.0015
# Epoch 4825/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.2815e-05 - val_loss: 0.0016
# Epoch 4826/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.4887e-05 - val_loss: 0.0016
# Epoch 4827/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.1745e-05 - val_loss: 0.0015
# Epoch 4828/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.2340e-05 - val_loss: 0.0016
# Epoch 4829/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.2096e-05 - val_loss: 0.0016
# Epoch 4830/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.3770e-05 - val_loss: 0.0016
# Epoch 4831/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.0510e-05 - val_loss: 0.0016
# Epoch 4832/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 5.9221e-05 - val_loss: 0.0017
# Epoch 4833/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.1350e-05 - val_loss: 0.0016
# Epoch 4834/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.0476e-05 - val_loss: 0.0016
# Epoch 4835/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.1872e-05 - val_loss: 0.0014
# Epoch 4836/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.6003e-05 - val_loss: 0.0016
# Epoch 4837/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 5.2895e-05 - val_loss: 0.0015
# Epoch 4838/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.5386e-05 - val_loss: 0.0016
# Epoch 4839/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.0526e-05 - val_loss: 0.0015
# Epoch 4840/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.5529e-05 - val_loss: 0.0016
# Epoch 4841/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 5.7435e-05 - val_loss: 0.0016
# Epoch 4842/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.8849e-05 - val_loss: 0.0014
# Epoch 4843/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.6571e-05 - val_loss: 0.0015
# Epoch 4844/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.3681e-05 - val_loss: 0.0015
# Epoch 4845/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.7522e-05 - val_loss: 0.0016
# Epoch 4846/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.0251e-05 - val_loss: 0.0015
# Epoch 4847/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.8968e-05 - val_loss: 0.0016
# Epoch 4848/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.3015e-05 - val_loss: 0.0016
# Epoch 4849/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 8.8092e-05 - val_loss: 0.0016
# Epoch 4850/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.1046e-04 - val_loss: 0.0018
# Epoch 4851/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.1066e-04 - val_loss: 0.0019
# Epoch 4852/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.0671e-04 - val_loss: 0.0018
# Epoch 4853/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 9.5653e-05 - val_loss: 0.0016
# Epoch 4854/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 9.6831e-05 - val_loss: 0.0016
# Epoch 4855/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 8.0098e-05 - val_loss: 0.0015
# Epoch 4856/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.6098e-05 - val_loss: 0.0018
# Epoch 4857/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.4546e-05 - val_loss: 0.0015
# Epoch 4858/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 9.5062e-05 - val_loss: 0.0017
# Epoch 4859/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.0005e-04 - val_loss: 0.0017
# Epoch 4860/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.0657e-04 - val_loss: 0.0015
# Epoch 4861/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.0245e-04 - val_loss: 0.0014
# Epoch 4862/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.2363e-05 - val_loss: 0.0014
# Epoch 4863/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.3908e-05 - val_loss: 0.0014
# Epoch 4864/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.6668e-05 - val_loss: 0.0015
# Epoch 4865/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.0745e-05 - val_loss: 0.0015
# Epoch 4866/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 8.8353e-05 - val_loss: 0.0015
# Epoch 4867/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.2910e-05 - val_loss: 0.0013
# Epoch 4868/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 7.8384e-05 - val_loss: 0.0017
# Epoch 4869/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.0800e-04 - val_loss: 0.0017
# Epoch 4870/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.0541e-04 - val_loss: 0.0016
# Epoch 4871/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.7169e-05 - val_loss: 0.0019
# Epoch 4872/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.0157e-04 - val_loss: 0.0016
# Epoch 4873/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.6635e-05 - val_loss: 0.0018
# Epoch 4874/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.7645e-05 - val_loss: 0.0016
# Epoch 4875/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 9.5214e-05 - val_loss: 0.0018
# Epoch 4876/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.8912e-05 - val_loss: 0.0016
# Epoch 4877/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 7.9503e-05 - val_loss: 0.0014
# Epoch 4878/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 8.3681e-05 - val_loss: 0.0016
# Epoch 4879/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 8.4320e-05 - val_loss: 0.0017
# Epoch 4880/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 7.4010e-05 - val_loss: 0.0014
# Epoch 4881/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 6.4434e-05 - val_loss: 0.0015
# Epoch 4882/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.1386e-05 - val_loss: 0.0016
# Epoch 4883/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.5243e-05 - val_loss: 0.0016
# Epoch 4884/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.7305e-05 - val_loss: 0.0016
# Epoch 4885/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.0300e-05 - val_loss: 0.0016
# Epoch 4886/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.1039e-05 - val_loss: 0.0015
# Epoch 4887/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.7025e-05 - val_loss: 0.0017
# Epoch 4888/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.8311e-05 - val_loss: 0.0017
# Epoch 4889/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.1898e-05 - val_loss: 0.0017
# Epoch 4890/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.1145e-05 - val_loss: 0.0017
# Epoch 4891/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.6617e-05 - val_loss: 0.0019
# Epoch 4892/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.7079e-05 - val_loss: 0.0018
# Epoch 4893/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.0122e-04 - val_loss: 0.0018
# Epoch 4894/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.2129e-04 - val_loss: 0.0014
# Epoch 4895/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.1345e-04 - val_loss: 0.0018
# Epoch 4896/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.1595e-04 - val_loss: 0.0016
# Epoch 4897/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.0705e-04 - val_loss: 0.0018
# Epoch 4898/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.1911e-04 - val_loss: 0.0018
# Epoch 4899/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.2355e-04 - val_loss: 0.0018
# Epoch 4900/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 1.0592e-04 - val_loss: 0.0015
# Epoch 4901/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.1732e-04 - val_loss: 0.0020
# Epoch 4902/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.1394e-04 - val_loss: 0.0015
# Epoch 4903/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.1513e-04 - val_loss: 0.0018
# Epoch 4904/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.3334e-04 - val_loss: 0.0016
# Epoch 4905/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.0738e-04 - val_loss: 0.0017
# Epoch 4906/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.0341e-04 - val_loss: 0.0016
# Epoch 4907/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.0361e-04 - val_loss: 0.0017
# Epoch 4908/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.4962e-04 - val_loss: 0.0016
# Epoch 4909/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.1698e-04 - val_loss: 0.0018
# Epoch 4910/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.1934e-04 - val_loss: 0.0015
# Epoch 4911/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.0004e-04 - val_loss: 0.0018
# Epoch 4912/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.1528e-04 - val_loss: 0.0017
# Epoch 4913/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1084e-04 - val_loss: 0.0016
# Epoch 4914/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.3849e-04 - val_loss: 0.0017
# Epoch 4915/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1488e-04 - val_loss: 0.0020
# Epoch 4916/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.2590e-04 - val_loss: 0.0015
# Epoch 4917/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.4911e-04 - val_loss: 0.0014
# Epoch 4918/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.2714e-04 - val_loss: 0.0016
# Epoch 4919/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.3152e-04 - val_loss: 0.0015
# Epoch 4920/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.2193e-04 - val_loss: 0.0014
# Epoch 4921/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.4239e-04 - val_loss: 0.0016
# Epoch 4922/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1955e-04 - val_loss: 0.0013
# Epoch 4923/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.4710e-04 - val_loss: 0.0010
# Epoch 4924/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.2243e-04 - val_loss: 0.0015
# Epoch 4925/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.0898e-04 - val_loss: 0.0013
# Epoch 4926/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.1846e-04 - val_loss: 0.0012
# Epoch 4927/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.2910e-04 - val_loss: 0.0017
# Epoch 4928/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.1373e-04 - val_loss: 0.0013
# Epoch 4929/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.2698e-04 - val_loss: 0.0013
# Epoch 4930/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.1812e-04 - val_loss: 0.0015
# Epoch 4931/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.1533e-04 - val_loss: 0.0011
# Epoch 4932/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.2851e-04 - val_loss: 0.0014
# Epoch 4933/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.2613e-04 - val_loss: 0.0015
# Epoch 4934/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.2336e-04 - val_loss: 9.9606e-04
# Epoch 4935/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.3389e-04 - val_loss: 0.0015
# Epoch 4936/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.2542e-04 - val_loss: 0.0013
# Epoch 4937/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1266e-04 - val_loss: 0.0015
# Epoch 4938/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.3684e-04 - val_loss: 0.0013
# Epoch 4939/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.2576e-04 - val_loss: 0.0015
# Epoch 4940/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.3475e-04 - val_loss: 0.0012
# Epoch 4941/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.4033e-04 - val_loss: 0.0014
# Epoch 4942/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.2813e-04 - val_loss: 0.0012
# Epoch 4943/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.0867e-04 - val_loss: 0.0012
# Epoch 4944/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.1372e-04 - val_loss: 0.0011
# Epoch 4945/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1755e-04 - val_loss: 0.0011
# Epoch 4946/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.1862e-04 - val_loss: 0.0012
# Epoch 4947/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.2381e-04 - val_loss: 0.0011
# Epoch 4948/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 1.2692e-04 - val_loss: 0.0011
# Epoch 4949/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.1360e-04 - val_loss: 0.0011
# Epoch 4950/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.2078e-04 - val_loss: 0.0011
# Epoch 4951/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.1135e-04 - val_loss: 0.0011
# Epoch 4952/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.1813e-04 - val_loss: 0.0011
# Epoch 4953/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.0646e-04 - val_loss: 0.0011
# Epoch 4954/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.1213e-04 - val_loss: 0.0011
# Epoch 4955/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.0225e-04 - val_loss: 0.0011
# Epoch 4956/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1054e-04 - val_loss: 0.0011
# Epoch 4957/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.0738e-04 - val_loss: 9.8377e-04
# Epoch 4958/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.0346e-04 - val_loss: 0.0011
# Epoch 4959/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.5159e-05 - val_loss: 0.0010
# Epoch 4960/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.0465e-04 - val_loss: 0.0010
# Epoch 4961/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.0247e-04 - val_loss: 0.0010
# Epoch 4962/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.8757e-05 - val_loss: 0.0011
# Epoch 4963/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.3691e-05 - val_loss: 0.0011
# Epoch 4964/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.9555e-05 - val_loss: 0.0011
# Epoch 4965/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.4830e-05 - val_loss: 0.0011
# Epoch 4966/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.6855e-05 - val_loss: 0.0011
# Epoch 4967/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.3756e-05 - val_loss: 0.0010
# Epoch 4968/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.6049e-05 - val_loss: 0.0010
# Epoch 4969/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 9.4001e-05 - val_loss: 0.0010
# Epoch 4970/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 9.4468e-05 - val_loss: 0.0010
# Epoch 4971/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 9.1226e-05 - val_loss: 0.0010
# Epoch 4972/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.2514e-05 - val_loss: 9.9572e-04
# Epoch 4973/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 9.0940e-05 - val_loss: 0.0010
# Epoch 4974/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.2671e-05 - val_loss: 9.8663e-04
# Epoch 4975/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.0546e-05 - val_loss: 0.0010
# Epoch 4976/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 9.3246e-05 - val_loss: 9.8185e-04
# Epoch 4977/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.1754e-05 - val_loss: 0.0010
# Epoch 4978/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.4821e-05 - val_loss: 9.7497e-04
# Epoch 4979/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.2223e-05 - val_loss: 0.0010
# Epoch 4980/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.6036e-05 - val_loss: 9.7370e-04
# Epoch 4981/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.2617e-05 - val_loss: 9.9980e-04
# Epoch 4982/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.6707e-05 - val_loss: 9.7301e-04
# Epoch 4983/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 9.2205e-05 - val_loss: 9.8498e-04
# Epoch 4984/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.6432e-05 - val_loss: 9.7226e-04
# Epoch 4985/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.1241e-05 - val_loss: 9.6938e-04
# Epoch 4986/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.5217e-05 - val_loss: 9.6918e-04
# Epoch 4987/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 8.8860e-05 - val_loss: 9.5428e-04
# Epoch 4988/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.2521e-05 - val_loss: 9.6359e-04
# Epoch 4989/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 8.5795e-05 - val_loss: 9.4241e-04
# Epoch 4990/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 8.9022e-05 - val_loss: 9.5306e-04
# Epoch 4991/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 8.3510e-05 - val_loss: 9.3219e-04
# Epoch 4992/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 8.6153e-05 - val_loss: 9.3653e-04
# Epoch 4993/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.3169e-05 - val_loss: 9.2359e-04
# Epoch 4994/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.4839e-05 - val_loss: 9.1995e-04
# Epoch 4995/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.3754e-05 - val_loss: 9.1558e-04
# Epoch 4996/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 8.4594e-05 - val_loss: 9.0566e-04
# Epoch 4997/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.5426e-05 - val_loss: 9.0677e-04
# Epoch 4998/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 8.5635e-05 - val_loss: 8.9461e-04
# Epoch 4999/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.7842e-05 - val_loss: 8.9809e-04
# Epoch 5000/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.7100e-05 - val_loss: 8.8647e-04
# Epoch 5001/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.0337e-05 - val_loss: 8.9130e-04
# Epoch 5002/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 8.6592e-05 - val_loss: 8.8225e-04
# Epoch 5003/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.9583e-05 - val_loss: 8.8878e-04
# Epoch 5004/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.1950e-05 - val_loss: 8.7618e-04
# Epoch 5005/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.3664e-05 - val_loss: 8.8324e-04
# Epoch 5006/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.5624e-05 - val_loss: 8.7014e-04
# Epoch 5007/7000
# ...
# Epoch 6952/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.4834e-05 - val_loss: 0.0010
# Epoch 6953/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.4134e-05 - val_loss: 0.0010
# Epoch 6954/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.2901e-05 - val_loss: 0.0010
# Epoch 6955/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.3397e-05 - val_loss: 9.8229e-04
# Epoch 6956/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.4913e-05 - val_loss: 9.7287e-04
# Epoch 6957/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.5962e-05 - val_loss: 9.8909e-04
# Epoch 6958/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.6432e-05 - val_loss: 0.0011
# Epoch 6959/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.8076e-05 - val_loss: 0.0012
# Epoch 6960/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.5124e-05 - val_loss: 0.0012
# Epoch 6961/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 3.3845e-05 - val_loss: 0.0012
# Epoch 6962/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.9492e-05 - val_loss: 0.0011
# Epoch 6963/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 3.9395e-05 - val_loss: 0.0011
# Epoch 6964/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.1261e-05 - val_loss: 0.0010
# Epoch 6965/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.9761e-05 - val_loss: 9.9797e-04
# Epoch 6966/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.1878e-05 - val_loss: 0.0011
# Epoch 6967/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 2.5809e-05 - val_loss: 0.0011
# Epoch 6968/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.2509e-05 - val_loss: 0.0010
# Epoch 6969/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.2288e-05 - val_loss: 9.8094e-04
# Epoch 6970/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.9271e-05 - val_loss: 0.0010
# Epoch 6971/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.8068e-05 - val_loss: 0.0011
# Epoch 6972/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.5077e-05 - val_loss: 0.0012
# Epoch 6973/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.2599e-05 - val_loss: 0.0012
# Epoch 6974/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.5221e-05 - val_loss: 0.0011
# Epoch 6975/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.4931e-05 - val_loss: 0.0011
# Epoch 6976/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.3852e-05 - val_loss: 0.0011
# Epoch 6977/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.3224e-05 - val_loss: 0.0011
# Epoch 6978/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.4201e-05 - val_loss: 0.0011
# Epoch 6979/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.1775e-05 - val_loss: 0.0011
# Epoch 6980/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.1007e-05 - val_loss: 0.0011
# Epoch 6981/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.2950e-05 - val_loss: 0.0012
# Epoch 6982/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.5510e-05 - val_loss: 0.0012
# Epoch 6983/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.7808e-05 - val_loss: 0.0012
# Epoch 6984/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.8427e-05 - val_loss: 0.0012
# Epoch 6985/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.6736e-05 - val_loss: 0.0012
# Epoch 6986/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.5006e-05 - val_loss: 0.0012
# Epoch 6987/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.5301e-05 - val_loss: 0.0011
# Epoch 6988/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.7055e-05 - val_loss: 0.0010
# Epoch 6989/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 2.0648e-05 - val_loss: 9.9963e-04
# Epoch 6990/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.6836e-05 - val_loss: 0.0011
# Epoch 6991/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.7267e-05 - val_loss: 0.0011
# Epoch 6992/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.3308e-05 - val_loss: 0.0013
# Epoch 6993/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.6168e-05 - val_loss: 0.0014
# Epoch 6994/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.2554e-05 - val_loss: 0.0012
# Epoch 6995/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.1022e-05 - val_loss: 0.0012
# Epoch 6996/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.4099e-05 - val_loss: 0.0011
# Epoch 6997/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.1773e-05 - val_loss: 0.0010
# Epoch 6998/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.1259e-05 - val_loss: 0.0011
# Epoch 6999/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.1161e-05 - val_loss: 0.0011
# Epoch 7000/7000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.3088e-05 - val_loss: 0.0011
# --- Starting Reinforcement Learning Fine-Tuning (Batched) ---
# RL Epoch 1/200, Average Loss per Batch: 0.000017
# RL Epoch 2/200, Average Loss per Batch: 0.000015
# RL Epoch 3/200, Average Loss per Batch: 0.000012
# RL Epoch 4/200, Average Loss per Batch: 0.000012
# RL Epoch 5/200, Average Loss per Batch: 0.000014
# RL Epoch 6/200, Average Loss per Batch: 0.000013
# RL Epoch 7/200, Average Loss per Batch: 0.000014
# RL Epoch 8/200, Average Loss per Batch: 0.000009
# RL Epoch 9/200, Average Loss per Batch: 0.000008
# RL Epoch 10/200, Average Loss per Batch: 0.000007
# RL Epoch 11/200, Average Loss per Batch: 0.000007
# RL Epoch 12/200, Average Loss per Batch: 0.000007
# RL Epoch 13/200, Average Loss per Batch: 0.000007
# RL Epoch 14/200, Average Loss per Batch: 0.000007
# RL Epoch 15/200, Average Loss per Batch: 0.000008
# RL Epoch 16/200, Average Loss per Batch: 0.000011
# RL Epoch 17/200, Average Loss per Batch: 0.000019
# RL Epoch 18/200, Average Loss per Batch: 0.000039
# RL Epoch 19/200, Average Loss per Batch: 0.000022
# RL Epoch 20/200, Average Loss per Batch: 0.000013
# RL Epoch 21/200, Average Loss per Batch: 0.000014
# RL Epoch 22/200, Average Loss per Batch: 0.000010
# RL Epoch 23/200, Average Loss per Batch: 0.000007
# RL Epoch 24/200, Average Loss per Batch: 0.000006
# RL Epoch 25/200, Average Loss per Batch: 0.000006
# RL Epoch 26/200, Average Loss per Batch: 0.000006
# RL Epoch 27/200, Average Loss per Batch: 0.000005
# RL Epoch 28/200, Average Loss per Batch: 0.000005
# RL Epoch 29/200, Average Loss per Batch: 0.000005
# RL Epoch 30/200, Average Loss per Batch: 0.000005
# RL Epoch 31/200, Average Loss per Batch: 0.000005
# RL Epoch 32/200, Average Loss per Batch: 0.000005
# RL Epoch 33/200, Average Loss per Batch: 0.000006
# RL Epoch 34/200, Average Loss per Batch: 0.000008
# RL Epoch 35/200, Average Loss per Batch: 0.000017
# RL Epoch 36/200, Average Loss per Batch: 0.000029
# RL Epoch 37/200, Average Loss per Batch: 0.000045
# RL Epoch 38/200, Average Loss per Batch: 0.000019
# RL Epoch 39/200, Average Loss per Batch: 0.000017
# RL Epoch 40/200, Average Loss per Batch: 0.000015
# RL Epoch 41/200, Average Loss per Batch: 0.000009
# RL Epoch 42/200, Average Loss per Batch: 0.000006
# RL Epoch 43/200, Average Loss per Batch: 0.000005
# RL Epoch 44/200, Average Loss per Batch: 0.000005
# RL Epoch 45/200, Average Loss per Batch: 0.000005
# RL Epoch 46/200, Average Loss per Batch: 0.000004
# RL Epoch 47/200, Average Loss per Batch: 0.000004
# RL Epoch 48/200, Average Loss per Batch: 0.000004
# RL Epoch 49/200, Average Loss per Batch: 0.000004
# RL Epoch 50/200, Average Loss per Batch: 0.000004
# RL Epoch 51/200, Average Loss per Batch: 0.000004
# RL Epoch 52/200, Average Loss per Batch: 0.000004
# RL Epoch 53/200, Average Loss per Batch: 0.000005
# RL Epoch 54/200, Average Loss per Batch: 0.000006
# RL Epoch 55/200, Average Loss per Batch: 0.000011
# RL Epoch 56/200, Average Loss per Batch: 0.000018
# RL Epoch 57/200, Average Loss per Batch: 0.000031
# RL Epoch 58/200, Average Loss per Batch: 0.000023
# RL Epoch 59/200, Average Loss per Batch: 0.000013
# RL Epoch 60/200, Average Loss per Batch: 0.000009
# RL Epoch 61/200, Average Loss per Batch: 0.000009
# RL Epoch 62/200, Average Loss per Batch: 0.000008
# RL Epoch 63/200, Average Loss per Batch: 0.000006
# RL Epoch 64/200, Average Loss per Batch: 0.000006
# RL Epoch 65/200, Average Loss per Batch: 0.000005
# RL Epoch 66/200, Average Loss per Batch: 0.000005
# RL Epoch 67/200, Average Loss per Batch: 0.000005
# RL Epoch 68/200, Average Loss per Batch: 0.000006
# RL Epoch 69/200, Average Loss per Batch: 0.000007
# RL Epoch 70/200, Average Loss per Batch: 0.000008
# RL Epoch 71/200, Average Loss per Batch: 0.000010
# RL Epoch 72/200, Average Loss per Batch: 0.000015
# RL Epoch 73/200, Average Loss per Batch: 0.000016
# RL Epoch 74/200, Average Loss per Batch: 0.000016
# RL Epoch 75/200, Average Loss per Batch: 0.000012
# RL Epoch 76/200, Average Loss per Batch: 0.000008
# RL Epoch 77/200, Average Loss per Batch: 0.000007
# RL Epoch 78/200, Average Loss per Batch: 0.000006
# RL Epoch 79/200, Average Loss per Batch: 0.000005
# RL Epoch 80/200, Average Loss per Batch: 0.000004
# RL Epoch 81/200, Average Loss per Batch: 0.000004
# RL Epoch 82/200, Average Loss per Batch: 0.000004
# RL Epoch 83/200, Average Loss per Batch: 0.000004
# RL Epoch 84/200, Average Loss per Batch: 0.000004
# RL Epoch 85/200, Average Loss per Batch: 0.000004
# RL Epoch 86/200, Average Loss per Batch: 0.000004
# RL Epoch 87/200, Average Loss per Batch: 0.000004
# RL Epoch 88/200, Average Loss per Batch: 0.000004
# RL Epoch 89/200, Average Loss per Batch: 0.000005
# RL Epoch 90/200, Average Loss per Batch: 0.000008
# RL Epoch 91/200, Average Loss per Batch: 0.000019
# RL Epoch 92/200, Average Loss per Batch: 0.000047
# RL Epoch 93/200, Average Loss per Batch: 0.000036
# RL Epoch 94/200, Average Loss per Batch: 0.000018
# RL Epoch 95/200, Average Loss per Batch: 0.000012
# RL Epoch 96/200, Average Loss per Batch: 0.000012
# RL Epoch 97/200, Average Loss per Batch: 0.000008
# RL Epoch 98/200, Average Loss per Batch: 0.000006
# RL Epoch 99/200, Average Loss per Batch: 0.000005
# RL Epoch 100/200, Average Loss per Batch: 0.000004
# RL Epoch 101/200, Average Loss per Batch: 0.000004
# RL Epoch 102/200, Average Loss per Batch: 0.000004
# RL Epoch 103/200, Average Loss per Batch: 0.000004
# RL Epoch 104/200, Average Loss per Batch: 0.000004
# RL Epoch 105/200, Average Loss per Batch: 0.000003
# RL Epoch 106/200, Average Loss per Batch: 0.000003
# RL Epoch 107/200, Average Loss per Batch: 0.000003
# RL Epoch 108/200, Average Loss per Batch: 0.000004
# RL Epoch 109/200, Average Loss per Batch: 0.000004
# RL Epoch 110/200, Average Loss per Batch: 0.000006
# RL Epoch 111/200, Average Loss per Batch: 0.000011
# RL Epoch 112/200, Average Loss per Batch: 0.000020
# RL Epoch 113/200, Average Loss per Batch: 0.000033
# RL Epoch 114/200, Average Loss per Batch: 0.000025
# RL Epoch 115/200, Average Loss per Batch: 0.000013
# RL Epoch 116/200, Average Loss per Batch: 0.000009
# RL Epoch 117/200, Average Loss per Batch: 0.000009
# RL Epoch 118/200, Average Loss per Batch: 0.000007
# RL Epoch 119/200, Average Loss per Batch: 0.000006
# RL Epoch 120/200, Average Loss per Batch: 0.000004
# RL Epoch 121/200, Average Loss per Batch: 0.000004
# RL Epoch 122/200, Average Loss per Batch: 0.000004
# RL Epoch 123/200, Average Loss per Batch: 0.000004
# RL Epoch 124/200, Average Loss per Batch: 0.000004
# RL Epoch 125/200, Average Loss per Batch: 0.000004
# RL Epoch 126/200, Average Loss per Batch: 0.000004
# RL Epoch 127/200, Average Loss per Batch: 0.000005
# RL Epoch 128/200, Average Loss per Batch: 0.000007
# RL Epoch 129/200, Average Loss per Batch: 0.000011
# RL Epoch 130/200, Average Loss per Batch: 0.000020
# RL Epoch 131/200, Average Loss per Batch: 0.000023
# RL Epoch 132/200, Average Loss per Batch: 0.000022
# RL Epoch 133/200, Average Loss per Batch: 0.000014
# RL Epoch 134/200, Average Loss per Batch: 0.000009
# RL Epoch 135/200, Average Loss per Batch: 0.000007
# RL Epoch 136/200, Average Loss per Batch: 0.000007
# RL Epoch 137/200, Average Loss per Batch: 0.000006
# RL Epoch 138/200, Average Loss per Batch: 0.000005
# RL Epoch 139/200, Average Loss per Batch: 0.000004
# RL Epoch 140/200, Average Loss per Batch: 0.000004
# RL Epoch 141/200, Average Loss per Batch: 0.000004
# RL Epoch 142/200, Average Loss per Batch: 0.000003
# RL Epoch 143/200, Average Loss per Batch: 0.000003
# RL Epoch 144/200, Average Loss per Batch: 0.000004
# RL Epoch 145/200, Average Loss per Batch: 0.000004
# RL Epoch 146/200, Average Loss per Batch: 0.000007
# RL Epoch 147/200, Average Loss per Batch: 0.000011
# RL Epoch 148/200, Average Loss per Batch: 0.000019
# RL Epoch 149/200, Average Loss per Batch: 0.000031
# RL Epoch 150/200, Average Loss per Batch: 0.000022
# RL Epoch 151/200, Average Loss per Batch: 0.000011
# RL Epoch 152/200, Average Loss per Batch: 0.000009
# RL Epoch 153/200, Average Loss per Batch: 0.000008
# RL Epoch 154/200, Average Loss per Batch: 0.000006
# RL Epoch 155/200, Average Loss per Batch: 0.000005
# RL Epoch 156/200, Average Loss per Batch: 0.000004
# RL Epoch 157/200, Average Loss per Batch: 0.000003
# RL Epoch 158/200, Average Loss per Batch: 0.000003
# RL Epoch 159/200, Average Loss per Batch: 0.000003
# RL Epoch 160/200, Average Loss per Batch: 0.000003
# RL Epoch 161/200, Average Loss per Batch: 0.000003
# RL Epoch 162/200, Average Loss per Batch: 0.000003
# RL Epoch 163/200, Average Loss per Batch: 0.000004
# RL Epoch 164/200, Average Loss per Batch: 0.000005
# RL Epoch 165/200, Average Loss per Batch: 0.000009
# RL Epoch 166/200, Average Loss per Batch: 0.000017
# RL Epoch 167/200, Average Loss per Batch: 0.000026
# RL Epoch 168/200, Average Loss per Batch: 0.000030
# RL Epoch 169/200, Average Loss per Batch: 0.000019
# RL Epoch 170/200, Average Loss per Batch: 0.000011
# RL Epoch 171/200, Average Loss per Batch: 0.000009
# RL Epoch 172/200, Average Loss per Batch: 0.000010
# RL Epoch 173/200, Average Loss per Batch: 0.000007
# RL Epoch 174/200, Average Loss per Batch: 0.000005
# RL Epoch 175/200, Average Loss per Batch: 0.000004
# RL Epoch 176/200, Average Loss per Batch: 0.000003
# RL Epoch 177/200, Average Loss per Batch: 0.000003
# RL Epoch 178/200, Average Loss per Batch: 0.000003
# RL Epoch 179/200, Average Loss per Batch: 0.000003
# RL Epoch 180/200, Average Loss per Batch: 0.000003
# RL Epoch 181/200, Average Loss per Batch: 0.000003
# RL Epoch 182/200, Average Loss per Batch: 0.000003
# RL Epoch 183/200, Average Loss per Batch: 0.000003
# RL Epoch 184/200, Average Loss per Batch: 0.000003
# RL Epoch 185/200, Average Loss per Batch: 0.000003
# RL Epoch 186/200, Average Loss per Batch: 0.000003
# RL Epoch 187/200, Average Loss per Batch: 0.000003
# RL Epoch 188/200, Average Loss per Batch: 0.000003
# RL Epoch 189/200, Average Loss per Batch: 0.000004
# RL Epoch 190/200, Average Loss per Batch: 0.000004
# RL Epoch 191/200, Average Loss per Batch: 0.000005
# RL Epoch 192/200, Average Loss per Batch: 0.000006
# RL Epoch 193/200, Average Loss per Batch: 0.000008
# RL Epoch 194/200, Average Loss per Batch: 0.000014
# RL Epoch 195/200, Average Loss per Batch: 0.000027
# RL Epoch 196/200, Average Loss per Batch: 0.000041
# RL Epoch 197/200, Average Loss per Batch: 0.000033
# RL Epoch 198/200, Average Loss per Batch: 0.000018
# RL Epoch 199/200, Average Loss per Batch: 0.000012
# RL Epoch 200/200, Average Loss per Batch: 0.000009
# --- RL Fine-Tuning Complete ---
#
#  Training Set Performance Metrics (RNN):
#  Mean Absolute Error (MAE) : ₹2.61
#  Mean Squared Error (MSE)  : ₹10.98
#  Root Squared Error (RMSE) : ₹3.31
#  R² Score                  : 0.9997
#  Mean Absolute Percentage Error (MAPE) : 0.20%
#  Accuracy (100 - MAPE) : 99.80%
#  MSE Percentage of Average Price : 0.80%
#  MAE Percentage of Average Price : 0.19%
#
#  Validation Set Performance Metrics (RNN):
#  Mean Absolute Error (MAE) : ₹35.42
#  Mean Squared Error (MSE)  : ₹1956.75
#  Root Squared Error (RMSE) : ₹44.24
#  R² Score                  : 0.9218
#  Mean Absolute Percentage Error (MAPE) : 2.04%
#  Accuracy (100 - MAPE) : 97.96%
#  MSE Percentage of Average Price: 112.38%
#  MAE Percentage of Average Price: 2.03%
#
#  Prediction for 2025-06-18:
#  Predicted Closing Price: ₹1647.59
#  Actual Closing Price   : ₹1632.9000244140625
#  Test Set Performance Metrics (RNN):
#  Mean Absolute Error (MAE) : ₹21.41
#  Mean Squared Error (MSE)  : ₹678.58
#  Root Squared Error (RMSE) : ₹26.05
#  R² Score                  : 0.2041
#  Mean Absolute Percentage Error (MAPE) : 1.34%
#  Accuracy (100 - MAPE) : 98.66%
#  MSE Percentage of Average Price: 42.51%
#  MAE Percentage of Average Price: 1.34%

# %% [markdown]
# # **10000 epochs**

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import SimpleRNN
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from matplotlib.dates import DateFormatter
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import numpy as np
import pandas as pd
import datetime
import holidays
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import warnings

warnings.filterwarnings('ignore')

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

SYMBOL = "INFY.NS"
SEQUENCE_LENGTH = 60

TRAIN_START_DATE = "2020-06-01"
TRAIN_END_DATE = "2025-05-31"

TEST_START_DATE = "2025-06-01"
TEST_END_DATE = "2025-07-01"

# Get Indian trading holidays
def get_nse_holidays():
    in_holidays = holidays.India(years=range(2020, 2026))
    return set(in_holidays.keys())

TRADING_HOLIDAYS = get_nse_holidays()

def is_valid_date(date_str):
    try:
        date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
        if not (datetime.date(2025, 6, 1) <= date <= datetime.date(2025, 7, 1)):
            print("Date must be between 2025-06-01 and 2025-07-01.")
            return False
        if date.weekday() >= 5:
            print("Weekends are not trading days.")
            return False
        if date in TRADING_HOLIDAYS:
            print("Entered date is a trading holiday.")
            return False
        return True
    except ValueError:
        print("Invalid date format. Use YYYY-MM-DD.")
        return False

def get_stock_data():
    print("Fetching data from Yahoo Finance...")
    full_df = yf.download(SYMBOL, start=TRAIN_START_DATE, end=TEST_END_DATE)
    full_df = full_df[['Close']]
    full_df.dropna(inplace=True)
    full_df.index = pd.to_datetime(full_df.index)

    train_df = full_df.loc[TRAIN_START_DATE:TRAIN_END_DATE]
    test_df = full_df.loc[TEST_START_DATE:TEST_END_DATE]
    return train_df, test_df, full_df

# Prompt until valid date is entered
def get_user_date():
    while True:
        date_input = input("Enter a date (YYYY-MM-DD): ")
        if is_valid_date(date_input):
            return datetime.datetime.strptime(date_input, "%Y-%m-%d").date()

# Build the SimpleRNN model
def build_model(input_shape, learning_rate=0.001): # Added learning_rate parameter
    model = Sequential()
    model.add(SimpleRNN(units=50, activation='tanh', input_shape=input_shape))
    model.add(Dense(1))
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate) # Use custom learning rate
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# Reinforcement Learning Fine-Tuning
class RLAgent:
    """
    A simple RL Agent to fine-tune the RNN model.
    The "environment" is the time series data, and the "action" is the prediction.
    The reward is based on prediction accuracy.
    """
    def __init__(self, model, learning_rate=0.001):
        self.model = model
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate) # Pass learning_rate to RLAgent

    @tf.function
    def train_step(self, state, target):
        """
        Performs a single training step to fine-tune the model weights.
        """
        with tf.GradientTape() as tape:
            prediction = self.model(state, training=True)
            # Use Mean Squared Error directly as the loss to minimize
            loss = tf.reduce_mean(tf.square(tf.cast(target, tf.float32) - prediction))

        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss # Return the mean loss for the batch


def fine_tune_with_rl(model, X_train, y_train, epochs=5, learning_rate=0.001, batch_size=32):
    """
    Fine- tunes the pre-trained RNN model using a simple reinforcement learning loop with batched data.
    """
    print("\n--- Starting Reinforcement Learning Fine-Tuning (Batched) ---")
    agent = RLAgent(model, learning_rate=learning_rate)

    # Create a TensorFlow Dataset and batch it
    dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    dataset = dataset.batch(batch_size)

    num_batches = tf.data.experimental.cardinality(dataset).numpy()

    for epoch in range(epochs):
        total_loss = 0
        batch_count = 0
        for batch_x, batch_y in dataset:
            # Ensure batch_x has the correct shape (batch_size, sequence_length, 1)
            batch_x_reshaped = tf.reshape(batch_x, (tf.shape(batch_x)[0], tf.shape(batch_x)[1], 1))
            loss = agent.train_step(batch_x_reshaped, batch_y)
            total_loss += loss.numpy() # Sum up the mean loss for each batch
            batch_count += 1

        # Calculate average loss per epoch
        average_epoch_loss = total_loss / num_batches if num_batches > 0 else 0
        print(f"RL Epoch {epoch + 1}/{epochs}, Average Loss per Batch: {average_epoch_loss:.6f}") # Print average loss

    print("--- RL Fine-Tuning Complete ---")
    return model


def create_test_sequences(train_df, test_df, scaler):
    combined = pd.concat([train_df, test_df])
    scaled = scaler.transform(combined[['Close']])
    X_test = []
    test_dates = test_df.index.date

    for i in range(len(train_df), len(combined)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled[i - SEQUENCE_LENGTH:i]
        X_test.append(seq)

    X_test = np.array(X_test)
    return X_test, test_dates

def predict_price_on_test(model, full_df, scaler, user_date):
    all_dates = full_df.index.date
    try:
        idx = list(all_dates).index(user_date)
    except ValueError:
        print("User date not found in data.")
        return None, None, user_date

    if idx < SEQUENCE_LENGTH:
        print("Not enough data to predict for this date.")
        return None, None, user_date

    input_seq = scaler.transform(full_df[['Close']].values)[idx - SEQUENCE_LENGTH:idx]
    input_seq = np.reshape(input_seq, (1, SEQUENCE_LENGTH, 1))

    predicted_scaled = model.predict(input_seq, verbose=0)
    predicted_price = scaler.inverse_transform(predicted_scaled)[0][0]

    actual_price = float(full_df.iloc[idx]['Close']) if idx < len(full_df) else None
    return predicted_price, actual_price, full_df.index[idx].date()

# Plot the result
def plot_results(df, predicted_date, predicted_price, actual_price):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Historical Close Price',zorder=1)
    #plt.axvline(pd.to_datetime(predicted_date), color='red', linestyle='--', label='Predicted Date')
    plt.scatter(pd.to_datetime(predicted_date), predicted_price, color='orange', label='Predicted Price',zorder=2)
    if actual_price is not None:
        plt.scatter(pd.to_datetime(predicted_date), actual_price, color='green', label='Actual Price',zorder=3, s=100)
    plt.title("INFOSYS Stock Price with Prediction (yfinance)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#Plotting error with no. of epochs
def plot_training_loss(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title("Training and Validation Loss Over Epochs (RNN)")
    plt.xlabel("Epoch no.")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def main():
    print("=== INFOSYS LSTM Stock Price Predictor (Test Phase June–July 2025) ===")
    user_date = get_user_date()

    # Step 1: Get stock data
    train_df, test_df, full_df = get_stock_data()

    # Step 2: Preprocess
    scaler = MinMaxScaler()
    scaled_train = scaler.fit_transform(train_df[['Close']])
    X, y = [], []
    for i in range(SEQUENCE_LENGTH, len(scaled_train)):
        X.append(scaled_train[i - SEQUENCE_LENGTH:i])
        y.append(scaled_train[i])
    X = np.array(X)
    y = np.array(y)

    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
    #early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    # Step 3: Build and train model
    model = build_model((X_train.shape[1], 1), learning_rate=0.0005) # Reduced Adam learning rate
    print("Training RNN model...")
    history = model.fit(X_train, y_train, epochs=10000, batch_size=64, validation_data=(X_val, y_val), verbose = 1) #callbacks = [early_stop], verbose=1)

    #print(f"\nBest weights restored from epoch: {early_stop.best_epoch + 1}")

    # Step 4: Plot training loss
    plot_training_loss(history)

    # Step 5: Fine-tune with Reinforcement Learning
    rl_tuned_model = fine_tune_with_rl(model, X_train, y_train, epochs=150, learning_rate=0.0001, batch_size=32)

    # Predict on training data to evaluate performance
    y_train_pred_scaled = rl_tuned_model.predict(X_train, verbose=0)
    y_train_pred = scaler.inverse_transform(y_train_pred_scaled)
    y_true_train = scaler.inverse_transform(y_train.reshape(-1, 1))

    # Calculate and print training metrics
    mae_train = mean_absolute_error(y_true_train, y_train_pred)
    mse_train = mean_squared_error(y_true_train, y_train_pred)
    rmse_train = np.sqrt(mse_train)
    r2_train = r2_score(y_true_train, y_train_pred)
    mape_train = mean_absolute_percentage_error(y_true_train, y_train_pred) * 100
    accuracy_train = 100 - mape_train
    mse_percent_train = (mse_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    mae_percent_train = (mae_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    print("\n Training Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_train:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_train:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_train:.2f}")
    print(f" R² Score                  : {r2_train:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_train:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_train:.2f}%")
    print(f" MSE Percentage of Average Price : {mse_percent_train:.2f}%")
    print(f" MAE Percentage of Average Price : {mae_percent_train:.2f}%")

    # Predict on validation set
    y_val_pred_scaled = rl_tuned_model.predict(X_val, verbose=0)
    y_val_pred = scaler.inverse_transform(y_val_pred_scaled)
    y_val_true = scaler.inverse_transform(y_val.reshape(-1, 1))

    # Calculate and print validation metrics
    mae_val = mean_absolute_error(y_val_true, y_val_pred)
    mse_val = mean_squared_error(y_val_true, y_val_pred)
    rmse_val = np.sqrt(mse_val)
    r2_val = r2_score(y_val_true, y_val_pred)
    mape_val = mean_absolute_percentage_error(y_val_true, y_val_pred) * 100
    accuracy_val = 100 - mape_val
    mse_percent_val = (mse_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    mae_percent_val = (mae_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    print("\n Validation Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_val:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_val:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_val:.2f}")
    print(f" R² Score                  : {r2_val:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_val:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_val:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_val:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_val:.2f}%")


    # Step 6: Predict for user-input test date
    predicted_price, actual_price, predicted_date = predict_price_on_test(rl_tuned_model, full_df, scaler, user_date)
    if predicted_price is not None:
        print(f"\n Prediction for {predicted_date}:")
        print(f" Predicted Closing Price: ₹{predicted_price:.2f}")
        if actual_price is not None:
            print(f" Actual Closing Price   : ₹{actual_price}")
        else:
            print("Actual price not available.")

        plot_results(full_df, predicted_date, predicted_price, actual_price)
    else:
        print("❌ Unable to make prediction.")

    # === Step 7: Predict all test dates and compare ===

    # Reuse combined full_df
    combined_df = pd.concat([train_df, test_df])
    scaled_combined = scaler.transform(combined_df[['Close']])

    X_test_all = []
    test_date_indexes = []

    for i in range(len(train_df), len(combined_df)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled_combined[i - SEQUENCE_LENGTH:i]
        X_test_all.append(seq)
        test_date_indexes.append(combined_df.index[i])

    X_test_all = np.array(X_test_all)

    # Predict on test sequences
    y_test_pred_scaled = rl_tuned_model.predict(X_test_all, verbose=0)
    y_test_pred = scaler.inverse_transform(y_test_pred_scaled)

    # Actual prices
    y_test_true = test_df.loc[test_date_indexes, 'Close'].values

    # Calculate and print test metrics
    mae_test = mean_absolute_error(y_test_true, y_test_pred)
    mse_test = mean_squared_error(y_test_true, y_test_pred)
    rmse_test = np.sqrt(mse_test)
    r2_test = r2_score(y_test_true, y_test_pred)
    mape_test = mean_absolute_percentage_error(y_test_true, y_test_pred) * 100
    accuracy_test = 100 - mape_test
    mse_percent_test = (mse_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    mae_percent_test = (mae_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    print("\n Test Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_test:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_test:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_test:.2f}")
    print(f" R² Score                  : {r2_test:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_test:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_test:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_test:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_test:.2f}%")

    # Plot actual vs predicted
    plt.figure(figsize=(12, 6))
    plt.plot(test_date_indexes, y_test_true, label='Actual Price')
    plt.plot(test_date_indexes, y_test_pred, label='Predicted Price')
    plt.title("Actual vs Predicted INFY Closing Prices (01-Jun to 01-Jul 2025)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.xticks(rotation=45)
    plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import SimpleRNN
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from matplotlib.dates import DateFormatter
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
import numpy as np
import pandas as pd
import datetime
import holidays
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import warnings

warnings.filterwarnings('ignore')

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

SYMBOL = "INFY.NS"
SEQUENCE_LENGTH = 60

TRAIN_START_DATE = "2020-06-01"
TRAIN_END_DATE = "2025-05-31"

TEST_START_DATE = "2025-06-01"
TEST_END_DATE = "2025-07-01"

# Get Indian trading holidays
def get_nse_holidays():
    in_holidays = holidays.India(years=range(2020, 2026))
    return set(in_holidays.keys())

TRADING_HOLIDAYS = get_nse_holidays()

def is_valid_date(date_str):
    try:
        date = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()
        if not (datetime.date(2025, 6, 1) <= date <= datetime.date(2025, 7, 1)):
            print("Date must be between 2025-06-01 and 2025-07-01.")
            return False
        if date.weekday() >= 5:
            print("Weekends are not trading days.")
            return False
        if date in TRADING_HOLIDAYS:
            print("Entered date is a trading holiday.")
            return False
        return True
    except ValueError:
        print("Invalid date format. Use YYYY-MM-DD.")
        return False

def get_stock_data():
    print("Fetching data from Yahoo Finance...")
    full_df = yf.download(SYMBOL, start=TRAIN_START_DATE, end=TEST_END_DATE)
    full_df = full_df[['Close']]
    full_df.dropna(inplace=True)
    full_df.index = pd.to_datetime(full_df.index)

    train_df = full_df.loc[TRAIN_START_DATE:TRAIN_END_DATE]
    test_df = full_df.loc[TEST_START_DATE:TEST_END_DATE]
    return train_df, test_df, full_df

# Prompt until valid date is entered
def get_user_date():
    while True:
        date_input = input("Enter a date (YYYY-MM-DD): ")
        if is_valid_date(date_input):
            return datetime.datetime.strptime(date_input, "%Y-%m-%d").date()

# Build the SimpleRNN model
def build_model(input_shape, learning_rate=0.001): # Added learning_rate parameter
    model = Sequential()
    model.add(SimpleRNN(units=50, activation='tanh', input_shape=input_shape))
    model.add(Dense(1))
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate) # Use custom learning rate
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# Reinforcement Learning Fine-Tuning
class RLAgent:
    """
    A simple RL Agent to fine-tune the RNN model.
    The "environment" is the time series data, and the "action" is the prediction.
    The reward is based on prediction accuracy.
    """
    def __init__(self, model, learning_rate=0.001):
        self.model = model
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate) # Pass learning_rate to RLAgent

    @tf.function
    def train_step(self, state, target):
        """
        Performs a single training step to fine-tune the model weights.
        """
        with tf.GradientTape() as tape:
            prediction = self.model(state, training=True)
            # Use Mean Squared Error directly as the loss to minimize
            loss = tf.reduce_mean(tf.square(tf.cast(target, tf.float32) - prediction))

        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss # Return the mean loss for the batch


def fine_tune_with_rl(model, X_train, y_train, epochs=5, learning_rate=0.001, batch_size=32):
    """
    Fine- tunes the pre-trained RNN model using a simple reinforcement learning loop with batched data.
    """
    print("\n--- Starting Reinforcement Learning Fine-Tuning (Batched) ---")
    agent = RLAgent(model, learning_rate=learning_rate)

    # Create a TensorFlow Dataset and batch it
    dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    dataset = dataset.batch(batch_size)

    num_batches = tf.data.experimental.cardinality(dataset).numpy()

    for epoch in range(epochs):
        total_loss = 0
        batch_count = 0
        for batch_x, batch_y in dataset:
            # Ensure batch_x has the correct shape (batch_size, sequence_length, 1)
            batch_x_reshaped = tf.reshape(batch_x, (tf.shape(batch_x)[0], tf.shape(batch_x)[1], 1))
            loss = agent.train_step(batch_x_reshaped, batch_y)
            total_loss += loss.numpy() # Sum up the mean loss for each batch
            batch_count += 1

        # Calculate average loss per epoch
        average_epoch_loss = total_loss / num_batches if num_batches > 0 else 0
        print(f"RL Epoch {epoch + 1}/{epochs}, Average Loss per Batch: {average_epoch_loss:.6f}") # Print average loss

    print("--- RL Fine-Tuning Complete ---")
    return model


def create_test_sequences(train_df, test_df, scaler):
    combined = pd.concat([train_df, test_df])
    scaled = scaler.transform(combined[['Close']])
    X_test = []
    test_dates = test_df.index.date

    for i in range(len(train_df), len(combined)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled[i - SEQUENCE_LENGTH:i]
        X_test.append(seq)

    X_test = np.array(X_test)
    return X_test, test_dates

def predict_price_on_test(model, full_df, scaler, user_date):
    all_dates = full_df.index.date
    try:
        idx = list(all_dates).index(user_date)
    except ValueError:
        print("User date not found in data.")
        return None, None, user_date

    if idx < SEQUENCE_LENGTH:
        print("Not enough data to predict for this date.")
        return None, None, user_date

    input_seq = scaler.transform(full_df[['Close']].values)[idx - SEQUENCE_LENGTH:idx]
    input_seq = np.reshape(input_seq, (1, SEQUENCE_LENGTH, 1))

    predicted_scaled = model.predict(input_seq, verbose=0)
    predicted_price = scaler.inverse_transform(predicted_scaled)[0][0]

    actual_price = float(full_df.iloc[idx]['Close']) if idx < len(full_df) else None
    return predicted_price, actual_price, full_df.index[idx].date()

# Plot the result
def plot_results(df, predicted_date, predicted_price, actual_price):
    plt.figure(figsize=(12, 6))
    plt.plot(df.index, df['Close'], label='Historical Close Price',zorder=1)
    #plt.axvline(pd.to_datetime(predicted_date), color='red', linestyle='--', label='Predicted Date')
    plt.scatter(pd.to_datetime(predicted_date), predicted_price, color='orange', label='Predicted Price',zorder=2)
    if actual_price is not None:
        plt.scatter(pd.to_datetime(predicted_date), actual_price, color='green', label='Actual Price',zorder=3, s=100)
    plt.title("INFOSYS Stock Price with Prediction (yfinance)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

#Plotting error with no. of epochs
def plot_training_loss(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title("Training and Validation Loss Over Epochs (RNN)")
    plt.xlabel("Epoch no.")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def main():
    print("=== INFOSYS LSTM Stock Price Predictor (Test Phase June–July 2025) ===")
    user_date = get_user_date()

    # Step 1: Get stock data
    train_df, test_df, full_df = get_stock_data()

    # Step 2: Preprocess
    scaler = MinMaxScaler()
    scaled_train = scaler.fit_transform(train_df[['Close']])
    X, y = [], []
    for i in range(SEQUENCE_LENGTH, len(scaled_train)):
        X.append(scaled_train[i - SEQUENCE_LENGTH:i])
        y.append(scaled_train[i])
    X = np.array(X)
    y = np.array(y)

    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
    #early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
    # Step 3: Build and train model
    model = build_model((X_train.shape[1], 1), learning_rate=0.0005) # Reduced Adam learning rate
    print("Training RNN model...")
    history = model.fit(X_train, y_train, epochs=10000, batch_size=64, validation_data=(X_val, y_val), verbose = 1) #callbacks = [early_stop], verbose=1)

    #print(f"\nBest weights restored from epoch: {early_stop.best_epoch + 1}")

    # Step 4: Plot training loss
    plot_training_loss(history)

    # Step 5: Fine-tune with Reinforcement Learning
    rl_tuned_model = fine_tune_with_rl(model, X_train, y_train, epochs=200, learning_rate=0.0001, batch_size=32)

    # Predict on training data to evaluate performance
    y_train_pred_scaled = rl_tuned_model.predict(X_train, verbose=0)
    y_train_pred = scaler.inverse_transform(y_train_pred_scaled)
    y_true_train = scaler.inverse_transform(y_train.reshape(-1, 1))

    # Calculate and print training metrics
    mae_train = mean_absolute_error(y_true_train, y_train_pred)
    mse_train = mean_squared_error(y_true_train, y_train_pred)
    rmse_train = np.sqrt(mse_train)
    r2_train = r2_score(y_true_train, y_train_pred)
    mape_train = mean_absolute_percentage_error(y_true_train, y_train_pred) * 100
    accuracy_train = 100 - mape_train
    mse_percent_train = (mse_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    mae_percent_train = (mae_train / np.mean(y_true_train)) * 100 if np.mean(y_true_train) != 0 else np.nan
    print("\n Training Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_train:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_train:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_train:.2f}")
    print(f" R² Score                  : {r2_train:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_train:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_train:.2f}%")
    print(f" MSE Percentage of Average Price : {mse_percent_train:.2f}%")
    print(f" MAE Percentage of Average Price : {mae_percent_train:.2f}%")

    # Predict on validation set
    y_val_pred_scaled = rl_tuned_model.predict(X_val, verbose=0)
    y_val_pred = scaler.inverse_transform(y_val_pred_scaled)
    y_val_true = scaler.inverse_transform(y_val.reshape(-1, 1))

    # Calculate and print validation metrics
    mae_val = mean_absolute_error(y_val_true, y_val_pred)
    mse_val = mean_squared_error(y_val_true, y_val_pred)
    rmse_val = np.sqrt(mse_val)
    r2_val = r2_score(y_val_true, y_val_pred)
    mape_val = mean_absolute_percentage_error(y_val_true, y_val_pred) * 100
    accuracy_val = 100 - mape_val
    mse_percent_val = (mse_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    mae_percent_val = (mae_val / np.mean(y_val_true)) * 100 if np.mean(y_val_true) != 0 else np.nan
    print("\n Validation Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_val:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_val:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_val:.2f}")
    print(f" R² Score                  : {r2_val:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_val:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_val:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_val:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_val:.2f}%")


    # Step 6: Predict for user-input test date
    predicted_price, actual_price, predicted_date = predict_price_on_test(rl_tuned_model, full_df, scaler, user_date)
    if predicted_price is not None:
        print(f"\n Prediction for {predicted_date}:")
        print(f" Predicted Closing Price: ₹{predicted_price:.2f}")
        if actual_price is not None:
            print(f" Actual Closing Price   : ₹{actual_price}")
        else:
            print("Actual price not available.")

        plot_results(full_df, predicted_date, predicted_price, actual_price)
    else:
        print("❌ Unable to make prediction.")

    # === Step 7: Predict all test dates and compare ===

    # Reuse combined full_df
    combined_df = pd.concat([train_df, test_df])
    scaled_combined = scaler.transform(combined_df[['Close']])

    X_test_all = []
    test_date_indexes = []

    for i in range(len(train_df), len(combined_df)):
        if i - SEQUENCE_LENGTH < 0:
            continue
        seq = scaled_combined[i - SEQUENCE_LENGTH:i]
        X_test_all.append(seq)
        test_date_indexes.append(combined_df.index[i])

    X_test_all = np.array(X_test_all)

    # Predict on test sequences
    y_test_pred_scaled = rl_tuned_model.predict(X_test_all, verbose=0)
    y_test_pred = scaler.inverse_transform(y_test_pred_scaled)

    # Actual prices
    y_test_true = test_df.loc[test_date_indexes, 'Close'].values

    # Calculate and print test metrics
    mae_test = mean_absolute_error(y_test_true, y_test_pred)
    mse_test = mean_squared_error(y_test_true, y_test_pred)
    rmse_test = np.sqrt(mse_test)
    r2_test = r2_score(y_test_true, y_test_pred)
    mape_test = mean_absolute_percentage_error(y_test_true, y_test_pred) * 100
    accuracy_test = 100 - mape_test
    mse_percent_test = (mse_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    mae_percent_test = (mae_test / np.mean(y_test_true)) * 100 if np.mean(y_test_true) != 0 else np.nan
    print("\n Test Set Performance Metrics (RNN):")
    print(f" Mean Absolute Error (MAE) : ₹{mae_test:.2f}")
    print(f" Mean Squared Error (MSE)  : ₹{mse_test:.2f}")
    print(f" Root Squared Error (RMSE) : ₹{rmse_test:.2f}")
    print(f" R² Score                  : {r2_test:.4f}")
    print(f" Mean Absolute Percentage Error (MAPE) : {mape_test:.2f}%")
    print(f" Accuracy (100 - MAPE) : {accuracy_test:.2f}%")
    print(f" MSE Percentage of Average Price: {mse_percent_test:.2f}%")
    print(f" MAE Percentage of Average Price: {mae_percent_test:.2f}%")

    # Plot actual vs predicted
    plt.figure(figsize=(12, 6))
    plt.plot(test_date_indexes, y_test_true, label='Actual Price')
    plt.plot(test_date_indexes, y_test_pred, label='Predicted Price')
    plt.title("Actual vs Predicted INFY Closing Prices (01-Jun to 01-Jul 2025)")
    plt.xlabel("Date")
    plt.ylabel("Closing Price (₹)")
    plt.xticks(rotation=45)
    plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()
